# %%
# Simulation of the interaction of ionizing particles in the scintillant

# %%
pip install TDCRPy --upgrade
# Out:
# ...
#    ---------------------------------------- 0.0/24.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/24.5 MB ? eta -:--:--
#    ---------------------------------------- 0.1/24.5 MB 1.7 MB/s eta 0:00:15
#    ---------------------------------------- 0.3/24.5 MB 2.3 MB/s eta 0:00:11
#     --------------------------------------- 0.4/24.5 MB 2.7 MB/s eta 0:00:09
#     --------------------------------------- 0.5/24.5 MB 2.6 MB/s eta 0:00:10
#    - -------------------------------------- 0.6/24.5 MB 2.9 MB/s eta 0:00:09
#    - -------------------------------------- 0.8/24.5 MB 2.9 MB/s eta 0:00:09
#    - -------------------------------------- 0.9/24.5 MB 3.0 MB/s eta 0:00:08
#    - -------------------------------------- 1.1/24.5 MB 3.1 MB/s eta 0:00:08
#    -- ------------------------------------- 1.2/24.5 MB 3.0 MB/s eta 0:00:08
#    -- ------------------------------------- 1.4/24.5 MB 3.1 MB/s eta 0:00:08
# ...

# %%
pip install opencv-python
# Out:
# ...
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    ---------------------------------------- 0.2/38.8 MB 3.3 MB/s eta 0:00:12
#    ---------------------------------------- 0.3/38.8 MB 3.2 MB/s eta 0:00:13
#    ---------------------------------------- 0.4/38.8 MB 2.9 MB/s eta 0:00:14
#     --------------------------------------- 0.6/38.8 MB 3.0 MB/s eta 0:00:13
#     --------------------------------------- 0.7/38.8 MB 3.2 MB/s eta 0:00:12
#     --------------------------------------- 0.8/38.8 MB 3.1 MB/s eta 0:00:13
#    - -------------------------------------- 1.0/38.8 MB 3.2 MB/s eta 0:00:12
#    - -------------------------------------- 1.1/38.8 MB 3.2 MB/s eta 0:00:12
#    - -------------------------------------- 1.2/38.8 MB 3.2 MB/s eta 0:00:12
#    - -------------------------------------- 1.4/38.8 MB 3.2 MB/s eta 0:00:12
# ...

# %%
import tdcrpy as td
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %% [markdown]
# ## Read bivariate distributions

# %% [markdown]
# ### Electrons from 0 keV to 200 keV

# %%
A = td.TDCR_model_lib.Matrice10_e_1
C = np.flipud(A[1:])
C = np.clip(C, a_min=1e-5, a_max=1e-2)
C = np.log(C)
C = cv2.GaussianBlur(C, (5, 5), 20)
extent = [A[0,0], A[0,-1], A[0,0], A[0,-1]]
x = np.arange(A[0,0], A[0,-1], A[0,-1]/9)
y = np.arange(A[0,0], A[0,-1], A[0,-1]/9)

plt.imshow(C, extent=extent, cmap='viridis', interpolation='nearest')
plt.colorbar()
plt.xticks(np.arange(A[0,0], A[0,-1], A[0,-1]/10))
plt.yticks(np.arange(A[0,0], A[0,-1], A[0,-1]/10))
plt.xlabel(r"$E_i$ /keV", fontsize=14)
plt.ylabel(r"$E_d$ /keV", fontsize=14)
plt.show()

# %% [markdown]
# ### Electrons from 200 keV to 2 MeV

# %%
A = td.TDCR_model_lib.Matrice10_e_2
C = np.flipud(A[1:])
C = np.clip(C, a_min=1e-5, a_max=1e-2)
C = np.log(C)
C = cv2.GaussianBlur(C, (5, 5), 20)
extent = [A[0,0], A[0,-1], A[0,0], A[0,-1]]
x = np.arange(A[0,0], A[0,-1], A[0,-1]/9)
y = np.arange(A[0,0], A[0,-1], A[0,-1]/9)

plt.imshow(C, extent=extent, cmap='viridis', interpolation='nearest')
plt.colorbar()
plt.xticks(np.arange(A[0,0], A[0,-1], A[0,-1]/10))
plt.yticks(np.arange(A[0,0], A[0,-1], A[0,-1]/10))
plt.xlabel(r"$E_i$ /keV", fontsize=14)
plt.ylabel(r"$E_d$ /keV", fontsize=14)
plt.show()

# %% [markdown]
# ### Electrons from 2 MeV to 8 MeV

# %%
A = td.TDCR_model_lib.Matrice10_e_3
C = np.flipud(A[1:])
C = np.clip(C, a_min=1e-5, a_max=1e-2)
C = np.log(C)
C = cv2.GaussianBlur(C, (5, 5), 20)
extent = [A[0,0], A[0,-1], A[0,0], A[0,-1]]
x = np.arange(A[0,0], A[0,-1], A[0,-1]/9)
y = np.arange(A[0,0], A[0,-1], A[0,-1]/9)

plt.imshow(C, extent=extent, cmap='viridis', interpolation='nearest')
plt.colorbar()
plt.xticks(np.arange(A[0,0], A[0,-1], A[0,-1]/10))
plt.yticks(np.arange(A[0,0], A[0,-1], A[0,-1]/10))
plt.xlabel(r"$E_i$ /keV", fontsize=14)
plt.ylabel(r"$E_d$ /keV", fontsize=14)
plt.show()

# %% [markdown]
# ### Photons from 0 keV to 200 keV

# %%
A = td.TDCR_model_lib.Matrice10_p_1
C = np.flipud(A[1:])
C = np.clip(C, a_min=1e-6, a_max=1e-3)
C = np.log(C)
C = cv2.GaussianBlur(C, (5, 5), 20)
extent = [A[0,0], A[0,-1], A[0,0], A[0,-1]]
x = np.arange(A[0,0], A[0,-1], A[0,-1]/9)
y = np.arange(A[0,0], A[0,-1], A[0,-1]/9)

plt.imshow(C, extent=extent, cmap='viridis', interpolation='nearest')
plt.colorbar()
plt.xticks(np.arange(A[0,0], A[0,-1], A[0,-1]/10))
plt.yticks(np.arange(A[0,0], A[0,-1], A[0,-1]/10))
plt.xlabel(r"$E_i$ /keV", fontsize=14)
plt.ylabel(r"$E_d$ /keV", fontsize=14)
plt.show()

# %% [markdown]
# ### Photons from 200 keV to 2 MeV

# %%
A = td.TDCR_model_lib.Matrice10_p_2
C = np.flipud(A[1:])
C = np.clip(C, a_min=1e-5, a_max=1e-4)
C = np.log(C)
C = cv2.GaussianBlur(C, (5, 5), 20)
extent = [A[0,0], A[0,-1], A[0,0], A[0,-1]]
x = np.arange(A[0,0], A[0,-1], A[0,-1]/9)
y = np.arange(A[0,0], A[0,-1], A[0,-1]/9)

plt.imshow(C, extent=extent, cmap='viridis', interpolation='nearest')
plt.colorbar()
plt.xticks(np.arange(A[0,0], A[0,-1], A[0,-1]/10))
plt.yticks(np.arange(A[0,0], A[0,-1], A[0,-1]/10))
plt.xlabel(r"$E_i$ /keV", fontsize=14)
plt.ylabel(r"$E_d$ /keV", fontsize=14)
plt.show()

# %% [markdown]
# ### Photons from 2 MeV to 10 MeV

# %%
A = td.TDCR_model_lib.Matrice10_p_3
C = np.flipud(A[1:])
C = np.clip(C, a_min=1e-6, a_max=1e-4)
C = np.log(C)
C = cv2.GaussianBlur(C, (5, 5), 20)
extent = [A[0,0], A[0,-1], A[0,0], A[0,-1]]
x = np.arange(A[0,0], A[0,-1], A[0,-1]/9)
y = np.arange(A[0,0], A[0,-1], A[0,-1]/9)

plt.imshow(C, extent=extent, cmap='viridis', interpolation='nearest')
plt.colorbar()
plt.xticks(np.arange(A[0,0], A[0,-1], A[0,-1]/10))
plt.yticks(np.arange(A[0,0], A[0,-1], A[0,-1]/10))
plt.xlabel(r"$E_i$ /keV", fontsize=14)
plt.ylabel(r"$E_d$ /keV", fontsize=14)
plt.show()

# %% [markdown]
# ## Sample a deposited energy given an initial energy

# %%
ei = 100  # initial energy in keV
v = 10     # volume of the scintillator in mL
ed_g=td.TDCR_model_lib.energie_dep_gamma2(ei,v)
ed_e=td.TDCR_model_lib.energie_dep_beta2(ei,v)
print(f"The gamma ray of initial energy = {ei} keV, has deposited = {ed_g} keV in the scintillant.")
print(f"The electron of initial energy = {ei} keV, has deposited = {ed_e} keV in the scintillant.")
# Out:
# The gamma ray of initial energy = 100 keV, has deposited = 0 keV in the scintillant.
# The electron of initial energy = 100 keV, has deposited = 100 keV in the scintillant.

# %% [markdown]
# ## Deposited energy of photons as a function of the sintillant volume

# %%
V=np.arange(8,21,0.1)
N=1000
E=15    # initial energy in keV
e_vec, ue_vec = [], []
for v in V:
    x=[]
    for i in range(N):
        out=td.TDCR_model_lib.energie_dep_gamma2(15,v)
        x.append(out)
    e_vec.append(np.mean(x))
    ue_vec.append(np.std(x)/np.sqrt(N))

plt.figure(r"Ed vs volume")
plt.clf()
plt.errorbar(V, e_vec, yerr=ue_vec, fmt="-k", label=rf'$E_i$ = {E} keV')
plt.legend()
plt.xlabel(r"$v$ /mL", fontsize=14)
plt.ylabel(r"$\bar{E_d}$ /(keV)", fontsize=14)
# Out:
# Text(0, 0.5, '$\\bar{E_d}$ /(keV)')
