# %% [markdown]
# # Read Beta spectrum

# %%
pip install TDCRPy==2.20.12
# Out:
# Requirement already satisfied: TDCRPy==2.20.12 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (2.20.12)
# Requirement already satisfied: numpy in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.12) (2.4.6)
# Requirement already satisfied: scipy in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.12) (1.18.0)
# Requirement already satisfied: matplotlib in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.12) (3.11.0)
# Requirement already satisfied: tqdm in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.12) (4.68.3)
# Requirement already satisfied: numba in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.12) (0.65.1)
# Requirement already satisfied: setuptools in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.12) (82.0.1)
# Requirement already satisfied: contourpy>=1.0.1 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.12) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.12) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.12) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.12) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.12) (26.2)
# Requirement already satisfied: pillow>=9 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.12) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.12) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.12) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from python-dateutil>=2.7->matplotlib->TDCRPy==2.20.12) (1.17.0)
# Requirement already satisfied: llvmlite<0.48,>=0.47.0dev0 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from numba->TDCRPy==2.20.12) (0.47.0)
# Requirement already satisfied: colorama in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from tqdm->TDCRPy==2.20.12) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import tdcrpy as td
import matplotlib.pyplot as plt
import numpy as np

# %%
radionuclide = "Tc-99"
mode = "beta-" # 'beta-' or 'beta+'
level = 'tot' # 0,1,2,3 .... or 'tot'

# %% [markdown]
# ## Get information about the BetaShape version

# %%
print(td.TDCR_model_lib.readBetaShapeInfo(radionuclide,mode,level))
# Out:
# -Beta Spectrum (theory) from Fig.9 in
#  https://arxiv.org/pdf/2309.14014-

# %% [markdown]
# ## Read the energy spectrum tabulated from BetaShape

# %%
energy, probability = td.TDCR_model_lib.readBetaShape(radionuclide,mode,level)

plt.figure("Energy spectrum")
plt.clf()
plt.plot(energy[:-1], probability)
plt.xlabel(r'$E$ /keV', fontsize=14)
plt.ylabel(r'$p(E)$ /(keV$^{-1}$)', fontsize=14)
# Out:
# Text(0, 0.5, '$p(E)$ /(keV$^{-1}$)')

# %% [markdown]
# ## Read the deposited energy spectrum
#
# This spectrum is built by TDCRPy (function `buildBetaSpectra`) to be used for the analytical TDCR model.
# This function is available for: H-3, C-14, S-35, Ca-45, Ni-63, Sr-89, Sr-90, Tc-99, Pm-147, Pu-241, Co-60.

# %%
energy2, probability2 = td.TDCR_model_lib.readBetaSpectra(radionuclide)

plt.figure("Deposied energy spectrum")
plt.clf()
plt.plot(energy[:-1], probability,'-b', label="emitted energy spectrum")
plt.plot(energy2, probability2,'-r', label="deposited energy spectrum")
plt.legend(fontsize=14)
plt.xlabel(r'$E$ /keV', fontsize=14)
plt.ylabel(r'$p(E)$ /(keV$^{-1}$)', fontsize=14)
# Out:
# Text(0, 0.5, '$p(E)$ /(keV$^{-1}$)')

# %% [markdown]
# ## Estimate deposited energy spectra for any volume of scintillator
#
# This function uses interpolation in response kernels precalculated with MCNP6.

# %%
rad = "K-40"       # name of the nuclide
N = 100000        # number of MC sampling

V1 = 5            # volume of the scintillator in mL
energy3, probability3 = td.TDCR_model_lib.buildBetaSpectra(rad, V1, N, prt=False)
V2 = 20            # volume of the scintillator in mL
energy4, probability4 = td.TDCR_model_lib.buildBetaSpectra(rad, V2, N, prt=False)

plt.figure(f"Deposied energy spectrum of {rad}")
plt.clf()
plt.plot(energy3, probability3,'-r', label=f"{V1} mL of scintillator")
plt.plot(energy4, probability4,'-k', label=f"{V2} mL of scintillator")
plt.legend(fontsize=14)
plt.xlabel(r'$E$ /keV', fontsize=14)
plt.ylabel(r'$p(E)$ /(keV$^{-1}$)', fontsize=14)
# Out:
# Processing:   0%|          | 0/100000 [00:00<?, ? bins/s]
# Processing:   3%|▎         | 3226/100000 [00:00<00:03, 32254.19 bins/s]
# Processing:   6%|▋         | 6452/100000 [00:00<00:02, 31771.92 bins/s]
# Processing:  10%|▉         | 9630/100000 [00:00<00:02, 31507.13 bins/s]
# Processing:  13%|█▎        | 12860/100000 [00:00<00:02, 31816.54 bins/s]
# Processing:  16%|█▌        | 16168/100000 [00:00<00:02, 32269.00 bins/s]
# Processing:  19%|█▉        | 19424/100000 [00:00<00:02, 32364.70 bins/s]
# Processing:  23%|██▎       | 22755/100000 [00:00<00:02, 32672.73 bins/s]
# Processing:  26%|██▌       | 26023/100000 [00:00<00:02, 32661.72 bins/s]
# Processing:  29%|██▉       | 29290/100000 [00:00<00:02, 32141.04 bins/s]
# Processing:  33%|███▎      | 32506/100000 [00:01<00:02, 32015.18 bins/s]
# Processing:  36%|███▌      | 35709/100000 [00:01<00:02, 31302.77 bins/s]
# Processing:  39%|███▉      | 39006/100000 [00:01<00:01, 31796.96 bins/s]
# Processing:  42%|████▏     | 42245/100000 [00:01<00:01, 31971.62 bins/s]
# Processing:  45%|████▌     | 45487/100000 [00:01<00:01, 32104.64 bins/s]
# Processing:  49%|████▊     | 48700/100000 [00:01<00:01, 31997.12 bins/s]
# Processing:  52%|█████▏    | 51902/100000 [00:01<00:01, 31909.35 bins/s]
# Processing:  55%|█████▌    | 55094/100000 [00:01<00:01, 31747.84 bins/s]
# Processing:  58%|█████▊    | 58313/100000 [00:01<00:01, 31876.25 bins/s]
# Processing:  62%|██████▏   | 61617/100000 [00:01<00:01, 32221.23 bins/s]
# Processing:  65%|██████▍   | 64840/100000 [00:02<00:01, 32173.17 bins/s]
# Processing:  68%|██████▊   | 68058/100000 [00:02<00:00, 32044.89 bins/s]
# Processing:  71%|███████▏  | 71263/100000 [00:02<00:00, 32003.30 bins/s]
# Processing:  74%|███████▍  | 74464/100000 [00:02<00:00, 31990.51 bins/s]
# Processing:  78%|███████▊  | 77669/100000 [00:02<00:00, 32005.31 bins/s]
# Processing:  81%|████████  | 80870/100000 [00:02<00:00, 31773.24 bins/s]
# Processing:  84%|████████▍ | 84048/100000 [00:02<00:00, 31766.58 bins/s]
# Processing:  87%|████████▋ | 87225/100000 [00:02<00:00, 31556.85 bins/s]
# Processing:  90%|█████████ | 90385/100000 [00:02<00:00, 31568.82 bins/s]
# Processing:  94%|█████████▎| 93613/100000 [00:02<00:00, 31779.82 bins/s]
# Processing:  97%|█████████▋| 96792/100000 [00:03<00:00, 31620.99 bins/s]
# Processing: 100%|█████████▉| 99955/100000 [00:03<00:00, 31525.98 bins/s]
# Processing: 100%|██████████| 100000/100000 [00:03<00:00, 31896.06 bins/s]
# mean emitted E = 583.4145011392619 keV 329 328
# mean deposited E = 520.5214399999999 keV 329 328
# Processing:   0%|          | 0/100000 [00:00<?, ? bins/s]
# Processing:   3%|▎         | 3037/100000 [00:00<00:03, 30364.74 bins/s]
# Processing:   6%|▌         | 6161/100000 [00:00<00:03, 30876.46 bins/s]
# Processing:   9%|▉         | 9277/100000 [00:00<00:02, 31003.57 bins/s]
# Processing:  12%|█▏        | 12398/100000 [00:00<00:02, 31084.78 bins/s]
# Processing:  16%|█▌        | 15507/100000 [00:00<00:02, 31071.66 bins/s]
# Processing:  19%|█▊        | 18615/100000 [00:00<00:02, 30882.19 bins/s]
# Processing:  22%|██▏       | 21710/100000 [00:00<00:02, 30902.06 bins/s]
# Processing:  25%|██▍       | 24927/100000 [00:00<00:02, 31304.18 bins/s]
# Processing:  28%|██▊       | 28119/100000 [00:00<00:02, 31493.41 bins/s]
# Processing:  31%|███▏      | 31324/100000 [00:01<00:02, 31663.15 bins/s]
# Processing:  35%|███▍      | 34559/100000 [00:01<00:02, 31871.82 bins/s]
# Processing:  38%|███▊      | 37747/100000 [00:01<00:01, 31594.40 bins/s]
# Processing:  41%|████      | 40908/100000 [00:01<00:01, 31278.95 bins/s]
# Processing:  44%|████▍     | 44037/100000 [00:01<00:01, 31259.36 bins/s]
# Processing:  47%|████▋     | 47259/100000 [00:01<00:01, 31545.87 bins/s]
# Processing:  50%|█████     | 50415/100000 [00:01<00:01, 31522.04 bins/s]
# Processing:  54%|█████▎    | 53568/100000 [00:01<00:01, 31452.12 bins/s]
# Processing:  57%|█████▋    | 56877/100000 [00:01<00:01, 31940.39 bins/s]
# Processing:  60%|██████    | 60072/100000 [00:01<00:01, 31884.95 bins/s]
# Processing:  63%|██████▎   | 63261/100000 [00:02<00:01, 31860.70 bins/s]
# Processing:  66%|██████▋   | 66473/100000 [00:02<00:01, 31936.06 bins/s]
# Processing:  70%|██████▉   | 69667/100000 [00:02<00:00, 31925.72 bins/s]
# Processing:  73%|███████▎  | 72860/100000 [00:02<00:00, 31744.77 bins/s]
# Processing:  76%|███████▌  | 76131/100000 [00:02<00:00, 32030.56 bins/s]
# Processing:  79%|███████▉  | 79406/100000 [00:02<00:00, 32242.59 bins/s]
# Processing:  83%|████████▎ | 82631/100000 [00:02<00:00, 31885.55 bins/s]
# Processing:  86%|████████▌ | 85821/100000 [00:02<00:00, 31714.67 bins/s]
# Processing:  89%|████████▉ | 89033/100000 [00:02<00:00, 31832.82 bins/s]
# Processing:  92%|█████████▏| 92310/100000 [00:02<00:00, 32110.67 bins/s]
# Processing:  96%|█████████▌| 95522/100000 [00:03<00:00, 31995.84 bins/s]
# Processing:  99%|█████████▉| 98754/100000 [00:03<00:00, 32089.98 bins/s]
# Processing: 100%|██████████| 100000/100000 [00:03<00:00, 31671.48 bins/s]
# mean emitted E = 583.4145011392619 keV 329 328
# mean deposited E = 541.3911200000002 keV 329 328
# Text(0, 0.5, '$p(E)$ /(keV$^{-1}$)')
