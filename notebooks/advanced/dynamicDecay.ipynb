# %% [markdown]
# # Dynamic efficiency estimation
#
# This notebook presents how to link the `TDCRPy` package with the `radioactivedecay` package [1] to simulate dynamic TDCR measurements.
#
# [1] Alex Malins & Thom Lemoine, radioactivedecay: A Python package for radioactive decay calculations. Journal of Open Source Software, 7 (71), 3318 (2022). https://doi.org/10.21105/joss.03318.

# %%
pip install TDCRPy==2.20.12
# Out:
# Requirement already satisfied: TDCRPy==2.20.12 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (2.20.12)
# Requirement already satisfied: numpy in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.12) (2.4.6)
# Requirement already satisfied: scipy in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.12) (1.18.0)
# Requirement already satisfied: matplotlib in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.12) (3.11.0)
# Requirement already satisfied: tqdm in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.12) (4.68.3)
# Requirement already satisfied: numba in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.12) (0.65.1)
# Requirement already satisfied: setuptools in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.12) (82.0.1)
# Requirement already satisfied: contourpy>=1.0.1 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.12) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.12) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.12) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.12) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.12) (26.2)
# Requirement already satisfied: pillow>=9 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.12) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.12) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.12) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from python-dateutil>=2.7->matplotlib->TDCRPy==2.20.12) (1.17.0)
# Requirement already satisfied: llvmlite<0.48,>=0.47.0dev0 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from numba->TDCRPy==2.20.12) (0.47.0)
# Requirement already satisfied: colorama in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from tqdm->TDCRPy==2.20.12) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install radioactivedecay
# Out:
# Requirement already satisfied: radioactivedecay in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (0.6.1)
# Requirement already satisfied: matplotlib in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from radioactivedecay) (3.11.0)
# Requirement already satisfied: networkx in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from radioactivedecay) (3.6.1)
# Requirement already satisfied: numpy in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from radioactivedecay) (2.4.6)
# Requirement already satisfied: pandas in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from radioactivedecay) (3.0.3)
# Requirement already satisfied: scipy in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from radioactivedecay) (1.18.0)
# Requirement already satisfied: sympy in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from radioactivedecay) (1.14.0)
# Requirement already satisfied: contourpy>=1.0.1 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->radioactivedecay) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->radioactivedecay) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->radioactivedecay) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->radioactivedecay) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->radioactivedecay) (26.2)
# Requirement already satisfied: pillow>=9 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->radioactivedecay) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->radioactivedecay) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->radioactivedecay) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from python-dateutil>=2.7->matplotlib->radioactivedecay) (1.17.0)
# Requirement already satisfied: tzdata in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from pandas->radioactivedecay) (2026.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from sympy->radioactivedecay) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import radioactivedecay as rd
import tdcrpy as td
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Input parameters

# %%
radionuclide = 'Mo-99' # parent nuclide decaying during the measurement
activity_unit = "Bq"   # unit of the initial activity
time_unit = "h"        # time unit of the decay process
A0 = 1                 # initial activity (set to 1 in order to obtain relative activities)
coolingTime = 30.0     # the cooling time

mode = "eff"
L = 1                  # free parameter (keV-1)
kB = 1e-5              # Birks constant cm/keV
V = 10                 # volume of scintillator (mL)
N = 1000                # number of simulated decays

# %% [markdown]
# ## Run radioactivedecay

# %%
rad_t0 = rd.Inventory({radionuclide: A0}, activity_unit)
rad_t1 = rad_t0.decay(coolingTime, time_unit)
A_t1 = rad_t1.activities(activity_unit)
As_t1 = sum(A_t1.values())
print(f"Activity at {coolingTime} {time_unit}") 
for key, val in A_t1.items(): print(f"\t {key}: {val} {activity_unit}")
print("Total activity = ", As_t1, activity_unit)
print(f"Relative activity at {coolingTime} {time_unit}")
for key, val in A_t1.items(): print(f"\t {key}: {val/As_t1}")
# Out:
# Activity at 30.0 h
# 	 Mo-99: 0.7295308772422591 Bq
# 	 Ru-99: 0.0 Bq
# 	 Tc-99: 7.44742326547114e-09 Bq
# 	 Tc-99m: 0.6738301487178286 Bq
# Total activity =  1.4033610334075108 Bq
# Relative activity at 30.0 h
# 	 Mo-99: 0.5198454708913215
# 	 Ru-99: 0.0
# 	 Tc-99: 5.306847695056773e-09
# 	 Tc-99m: 0.4801545238018309

# %% [markdown]
# ## Display the decay graph

# %%
nuc = rd.Nuclide(radionuclide)
nuc.plot()
# Out:
# (<Figure size 450x750 with 1 Axes>, <Axes: >)

# %% [markdown]
# ## Display the decay curve

# %%
rad_t0 .plot(coolingTime, time_unit, yunits=activity_unit)
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <Axes: xlabel='Time (h)', ylabel='Activity (Bq)'>)

# %% [markdown]
# ## Efficiency calculation as a function of the time

# %%
timeVec = np.arange(0, 30, 2)   # time vector (hours)
effS, ueffS, effD, ueffD, effT, ueffT, effD2, ueffD2 = [], [], [], [], [], [], [], []

# Nuclides to exclude: stable daughters or those absent from TDCRPy decay data
EXCLUDE = {"Pb-208", "Ru-99"}

for t in timeVec:
    rad_t1  = rad_t0.decay(t, time_unit)
    A_t1    = rad_t1.activities(activity_unit)

    # Keep only nuclides with non-negligible activity and known to TDCRPy
    activities = {k: v for k, v in A_t1.items() if k not in EXCLUDE and v > 0}
    total_A    = sum(activities.values())

    # Build comma-separated strings; renormalise so fractions sum exactly to 1
    rads = ", ".join(activities.keys())
    pmf1 = ", ".join(f"{v / total_A:.10f}" for v in activities.values())

    out = td.TDCRPy.TDCRPy(L, rads, pmf1, N, kB, V, mode)
    effS.append(out[0]);  ueffS.append(out[1])
    effD.append(out[2]);  ueffD.append(out[3])
    effT.append(out[4]);  ueffT.append(out[5])
    effD2.append(out[12]); ueffD2.append(out[13])
    print(f"t={t:5.1f} {time_unit}  nuclides={rads}  eff_D={out[2]:.4f}±{out[3]:.4f}")

effS  = np.asarray(effS);  ueffS  = np.asarray(ueffS)
effD  = np.asarray(effD);  ueffD  = np.asarray(ueffD)
effT  = np.asarray(effT);  ueffT  = np.asarray(ueffT)
effD2 = np.asarray(effD2); ueffD2 = np.asarray(ueffD2)
tdcr  = effT / effD
# Out:
# t=  0.0 h  nuclides=Mo-99  eff_D=0.9833±0.0039
# t=  2.0 h  nuclides=Mo-99, Tc-99, Tc-99m  eff_D=0.8472±0.0111
# t=  4.0 h  nuclides=Mo-99, Tc-99, Tc-99m  eff_D=0.7540±0.0134
# t=  6.0 h  nuclides=Mo-99, Tc-99, Tc-99m  eff_D=0.6897±0.0144
# t=  8.0 h  nuclides=Mo-99, Tc-99, Tc-99m  eff_D=0.6760±0.0147
# t= 10.0 h  nuclides=Mo-99, Tc-99, Tc-99m  eff_D=0.6399±0.0150
# t= 12.0 h  nuclides=Mo-99, Tc-99, Tc-99m  eff_D=0.5956±0.0154
# t= 14.0 h  nuclides=Mo-99, Tc-99, Tc-99m  eff_D=0.6142±0.0153
# t= 16.0 h  nuclides=Mo-99, Tc-99, Tc-99m  eff_D=0.5885±0.0153
# t= 18.0 h  nuclides=Mo-99, Tc-99, Tc-99m  eff_D=0.5813±0.0154
# t= 20.0 h  nuclides=Mo-99, Tc-99, Tc-99m  eff_D=0.5933±0.0154
# t= 22.0 h  nuclides=Mo-99, Tc-99, Tc-99m  eff_D=0.5789±0.0155
# t= 24.0 h  nuclides=Mo-99, Tc-99, Tc-99m  eff_D=0.5510±0.0156
# t= 26.0 h  nuclides=Mo-99, Tc-99, Tc-99m  eff_D=0.5732±0.0155
# t= 28.0 h  nuclides=Mo-99, Tc-99, Tc-99m  eff_D=0.5572±0.0156

# %% [markdown]
# ## Plot efficiency curves

# %%
# Create the plot
plt.figure(figsize=(10, 6))
plt.errorbar(timeVec, effS, yerr=ueffS, fmt='o', capsize=5, label=r'$\epsilon_S$')
plt.errorbar(timeVec, effD, yerr=ueffD, fmt='o', capsize=5, label=r'$\epsilon_D$')
plt.errorbar(timeVec, tdcr, yerr=ueffT , fmt='o', capsize=5, label=r'$\epsilon_T/\epsilon_D$')
plt.errorbar(timeVec, effD2, yerr=ueffD2, fmt='o', capsize=5, label=r'$\epsilon_D$ (CIEMAT/NIST)')

# Adding titles and labels
#plt.title('Efficiency (effD) as a Function of Time')
plt.xlabel(f'cooling time /{time_unit}',fontsize=16)
plt.ylabel(r'$\epsilon_D$ and $\epsilon_T/\epsilon_D$',fontsize=16)
plt.legend(fontsize=16)
plt.grid(True)

plt.savefig("plotDecay")
# Show the plot
plt.show()
