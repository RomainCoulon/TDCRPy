# %% [markdown]
# # Efficiency curves using TDCRPy

# %%
pip install TDCRPy==2.20.12
# Out:
# Requirement already satisfied: TDCRPy==2.20.12 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (2.20.12)
# Requirement already satisfied: numpy in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.12) (2.4.6)
# Requirement already satisfied: scipy in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.12) (1.18.0)
# Requirement already satisfied: matplotlib in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.12) (3.11.0)
# Requirement already satisfied: tqdm in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.12) (4.68.3)
# Requirement already satisfied: numba in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.12) (0.65.1)
# Requirement already satisfied: setuptools in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.12) (82.0.1)
# Requirement already satisfied: contourpy>=1.0.1 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.12) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.12) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.12) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.12) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.12) (26.2)
# Requirement already satisfied: pillow>=9 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.12) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.12) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.12) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from python-dateutil>=2.7->matplotlib->TDCRPy==2.20.12) (1.17.0)
# Requirement already satisfied: llvmlite<0.48,>=0.47.0dev0 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from numba->TDCRPy==2.20.12) (0.47.0)
# Requirement already satisfied: colorama in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from tqdm->TDCRPy==2.20.12) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import tdcrpy as td
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt

# %%
mode = "eff"                # ask for efficiency calculation
Rad="Co-60"                 # radionuclides
pmf_1="1"                   # relatives fractions of the radionulides
N = 1000                     # number of Monte Carlo trials
kB =1.0e-5                  # Birks constant in cm keV-1
V = 10                      # volume of scintillator in mL
L=np.logspace(-3,2,num=100) # free parameter in keV-1

# Record decay histories in temporary files
td.TDCRPy.TDCRPy(L[0], Rad, pmf_1, N, kB, V, mode, barp=True, record=True)

effS, u_effS, effD, u_effD, effT, u_effT, effD2, u_effD2 = [], [],[], [],[], [], [], []
for l in tqdm(L, desc="free parameters ", unit=" iterations"):
  out = td.TDCRPy.TDCRPy(l, Rad, pmf_1, N, kB, V, mode, readRecHist=True)
  effS.append(out[2])
  u_effS.append(out[3])
  effD.append(out[2])
  u_effD.append(out[3])
  effT.append(out[4])
  u_effT.append(out[5])
  effD2.append(out[12])
  u_effD2.append(out[13])
# Out:
#  ______  ______  ______ _______  ________
# |__  __||  ___ \|  ___||  ___ | |  ____ |
#   | |   | |  | || |    | |  | | | |___| |___     ___
#   | |   | |  | || |    | |__| | |  _____|\  \   |  |
#   | |   | |__| || |____|  __  \ | |       \  \  |  |
#   |_|   |_____/ |_____||_|  \__\|_|        \  \_|  |
#   +++++++++++++++++++++++++++++++++++++++++/      /
#   ________________________________________/      /
#  |______________________________________________/
#
#
# version 2.20.12
# BIPM 2023 - license MIT
# distribution: https://pypi.org/project/TDCRPy
# developement: https://github.com/RomainCoulon/TDCRPy
#
# start calculation...
# Processing:   0%|          | 0/1000 [00:00<?, ? decays/s]
# Processing:   1%|          | 8/1000 [00:00<00:13, 75.79 decays/s]
# Processing:   2%|▏         | 17/1000 [00:00<00:12, 79.66 decays/s]
# Processing:   3%|▎         | 26/1000 [00:00<00:11, 81.51 decays/s]
# Processing:   4%|▎         | 35/1000 [00:00<00:11, 82.42 decays/s]
# Processing:   4%|▍         | 44/1000 [00:00<00:11, 82.87 decays/s]
# Processing:   5%|▌         | 53/1000 [00:00<00:11, 83.07 decays/s]
# Processing:   6%|▌         | 62/1000 [00:00<00:11, 82.35 decays/s]
# Processing:   7%|▋         | 71/1000 [00:00<00:11, 82.68 decays/s]
# Processing:   8%|▊         | 80/1000 [00:00<00:11, 83.21 decays/s]
# Processing:   9%|▉         | 89/1000 [00:01<00:11, 82.72 decays/s]
# Processing:  10%|▉         | 98/1000 [00:01<00:10, 82.50 decays/s]
# Processing:  11%|█         | 107/1000 [00:01<00:10, 82.74 decays/s]
# Processing:  12%|█▏        | 116/1000 [00:01<00:11, 79.72 decays/s]
# Processing:  12%|█▎        | 125/1000 [00:01<00:10, 80.15 decays/s]
# Processing:  13%|█▎        | 134/1000 [00:01<00:10, 80.84 decays/s]
# Processing:  14%|█▍        | 143/1000 [00:01<00:10, 80.25 decays/s]
# Processing:  15%|█▌        | 152/1000 [00:01<00:10, 79.86 decays/s]
# Processing:  16%|█▌        | 161/1000 [00:01<00:10, 81.36 decays/s]
# Processing:  17%|█▋        | 170/1000 [00:02<00:10, 82.32 decays/s]
# Processing:  18%|█▊        | 179/1000 [00:02<00:09, 82.86 decays/s]
# Processing:  19%|█▉        | 188/1000 [00:02<00:09, 83.39 decays/s]
# Processing:  20%|█▉        | 197/1000 [00:02<00:09, 83.61 decays/s]
# Processing:  21%|██        | 206/1000 [00:02<00:09, 84.05 decays/s]
# Processing:  22%|██▏       | 215/1000 [00:02<00:09, 84.24 decays/s]
# Processing:  22%|██▏       | 224/1000 [00:02<00:09, 83.96 decays/s]
# Processing:  23%|██▎       | 233/1000 [00:02<00:09, 82.54 decays/s]
# Processing:  24%|██▍       | 242/1000 [00:02<00:09, 83.11 decays/s]
# Processing:  25%|██▌       | 251/1000 [00:03<00:08, 83.73 decays/s]
# Processing:  26%|██▌       | 260/1000 [00:03<00:08, 83.63 decays/s]
# Processing:  27%|██▋       | 269/1000 [00:03<00:08, 83.03 decays/s]
# Processing:  28%|██▊       | 278/1000 [00:03<00:08, 83.76 decays/s]
# Processing:  29%|██▊       | 287/1000 [00:03<00:08, 82.88 decays/s]
# Processing:  30%|██▉       | 296/1000 [00:03<00:08, 83.09 decays/s]
# Processing:  30%|███       | 305/1000 [00:03<00:08, 82.87 decays/s]
# Processing:  31%|███▏      | 314/1000 [00:03<00:08, 82.95 decays/s]
# Processing:  32%|███▏      | 323/1000 [00:03<00:08, 83.13 decays/s]
# Processing:  33%|███▎      | 332/1000 [00:04<00:08, 82.05 decays/s]
# Processing:  34%|███▍      | 341/1000 [00:04<00:07, 82.52 decays/s]
# Processing:  35%|███▌      | 350/1000 [00:04<00:07, 82.49 decays/s]
# Processing:  36%|███▌      | 359/1000 [00:04<00:07, 82.89 decays/s]
# Processing:  37%|███▋      | 368/1000 [00:04<00:07, 83.18 decays/s]
# Processing:  38%|███▊      | 377/1000 [00:04<00:07, 83.38 decays/s]
# Processing:  39%|███▊      | 386/1000 [00:04<00:07, 83.71 decays/s]
# Processing:  40%|███▉      | 395/1000 [00:04<00:07, 83.84 decays/s]
# Processing:  40%|████      | 404/1000 [00:04<00:07, 83.77 decays/s]
# Processing:  41%|████▏     | 413/1000 [00:05<00:07, 82.67 decays/s]
# Processing:  42%|████▏     | 422/1000 [00:05<00:06, 82.59 decays/s]
# Processing:  43%|████▎     | 431/1000 [00:05<00:06, 82.76 decays/s]
# Processing:  44%|████▍     | 440/1000 [00:05<00:06, 83.13 decays/s]
# Processing:  45%|████▍     | 449/1000 [00:05<00:06, 83.35 decays/s]
# Processing:  46%|████▌     | 458/1000 [00:05<00:06, 81.93 decays/s]
# Processing:  47%|████▋     | 467/1000 [00:05<00:06, 82.08 decays/s]
# Processing:  48%|████▊     | 476/1000 [00:05<00:06, 82.07 decays/s]
# Processing:  48%|████▊     | 485/1000 [00:05<00:06, 82.45 decays/s]
# Processing:  49%|████▉     | 494/1000 [00:05<00:06, 83.15 decays/s]
# Processing:  50%|█████     | 503/1000 [00:06<00:06, 81.49 decays/s]
# Processing:  51%|█████     | 512/1000 [00:06<00:05, 82.18 decays/s]
# Processing:  52%|█████▏    | 521/1000 [00:06<00:05, 82.68 decays/s]
# Processing:  53%|█████▎    | 530/1000 [00:06<00:05, 83.18 decays/s]
# Processing:  54%|█████▍    | 539/1000 [00:06<00:05, 83.29 decays/s]
# Processing:  55%|█████▍    | 548/1000 [00:06<00:05, 83.48 decays/s]
# Processing:  56%|█████▌    | 557/1000 [00:06<00:05, 83.49 decays/s]
# Processing:  57%|█████▋    | 566/1000 [00:06<00:05, 83.77 decays/s]
# Processing:  57%|█████▊    | 575/1000 [00:06<00:05, 83.48 decays/s]
# Processing:  58%|█████▊    | 584/1000 [00:07<00:04, 83.71 decays/s]
# Processing:  59%|█████▉    | 593/1000 [00:07<00:04, 83.61 decays/s]
# Processing:  60%|██████    | 602/1000 [00:07<00:04, 83.39 decays/s]
# Processing:  61%|██████    | 611/1000 [00:07<00:04, 83.33 decays/s]
# Processing:  62%|██████▏   | 620/1000 [00:07<00:04, 81.10 decays/s]
# Processing:  63%|██████▎   | 629/1000 [00:07<00:04, 81.74 decays/s]
# Processing:  64%|██████▍   | 638/1000 [00:07<00:04, 81.57 decays/s]
# Processing:  65%|██████▍   | 647/1000 [00:07<00:04, 81.89 decays/s]
# Processing:  66%|██████▌   | 656/1000 [00:07<00:04, 82.68 decays/s]
# Processing:  66%|██████▋   | 665/1000 [00:08<00:04, 82.96 decays/s]
# Processing:  67%|██████▋   | 674/1000 [00:08<00:03, 83.59 decays/s]
# Processing:  68%|██████▊   | 683/1000 [00:08<00:03, 79.64 decays/s]
# Processing:  69%|██████▉   | 692/1000 [00:08<00:03, 81.02 decays/s]
# Processing:  70%|███████   | 701/1000 [00:08<00:03, 81.30 decays/s]
# Processing:  71%|███████   | 710/1000 [00:08<00:03, 82.11 decays/s]
# Processing:  72%|███████▏  | 719/1000 [00:08<00:03, 82.53 decays/s]
# Processing:  73%|███████▎  | 728/1000 [00:08<00:03, 82.12 decays/s]
# Processing:  74%|███████▎  | 737/1000 [00:08<00:03, 82.69 decays/s]
# Processing:  75%|███████▍  | 746/1000 [00:09<00:03, 83.22 decays/s]
# Processing:  76%|███████▌  | 755/1000 [00:09<00:02, 83.93 decays/s]
# Processing:  76%|███████▋  | 764/1000 [00:09<00:02, 84.25 decays/s]
# Processing:  77%|███████▋  | 773/1000 [00:09<00:02, 84.27 decays/s]
# Processing:  78%|███████▊  | 782/1000 [00:09<00:02, 83.56 decays/s]
# Processing:  79%|███████▉  | 791/1000 [00:09<00:02, 84.00 decays/s]
# Processing:  80%|████████  | 800/1000 [00:09<00:02, 82.08 decays/s]
# Processing:  81%|████████  | 809/1000 [00:09<00:02, 82.88 decays/s]
# Processing:  82%|████████▏ | 818/1000 [00:09<00:02, 83.07 decays/s]
# Processing:  83%|████████▎ | 827/1000 [00:10<00:02, 83.45 decays/s]
# Processing:  84%|████████▎ | 836/1000 [00:10<00:01, 83.78 decays/s]
# Processing:  84%|████████▍ | 845/1000 [00:10<00:01, 83.62 decays/s]
# Processing:  85%|████████▌ | 854/1000 [00:10<00:01, 83.74 decays/s]
# Processing:  86%|████████▋ | 863/1000 [00:10<00:01, 81.01 decays/s]
# Processing:  87%|████████▋ | 872/1000 [00:10<00:01, 81.88 decays/s]
# Processing:  88%|████████▊ | 881/1000 [00:10<00:01, 82.36 decays/s]
# Processing:  89%|████████▉ | 890/1000 [00:10<00:01, 82.08 decays/s]
# Processing:  90%|████████▉ | 899/1000 [00:10<00:01, 82.38 decays/s]
# Processing:  91%|█████████ | 908/1000 [00:10<00:01, 81.31 decays/s]
# Processing:  92%|█████████▏| 917/1000 [00:11<00:01, 80.07 decays/s]
# Processing:  93%|█████████▎| 926/1000 [00:11<00:00, 81.05 decays/s]
# Processing:  94%|█████████▎| 935/1000 [00:11<00:00, 82.10 decays/s]
# Processing:  94%|█████████▍| 944/1000 [00:11<00:00, 82.69 decays/s]
# Processing:  95%|█████████▌| 953/1000 [00:11<00:00, 82.24 decays/s]
# Processing:  96%|█████████▌| 962/1000 [00:11<00:00, 82.96 decays/s]
# Processing:  97%|█████████▋| 971/1000 [00:11<00:00, 82.58 decays/s]
# Processing:  98%|█████████▊| 980/1000 [00:11<00:00, 82.40 decays/s]
# Processing:  99%|█████████▉| 989/1000 [00:11<00:00, 82.82 decays/s]
# Processing: 100%|█████████▉| 998/1000 [00:12<00:00, 83.22 decays/s]
# Processing: 100%|██████████| 1000/1000 [00:12<00:00, 82.62 decays/s]
# free parameters :   0%|          | 0/100 [00:00<?, ? iterations/s]
# free parameters :  10%|█         | 10/100 [00:00<00:00, 99.16 iterations/s]
# free parameters :  21%|██        | 21/100 [00:00<00:00, 99.89 iterations/s]
# free parameters :  32%|███▏      | 32/100 [00:00<00:00, 100.05 iterations/s]
# free parameters :  43%|████▎     | 43/100 [00:00<00:00, 98.38 iterations/s]
# free parameters :  54%|█████▍    | 54/100 [00:00<00:00, 100.03 iterations/s]
# free parameters :  65%|██████▌   | 65/100 [00:00<00:00, 100.19 iterations/s]
# free parameters :  76%|███████▌  | 76/100 [00:00<00:00, 100.80 iterations/s]
# free parameters :  87%|████████▋ | 87/100 [00:00<00:00, 100.47 iterations/s]
# free parameters :  98%|█████████▊| 98/100 [00:00<00:00, 100.22 iterations/s]
# free parameters : 100%|██████████| 100/100 [00:00<00:00, 100.07 iterations/s]

# %%
effS=np.asarray(effS)
effT=np.asarray(effT)
effD=np.asarray(effD)
effD2=np.asarray(effD2)
u_effS=np.asarray(u_effS)
u_effT=np.asarray(u_effT)
u_effD=np.asarray(u_effD)
u_effD2=np.asarray(u_effD2)

tdcr=effT/effD
u_tdcr=np.sqrt(u_effD**2*effT**2/effD**4+u_effT**2/effD**2)

plt.figure("efficiency vs free parameter")
plt.clf()
plt.errorbar(L,effD,yerr=u_effD,fmt="-k",label="double coincidences")
plt.errorbar(L,effT,yerr=u_effT,fmt="-r",label="triple coincidences")
plt.errorbar(L,effD2,yerr=u_effD2,fmt="-g",label="double coincidences (CIEMAT/NIST)")
plt.xscale('log')
plt.xlabel(r'$L$ /keV$^{-1}$', fontsize=14)
plt.ylabel(r'$\epsilon$', fontsize=14)
plt.legend()

plt.figure("efficiency vs TDCR")
plt.clf()
plt.errorbar(tdcr,effD,xerr=u_tdcr,yerr=u_effD,fmt="-k")
#plt.xscale('log')
plt.xlabel(r'$R_T/R_D$', fontsize=14)
plt.ylabel(r'$\epsilon_{D}$', fontsize=14)
# Out:
# Text(0, 0.5, '$\\epsilon_{D}$')
