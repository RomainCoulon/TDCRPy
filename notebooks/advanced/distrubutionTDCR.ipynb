# %% [markdown]
# # Distribution of TDCR measurements

# %%
pip install TDCRPy==2.20.12
# Out:
# Requirement already satisfied: TDCRPy==2.20.12 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (2.20.12)
# Requirement already satisfied: numpy in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.12) (2.4.6)
# Requirement already satisfied: scipy in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.12) (1.18.0)
# Requirement already satisfied: matplotlib in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.12) (3.11.0)
# Requirement already satisfied: tqdm in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.12) (4.68.3)
# Requirement already satisfied: numba in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.12) (0.65.1)
# Requirement already satisfied: setuptools in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.12) (82.0.1)
# Requirement already satisfied: contourpy>=1.0.1 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.12) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.12) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.12) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.12) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.12) (26.2)
# Requirement already satisfied: pillow>=9 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.12) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.12) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.12) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from python-dateutil>=2.7->matplotlib->TDCRPy==2.20.12) (1.17.0)
# Requirement already satisfied: llvmlite<0.48,>=0.47.0dev0 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from numba->TDCRPy==2.20.12) (0.47.0)
# Requirement already satisfied: colorama in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from tqdm->TDCRPy==2.20.12) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import tdcrpy as td
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt

# %% [markdown]
# ## Record the decay histories in temporary files

# %%
mode = "eff"                # ask for efficiency calculation
Rad="Cd-109"                # radionuclides
pmf_1="1"                   # relatives fractions of the radionulides
N = 1500                    # number of Monte Carlo trials
kB =1.0e-5                  # Birks constant in cm keV-1
V = 10                      # volume of scintillator in mL
L=1                         # free parameter in keV-1

out = td.TDCRPy.TDCRPy(1, Rad, pmf_1, N, kB, V, mode, record=True, barp=True)
# Out:
#  ______  ______  ______ _______  ________
# |__  __||  ___ \|  ___||  ___ | |  ____ |
#   | |   | |  | || |    | |  | | | |___| |___     ___
#   | |   | |  | || |    | |__| | |  _____|\  \   |  |
#   | |   | |__| || |____|  __  \ | |       \  \  |  |
#   |_|   |_____/ |_____||_|  \__\|_|        \  \_|  |
#   +++++++++++++++++++++++++++++++++++++++++/      /
#   ________________________________________/      /
#  |______________________________________________/
#
#
# version 2.20.12
# BIPM 2023 - license MIT
# distribution: https://pypi.org/project/TDCRPy
# developement: https://github.com/RomainCoulon/TDCRPy
#
# start calculation...
# Processing:   0%|          | 0/1500 [00:00<?, ? decays/s]
# Processing:   0%|          | 1/1500 [00:00<04:10,  5.99 decays/s]
# Processing:   1%|          | 12/1500 [00:00<00:27, 53.64 decays/s]
# Processing:   1%|▏         | 19/1500 [00:00<00:29, 50.83 decays/s]
# Processing:   2%|▏         | 25/1500 [00:00<00:29, 49.84 decays/s]
# Processing:   2%|▏         | 35/1500 [00:00<00:24, 60.60 decays/s]
# Processing:   3%|▎         | 42/1500 [00:00<00:24, 58.79 decays/s]
# Processing:   3%|▎         | 51/1500 [00:00<00:21, 66.83 decays/s]
# Processing:   4%|▍         | 63/1500 [00:00<00:17, 81.34 decays/s]
# Processing:   5%|▍         | 72/1500 [00:01<00:19, 73.33 decays/s]
# Processing:   6%|▌         | 85/1500 [00:01<00:16, 87.38 decays/s]
# Processing:   6%|▋         | 95/1500 [00:01<00:15, 88.93 decays/s]
# Processing:   7%|▋         | 106/1500 [00:01<00:15, 89.89 decays/s]
# Processing:   8%|▊         | 116/1500 [00:01<00:17, 80.01 decays/s]
# Processing:   8%|▊         | 126/1500 [00:01<00:16, 84.67 decays/s]
# Processing:   9%|▉         | 136/1500 [00:01<00:15, 86.33 decays/s]
# Processing:  10%|▉         | 146/1500 [00:01<00:15, 89.21 decays/s]
# Processing:  10%|█         | 157/1500 [00:02<00:14, 91.75 decays/s]
# Processing:  11%|█         | 167/1500 [00:02<00:15, 86.82 decays/s]
# Processing:  12%|█▏        | 176/1500 [00:02<00:16, 80.17 decays/s]
# Processing:  13%|█▎        | 189/1500 [00:02<00:14, 88.01 decays/s]
# Processing:  13%|█▎        | 201/1500 [00:02<00:13, 93.64 decays/s]
# Processing:  14%|█▍        | 212/1500 [00:02<00:13, 93.61 decays/s]
# Processing:  15%|█▍        | 222/1500 [00:02<00:15, 81.03 decays/s]
# Processing:  15%|█▌        | 232/1500 [00:02<00:14, 84.58 decays/s]
# Processing:  16%|█▌        | 242/1500 [00:03<00:14, 88.37 decays/s]
# Processing:  17%|█▋        | 256/1500 [00:03<00:12, 99.89 decays/s]
# Processing:  18%|█▊        | 267/1500 [00:03<00:14, 82.44 decays/s]
# Processing:  19%|█▊        | 279/1500 [00:03<00:13, 90.63 decays/s]
# Processing:  19%|█▉        | 291/1500 [00:03<00:12, 96.88 decays/s]
# Processing:  20%|██        | 302/1500 [00:03<00:14, 84.13 decays/s]
# Processing:  21%|██        | 312/1500 [00:03<00:13, 85.83 decays/s]
# Processing:  21%|██▏       | 322/1500 [00:03<00:13, 88.51 decays/s]
# Processing:  22%|██▏       | 332/1500 [00:04<00:13, 89.20 decays/s]
# Processing:  23%|██▎       | 344/1500 [00:04<00:12, 92.62 decays/s]
# Processing:  24%|██▎       | 354/1500 [00:04<00:13, 83.11 decays/s]
# Processing:  24%|██▍       | 364/1500 [00:04<00:13, 86.05 decays/s]
# Processing:  25%|██▍       | 373/1500 [00:04<00:13, 83.89 decays/s]
# Processing:  25%|██▌       | 382/1500 [00:04<00:13, 84.10 decays/s]
# Processing:  26%|██▌       | 391/1500 [00:04<00:13, 80.84 decays/s]
# Processing:  27%|██▋       | 400/1500 [00:04<00:13, 81.58 decays/s]
# Processing:  27%|██▋       | 409/1500 [00:05<00:14, 76.60 decays/s]
# Processing:  28%|██▊       | 418/1500 [00:05<00:14, 77.15 decays/s]
# Processing:  28%|██▊       | 427/1500 [00:05<00:13, 77.37 decays/s]
# Processing:  29%|██▉       | 440/1500 [00:05<00:11, 90.66 decays/s]
# Processing:  30%|███       | 450/1500 [00:05<00:12, 86.09 decays/s]
# Processing:  31%|███       | 461/1500 [00:05<00:11, 91.44 decays/s]
# Processing:  31%|███▏      | 471/1500 [00:05<00:11, 91.54 decays/s]
# Processing:  32%|███▏      | 481/1500 [00:05<00:12, 81.21 decays/s]
# Processing:  33%|███▎      | 490/1500 [00:05<00:12, 80.52 decays/s]
# Processing:  33%|███▎      | 499/1500 [00:06<00:12, 82.85 decays/s]
# Processing:  34%|███▍      | 508/1500 [00:06<00:12, 77.86 decays/s]
# Processing:  35%|███▍      | 518/1500 [00:06<00:11, 83.46 decays/s]
# Processing:  35%|███▌      | 527/1500 [00:06<00:11, 83.44 decays/s]
# Processing:  36%|███▌      | 536/1500 [00:06<00:11, 81.80 decays/s]
# Processing:  36%|███▋      | 546/1500 [00:06<00:11, 85.12 decays/s]
# Processing:  37%|███▋      | 555/1500 [00:06<00:13, 67.64 decays/s]
# Processing:  38%|███▊      | 563/1500 [00:06<00:13, 69.18 decays/s]
# Processing:  38%|███▊      | 574/1500 [00:07<00:12, 76.98 decays/s]
# Processing:  39%|███▉      | 583/1500 [00:07<00:11, 79.33 decays/s]
# Processing:  39%|███▉      | 592/1500 [00:07<00:11, 79.16 decays/s]
# Processing:  40%|████      | 602/1500 [00:07<00:11, 75.43 decays/s]
# Processing:  41%|████      | 610/1500 [00:07<00:12, 72.21 decays/s]
# Processing:  41%|████▏     | 619/1500 [00:07<00:11, 74.32 decays/s]
# Processing:  42%|████▏     | 627/1500 [00:07<00:11, 74.01 decays/s]
# Processing:  42%|████▏     | 635/1500 [00:07<00:11, 72.38 decays/s]
# Processing:  43%|████▎     | 644/1500 [00:07<00:11, 76.63 decays/s]
# Processing:  44%|████▎     | 654/1500 [00:08<00:10, 81.08 decays/s]
# Processing:  44%|████▍     | 666/1500 [00:08<00:09, 90.73 decays/s]
# Processing:  45%|████▌     | 676/1500 [00:08<00:09, 90.94 decays/s]
# Processing:  46%|████▌     | 686/1500 [00:08<00:08, 91.43 decays/s]
# Processing:  46%|████▋     | 696/1500 [00:08<00:10, 79.80 decays/s]
# Processing:  47%|████▋     | 705/1500 [00:08<00:09, 80.03 decays/s]
# Processing:  48%|████▊     | 715/1500 [00:08<00:09, 85.22 decays/s]
# Processing:  48%|████▊     | 724/1500 [00:08<00:09, 78.40 decays/s]
# Processing:  49%|████▉     | 733/1500 [00:09<00:10, 75.60 decays/s]
# Processing:  50%|████▉     | 745/1500 [00:09<00:09, 82.88 decays/s]
# Processing:  50%|█████     | 756/1500 [00:09<00:08, 89.72 decays/s]
# Processing:  51%|█████     | 766/1500 [00:09<00:08, 85.21 decays/s]
# Processing:  52%|█████▏    | 777/1500 [00:09<00:08, 86.71 decays/s]
# Processing:  52%|█████▏    | 786/1500 [00:09<00:08, 80.74 decays/s]
# Processing:  53%|█████▎    | 796/1500 [00:09<00:08, 84.19 decays/s]
# Processing:  54%|█████▍    | 807/1500 [00:09<00:07, 88.33 decays/s]
# Processing:  54%|█████▍    | 816/1500 [00:10<00:08, 83.27 decays/s]
# Processing:  55%|█████▌    | 826/1500 [00:10<00:08, 83.32 decays/s]
# Processing:  56%|█████▌    | 835/1500 [00:10<00:08, 79.54 decays/s]
# Processing:  56%|█████▋    | 844/1500 [00:10<00:08, 79.93 decays/s]
# Processing:  57%|█████▋    | 853/1500 [00:10<00:08, 76.62 decays/s]
# Processing:  57%|█████▋    | 862/1500 [00:10<00:08, 79.16 decays/s]
# Processing:  58%|█████▊    | 875/1500 [00:10<00:07, 88.76 decays/s]
# Processing:  59%|█████▉    | 887/1500 [00:10<00:06, 95.29 decays/s]
# Processing:  60%|█████▉    | 898/1500 [00:10<00:06, 96.01 decays/s]
# Processing:  61%|██████    | 908/1500 [00:11<00:06, 91.28 decays/s]
# Processing:  61%|██████▏   | 921/1500 [00:11<00:06, 94.78 decays/s]
# Processing:  62%|██████▏   | 931/1500 [00:11<00:06, 82.57 decays/s]
# Processing:  63%|██████▎   | 940/1500 [00:11<00:06, 81.56 decays/s]
# Processing:  64%|██████▎   | 954/1500 [00:11<00:05, 91.63 decays/s]
# Processing:  64%|██████▍   | 966/1500 [00:11<00:05, 96.51 decays/s]
# Processing:  65%|██████▌   | 976/1500 [00:11<00:05, 94.82 decays/s]
# Processing:  66%|██████▌   | 986/1500 [00:11<00:05, 91.85 decays/s]
# Processing:  66%|██████▋   | 996/1500 [00:12<00:06, 82.54 decays/s]
# Processing:  67%|██████▋   | 1005/1500 [00:12<00:06, 78.65 decays/s]
# Processing:  68%|██████▊   | 1014/1500 [00:12<00:06, 77.67 decays/s]
# Processing:  69%|██████▊   | 1028/1500 [00:12<00:05, 88.89 decays/s]
# Processing:  69%|██████▉   | 1037/1500 [00:12<00:05, 86.78 decays/s]
# Processing:  70%|██████▉   | 1047/1500 [00:12<00:05, 88.94 decays/s]
# Processing:  70%|███████   | 1056/1500 [00:12<00:05, 83.35 decays/s]
# Processing:  71%|███████   | 1068/1500 [00:12<00:04, 91.33 decays/s]
# Processing:  72%|███████▏  | 1078/1500 [00:13<00:04, 90.08 decays/s]
# Processing:  73%|███████▎  | 1091/1500 [00:13<00:04, 96.25 decays/s]
# Processing:  73%|███████▎  | 1101/1500 [00:13<00:04, 90.84 decays/s]
# Processing:  74%|███████▍  | 1111/1500 [00:13<00:04, 89.23 decays/s]
# Processing:  75%|███████▍  | 1120/1500 [00:13<00:04, 86.40 decays/s]
# Processing:  75%|███████▌  | 1129/1500 [00:13<00:05, 73.04 decays/s]
# Processing:  76%|███████▌  | 1137/1500 [00:13<00:04, 74.50 decays/s]
# Processing:  76%|███████▋  | 1145/1500 [00:13<00:04, 74.57 decays/s]
# Processing:  77%|███████▋  | 1153/1500 [00:13<00:04, 71.58 decays/s]
# Processing:  78%|███████▊  | 1163/1500 [00:14<00:04, 77.96 decays/s]
# Processing:  78%|███████▊  | 1171/1500 [00:14<00:04, 68.18 decays/s]
# Processing:  79%|███████▊  | 1179/1500 [00:14<00:04, 67.12 decays/s]
# Processing:  79%|███████▉  | 1189/1500 [00:14<00:04, 74.88 decays/s]
# Processing:  80%|████████  | 1201/1500 [00:14<00:03, 83.37 decays/s]
# Processing:  81%|████████  | 1210/1500 [00:14<00:03, 84.88 decays/s]
# Processing:  82%|████████▏ | 1223/1500 [00:14<00:02, 95.74 decays/s]
# Processing:  82%|████████▏ | 1233/1500 [00:14<00:02, 94.33 decays/s]
# Processing:  83%|████████▎ | 1243/1500 [00:15<00:02, 94.25 decays/s]
# Processing:  84%|████████▎ | 1253/1500 [00:15<00:02, 88.38 decays/s]
# Processing:  84%|████████▍ | 1262/1500 [00:15<00:02, 80.88 decays/s]
# Processing:  85%|████████▍ | 1273/1500 [00:15<00:02, 84.18 decays/s]
# Processing:  86%|████████▌ | 1283/1500 [00:15<00:02, 84.48 decays/s]
# Processing:  86%|████████▌ | 1292/1500 [00:15<00:02, 82.40 decays/s]
# Processing:  87%|████████▋ | 1301/1500 [00:15<00:02, 81.11 decays/s]
# Processing:  87%|████████▋ | 1310/1500 [00:15<00:02, 75.96 decays/s]
# Processing:  88%|████████▊ | 1318/1500 [00:15<00:02, 74.87 decays/s]
# Processing:  88%|████████▊ | 1327/1500 [00:16<00:02, 74.66 decays/s]
# Processing:  89%|████████▉ | 1335/1500 [00:16<00:02, 66.31 decays/s]
# Processing:  90%|████████▉ | 1346/1500 [00:16<00:02, 72.71 decays/s]
# Processing:  90%|█████████ | 1354/1500 [00:16<00:01, 74.46 decays/s]
# Processing:  91%|█████████ | 1363/1500 [00:16<00:01, 75.10 decays/s]
# Processing:  91%|█████████▏| 1372/1500 [00:16<00:01, 78.67 decays/s]
# Processing:  92%|█████████▏| 1381/1500 [00:16<00:01, 80.43 decays/s]
# Processing:  93%|█████████▎| 1391/1500 [00:16<00:01, 85.47 decays/s]
# Processing:  94%|█████████▎| 1404/1500 [00:17<00:00, 97.63 decays/s]
# Processing:  94%|█████████▍| 1414/1500 [00:17<00:00, 91.98 decays/s]
# Processing:  95%|█████████▍| 1424/1500 [00:17<00:00, 83.42 decays/s]
# Processing:  96%|█████████▌| 1433/1500 [00:17<00:00, 82.29 decays/s]
# Processing:  96%|█████████▌| 1442/1500 [00:17<00:00, 82.51 decays/s]
# Processing:  97%|█████████▋| 1451/1500 [00:17<00:00, 78.33 decays/s]
# Processing:  97%|█████████▋| 1459/1500 [00:17<00:00, 78.16 decays/s]
# Processing:  98%|█████████▊| 1472/1500 [00:17<00:00, 88.68 decays/s]
# Processing:  99%|█████████▊| 1481/1500 [00:17<00:00, 86.03 decays/s]
# Processing:  99%|█████████▉| 1490/1500 [00:18<00:00, 74.16 decays/s]
# Processing: 100%|██████████| 1500/1500 [00:18<00:00, 82.34 decays/s]

# %% [markdown]
# ## Read initial energy from the decay process

# %%
temp1, temp2, temp3, temp4 = td.TDCR_model_lib.read_temp_files()

ee_vec, eg_vec, ep_vec, ea_vec = td.TDCR_model_lib.energyVectors1(temp1)
nbins=50
plt.figure("1")
plt.hist(eg_vec, bins=nbins, edgecolor='none',density=True,label='photons')
plt.hist(ee_vec, bins=nbins, edgecolor='none',density=True,label='electrons')
plt.hist(ep_vec, bins=nbins, edgecolor='none',density=True,label='positrons')
plt.hist(ea_vec, bins=nbins, edgecolor='none',density=True,label='alphas')
plt.title('Distribution of Initial Energies')
plt.xlabel('Energy /keV')
plt.ylabel('Frequency')
plt.legend()
plt.show()
# Out:
# g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages\numpy\lib\_histograms_impl.py:897: RuntimeWarning: invalid value encountered in divide
#   return n / db / n.sum(), bin_edges

# %% [markdown]
# ## Read deposited energy in the scintillator

# %%
ee_vec, ep_vec, ea_vec = td.TDCR_model_lib.energyVectors2(temp2)
nbins=50
plt.figure("2")
plt.hist(ee_vec, bins=nbins, edgecolor='none',density=True,label='electrons')
plt.hist(ep_vec, bins=nbins, edgecolor='none',density=True,label='positrons')
plt.hist(ea_vec, bins=nbins, edgecolor='none',density=True,label='alphas')
plt.title('Distribution of Deposited Energies')
plt.xlabel('Energy /keV')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %% [markdown]
# ## Read quenched deposited energy in the scintillator

# %%
ee_vec = td.TDCR_model_lib.energyVectors3(temp3)
nbins=50
plt.figure("3")
plt.hist(ee_vec, bins=nbins, edgecolor='none',density=True,label='electrons')
plt.title('Distribution of Quenched Deposited Energies')
plt.xlabel('Energy /keV')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %% [markdown]
# ## Read detection probabilities per decay event

# %%
s_vec, d_vec, t_vec = td.TDCR_model_lib.effVector(temp4)
nbins=50
plt.figure("4")
plt.hist(s_vec, bins=nbins, edgecolor='none',density=True,label='single events')
plt.hist(d_vec, bins=nbins, edgecolor='none',density=True,label='double coincidences')
plt.hist(t_vec, bins=nbins, edgecolor='none',density=True,label='triple coincidences')
plt.title('Distribution of detection probabilities per decay event')
plt.xlabel('Detection probability')
plt.ylabel('Frequency')
plt.legend()
plt.show()
