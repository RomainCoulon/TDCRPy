# %% [markdown]
# # Efficiency curves using TDCRPy

# %%
pip install TDCRPy==2.20.12
# Out:
# Requirement already satisfied: TDCRPy==2.20.10 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (2.20.10)
# Requirement already satisfied: numpy in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.10) (2.4.6)
# Requirement already satisfied: scipy in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.10) (1.18.0)
# Requirement already satisfied: matplotlib in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.10) (3.11.0)
# Requirement already satisfied: tqdm in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.10) (4.68.3)
# Requirement already satisfied: numba in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.10) (0.65.1)
# Requirement already satisfied: setuptools in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.10) (82.0.1)
# Requirement already satisfied: contourpy>=1.0.1 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.10) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.10) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.10) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.10) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.10) (26.2)
# Requirement already satisfied: pillow>=9 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.10) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.10) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.10) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from python-dateutil>=2.7->matplotlib->TDCRPy==2.20.10) (1.17.0)
# Requirement already satisfied: llvmlite<0.48,>=0.47.0dev0 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from numba->TDCRPy==2.20.10) (0.47.0)
# Requirement already satisfied: colorama in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from tqdm->TDCRPy==2.20.10) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import tdcrpy as td
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt

# %%
mode = "eff"                # ask for efficiency calculation
Rad="Co-60"                 # radionuclides
pmf_1="1"                   # relatives fractions of the radionulides
N = 1000                     # number of Monte Carlo trials
kB =1.0e-5                  # Birks constant in cm keV-1
V = 10                      # volume of scintillator in mL
L=np.logspace(-3,2,num=100) # free parameter in keV-1

# Record decay histories in temporary files
td.TDCRPy.TDCRPy(L[0], Rad, pmf_1, N, kB, V, mode, barp=True, record=True)

effS, u_effS, effD, u_effD, effT, u_effT, effD2, u_effD2 = [], [],[], [],[], [], [], []
for l in tqdm(L, desc="free parameters ", unit=" iterations"):
  out = td.TDCRPy.TDCRPy(l, Rad, pmf_1, N, kB, V, mode, readRecHist=True)
  effS.append(out[2])
  u_effS.append(out[3])
  effD.append(out[2])
  u_effD.append(out[3])
  effT.append(out[4])
  u_effT.append(out[5])
  effD2.append(out[12])
  u_effD2.append(out[13])
# Out:
#  ______  ______  ______ _______  ________
# |__  __||  ___ \|  ___||  ___ | |  ____ |
#   | |   | |  | || |    | |  | | | |___| |___     ___
#   | |   | |  | || |    | |__| | |  _____|\  \   |  |
#   | |   | |__| || |____|  __  \ | |       \  \  |  |
#   |_|   |_____/ |_____||_|  \__\|_|        \  \_|  |
#   +++++++++++++++++++++++++++++++++++++++++/      /
#   ________________________________________/      /
#  |______________________________________________/
#
#
# version 2.20.10
# BIPM 2023 - license MIT
# distribution: https://pypi.org/project/TDCRPy
# developement: https://github.com/RomainCoulon/TDCRPy
#
# start calculation...
# Processing:   0%|          | 0/1000 [00:00<?, ? decays/s]
# Processing:   1%|          | 8/1000 [00:00<00:13, 75.24 decays/s]
# Processing:   2%|▏         | 16/1000 [00:00<00:12, 75.94 decays/s]
# Processing:   2%|▏         | 24/1000 [00:00<00:12, 76.89 decays/s]
# Processing:   3%|▎         | 32/1000 [00:00<00:12, 74.58 decays/s]
# Processing:   4%|▍         | 40/1000 [00:00<00:12, 75.50 decays/s]
# Processing:   5%|▍         | 48/1000 [00:00<00:12, 74.55 decays/s]
# Processing:   6%|▌         | 56/1000 [00:00<00:12, 74.25 decays/s]
# Processing:   6%|▋         | 64/1000 [00:00<00:12, 73.46 decays/s]
# Processing:   7%|▋         | 72/1000 [00:00<00:12, 73.16 decays/s]
# Processing:   8%|▊         | 80/1000 [00:01<00:12, 72.01 decays/s]
# Processing:   9%|▉         | 88/1000 [00:01<00:12, 72.09 decays/s]
# Processing:  10%|▉         | 96/1000 [00:01<00:12, 73.18 decays/s]
# Processing:  10%|█         | 104/1000 [00:01<00:12, 74.50 decays/s]
# Processing:  11%|█         | 112/1000 [00:01<00:11, 75.46 decays/s]
# Processing:  12%|█▏        | 120/1000 [00:01<00:11, 75.98 decays/s]
# Processing:  13%|█▎        | 128/1000 [00:01<00:11, 76.26 decays/s]
# Processing:  14%|█▎        | 136/1000 [00:01<00:11, 74.59 decays/s]
# Processing:  14%|█▍        | 144/1000 [00:01<00:11, 75.48 decays/s]
# Processing:  15%|█▌        | 152/1000 [00:02<00:11, 76.39 decays/s]
# Processing:  16%|█▌        | 160/1000 [00:02<00:10, 77.05 decays/s]
# Processing:  17%|█▋        | 168/1000 [00:02<00:10, 77.11 decays/s]
# Processing:  18%|█▊        | 176/1000 [00:02<00:10, 77.09 decays/s]
# Processing:  18%|█▊        | 184/1000 [00:02<00:10, 77.35 decays/s]
# Processing:  19%|█▉        | 192/1000 [00:02<00:10, 76.10 decays/s]
# Processing:  20%|██        | 200/1000 [00:02<00:10, 76.18 decays/s]
# Processing:  21%|██        | 208/1000 [00:02<00:10, 76.36 decays/s]
# Processing:  22%|██▏       | 216/1000 [00:02<00:10, 76.48 decays/s]
# Processing:  22%|██▏       | 224/1000 [00:02<00:10, 76.62 decays/s]
# Processing:  23%|██▎       | 232/1000 [00:03<00:10, 76.63 decays/s]
# Processing:  24%|██▍       | 240/1000 [00:03<00:10, 74.79 decays/s]
# Processing:  25%|██▍       | 248/1000 [00:03<00:10, 75.13 decays/s]
# Processing:  26%|██▌       | 256/1000 [00:03<00:09, 75.57 decays/s]
# Processing:  26%|██▋       | 264/1000 [00:03<00:09, 76.02 decays/s]
# Processing:  27%|██▋       | 272/1000 [00:03<00:09, 76.80 decays/s]
# Processing:  28%|██▊       | 280/1000 [00:03<00:09, 76.86 decays/s]
# Processing:  29%|██▉       | 288/1000 [00:03<00:09, 77.03 decays/s]
# Processing:  30%|██▉       | 296/1000 [00:03<00:09, 76.96 decays/s]
# Processing:  30%|███       | 304/1000 [00:04<00:09, 76.93 decays/s]
# Processing:  31%|███       | 312/1000 [00:04<00:08, 77.14 decays/s]
# Processing:  32%|███▏      | 320/1000 [00:04<00:10, 67.63 decays/s]
# Processing:  33%|███▎      | 328/1000 [00:04<00:09, 70.85 decays/s]
# Processing:  34%|███▎      | 336/1000 [00:04<00:09, 70.14 decays/s]
# Processing:  34%|███▍      | 344/1000 [00:04<00:09, 71.08 decays/s]
# Processing:  35%|███▌      | 352/1000 [00:04<00:08, 73.23 decays/s]
# Processing:  36%|███▌      | 361/1000 [00:04<00:08, 75.36 decays/s]
# Processing:  37%|███▋      | 370/1000 [00:04<00:08, 76.80 decays/s]
# Processing:  38%|███▊      | 378/1000 [00:05<00:08, 77.57 decays/s]
# Processing:  39%|███▊      | 386/1000 [00:05<00:07, 78.23 decays/s]
# Processing:  39%|███▉      | 394/1000 [00:05<00:07, 77.64 decays/s]
# Processing:  40%|████      | 402/1000 [00:05<00:07, 78.13 decays/s]
# Processing:  41%|████      | 410/1000 [00:05<00:07, 78.25 decays/s]
# Processing:  42%|████▏     | 419/1000 [00:05<00:07, 80.21 decays/s]
# Processing:  43%|████▎     | 428/1000 [00:05<00:07, 80.15 decays/s]
# Processing:  44%|████▎     | 437/1000 [00:05<00:07, 80.11 decays/s]
# Processing:  45%|████▍     | 446/1000 [00:05<00:06, 80.05 decays/s]
# Processing:  46%|████▌     | 455/1000 [00:05<00:06, 79.20 decays/s]
# Processing:  46%|████▋     | 463/1000 [00:06<00:06, 78.47 decays/s]
# Processing:  47%|████▋     | 471/1000 [00:06<00:06, 78.13 decays/s]
# Processing:  48%|████▊     | 479/1000 [00:06<00:06, 77.87 decays/s]
# Processing:  49%|████▊     | 487/1000 [00:06<00:06, 77.56 decays/s]
# Processing:  50%|████▉     | 495/1000 [00:06<00:06, 76.78 decays/s]
# Processing:  50%|█████     | 503/1000 [00:06<00:07, 66.92 decays/s]
# Processing:  51%|█████     | 510/1000 [00:06<00:07, 65.63 decays/s]
# Processing:  52%|█████▏    | 518/1000 [00:06<00:07, 68.32 decays/s]
# Processing:  53%|█████▎    | 526/1000 [00:06<00:06, 70.12 decays/s]
# Processing:  53%|█████▎    | 534/1000 [00:07<00:06, 70.49 decays/s]
# Processing:  54%|█████▍    | 542/1000 [00:07<00:06, 69.45 decays/s]
# Processing:  55%|█████▌    | 550/1000 [00:07<00:06, 71.61 decays/s]
# Processing:  56%|█████▌    | 558/1000 [00:07<00:06, 70.13 decays/s]
# Processing:  57%|█████▋    | 566/1000 [00:07<00:06, 72.16 decays/s]
# Processing:  57%|█████▋    | 574/1000 [00:07<00:05, 73.51 decays/s]
# Processing:  58%|█████▊    | 582/1000 [00:07<00:05, 74.62 decays/s]
# Processing:  59%|█████▉    | 590/1000 [00:07<00:05, 75.17 decays/s]
# Processing:  60%|█████▉    | 598/1000 [00:07<00:05, 75.57 decays/s]
# Processing:  61%|██████    | 606/1000 [00:08<00:05, 75.85 decays/s]
# Processing:  61%|██████▏   | 614/1000 [00:08<00:05, 76.36 decays/s]
# Processing:  62%|██████▏   | 622/1000 [00:08<00:04, 76.49 decays/s]
# Processing:  63%|██████▎   | 630/1000 [00:08<00:04, 76.77 decays/s]
# Processing:  64%|██████▍   | 638/1000 [00:08<00:04, 76.74 decays/s]
# Processing:  65%|██████▍   | 646/1000 [00:08<00:04, 75.98 decays/s]
# Processing:  65%|██████▌   | 654/1000 [00:08<00:04, 76.41 decays/s]
# Processing:  66%|██████▌   | 662/1000 [00:08<00:04, 76.69 decays/s]
# Processing:  67%|██████▋   | 670/1000 [00:08<00:04, 77.01 decays/s]
# Processing:  68%|██████▊   | 678/1000 [00:09<00:04, 76.91 decays/s]
# Processing:  69%|██████▊   | 686/1000 [00:09<00:04, 77.66 decays/s]
# Processing:  69%|██████▉   | 694/1000 [00:09<00:03, 77.43 decays/s]
# Processing:  70%|███████   | 702/1000 [00:09<00:03, 77.98 decays/s]
# Processing:  71%|███████   | 710/1000 [00:09<00:03, 78.14 decays/s]
# Processing:  72%|███████▏  | 718/1000 [00:09<00:03, 73.19 decays/s]
# Processing:  73%|███████▎  | 726/1000 [00:09<00:03, 73.13 decays/s]
# Processing:  73%|███████▎  | 734/1000 [00:09<00:03, 72.60 decays/s]
# Processing:  74%|███████▍  | 742/1000 [00:09<00:03, 72.44 decays/s]
# Processing:  75%|███████▌  | 750/1000 [00:09<00:03, 70.89 decays/s]
# Processing:  76%|███████▌  | 758/1000 [00:10<00:03, 72.58 decays/s]
# Processing:  77%|███████▋  | 766/1000 [00:10<00:03, 73.87 decays/s]
# Processing:  77%|███████▋  | 774/1000 [00:10<00:03, 74.89 decays/s]
# Processing:  78%|███████▊  | 782/1000 [00:10<00:02, 75.68 decays/s]
# Processing:  79%|███████▉  | 790/1000 [00:10<00:02, 74.98 decays/s]
# Processing:  80%|███████▉  | 798/1000 [00:10<00:02, 75.67 decays/s]
# Processing:  81%|████████  | 806/1000 [00:10<00:02, 73.91 decays/s]
# Processing:  81%|████████▏ | 814/1000 [00:10<00:02, 74.03 decays/s]
# Processing:  82%|████████▏ | 822/1000 [00:10<00:02, 75.16 decays/s]
# Processing:  83%|████████▎ | 830/1000 [00:11<00:02, 75.66 decays/s]
# Processing:  84%|████████▍ | 838/1000 [00:11<00:02, 76.15 decays/s]
# Processing:  85%|████████▍ | 846/1000 [00:11<00:02, 76.62 decays/s]
# Processing:  85%|████████▌ | 854/1000 [00:11<00:01, 75.91 decays/s]
# Processing:  86%|████████▌ | 862/1000 [00:11<00:01, 76.31 decays/s]
# Processing:  87%|████████▋ | 870/1000 [00:11<00:01, 77.30 decays/s]
# Processing:  88%|████████▊ | 878/1000 [00:11<00:01, 76.98 decays/s]
# Processing:  89%|████████▊ | 886/1000 [00:11<00:01, 77.04 decays/s]
# Processing:  89%|████████▉ | 894/1000 [00:11<00:01, 77.75 decays/s]
# Processing:  90%|█████████ | 902/1000 [00:11<00:01, 77.84 decays/s]
# Processing:  91%|█████████ | 910/1000 [00:12<00:01, 74.41 decays/s]
# Processing:  92%|█████████▏| 918/1000 [00:12<00:01, 74.61 decays/s]
# Processing:  93%|█████████▎| 926/1000 [00:12<00:01, 71.17 decays/s]
# Processing:  93%|█████████▎| 934/1000 [00:12<00:00, 72.38 decays/s]
# Processing:  94%|█████████▍| 942/1000 [00:12<00:00, 73.26 decays/s]
# Processing:  95%|█████████▌| 950/1000 [00:12<00:00, 71.68 decays/s]
# Processing:  96%|█████████▌| 958/1000 [00:12<00:00, 72.77 decays/s]
# Processing:  97%|█████████▋| 966/1000 [00:12<00:00, 73.68 decays/s]
# Processing:  97%|█████████▋| 974/1000 [00:12<00:00, 74.30 decays/s]
# Processing:  98%|█████████▊| 982/1000 [00:13<00:00, 74.64 decays/s]
# Processing:  99%|█████████▉| 990/1000 [00:13<00:00, 74.62 decays/s]
# Processing: 100%|█████████▉| 998/1000 [00:13<00:00, 74.35 decays/s]
# Processing: 100%|██████████| 1000/1000 [00:13<00:00, 75.03 decays/s]
# free parameters :   0%|          | 0/100 [00:00<?, ? iterations/s]
# free parameters :  10%|█         | 10/100 [00:00<00:00, 93.11 iterations/s]
# free parameters :  20%|██        | 20/100 [00:00<00:02, 39.78 iterations/s]
# free parameters :  30%|███       | 30/100 [00:00<00:01, 54.76 iterations/s]
# free parameters :  39%|███▉      | 39/100 [00:00<00:00, 63.58 iterations/s]
# free parameters :  49%|████▉     | 49/100 [00:00<00:00, 73.37 iterations/s]
# free parameters :  58%|█████▊    | 58/100 [00:00<00:00, 65.45 iterations/s]
# free parameters :  66%|██████▌   | 66/100 [00:01<00:00, 42.49 iterations/s]
# free parameters :  75%|███████▌  | 75/100 [00:01<00:00, 50.29 iterations/s]
# free parameters :  85%|████████▌ | 85/100 [00:01<00:00, 59.23 iterations/s]
# free parameters :  95%|█████████▌| 95/100 [00:01<00:00, 67.88 iterations/s]
# free parameters : 100%|██████████| 100/100 [00:01<00:00, 60.26 iterations/s]

# %%
effS=np.asarray(effS)
effT=np.asarray(effT)
effD=np.asarray(effD)
effD2=np.asarray(effD2)
u_effS=np.asarray(u_effS)
u_effT=np.asarray(u_effT)
u_effD=np.asarray(u_effD)
u_effD2=np.asarray(u_effD2)

tdcr=effT/effD
u_tdcr=np.sqrt(u_effD**2*effT**2/effD**4+u_effT**2/effD**2)

plt.figure("efficiency vs free parameter")
plt.clf()
plt.errorbar(L,effD,yerr=u_effD,fmt="-k",label="double coincidences")
plt.errorbar(L,effT,yerr=u_effT,fmt="-r",label="triple coincidences")
plt.errorbar(L,effD2,yerr=u_effD2,fmt="-g",label="double coincidences (CIEMAT/NIST)")
plt.xscale('log')
plt.xlabel(r'$L$ /keV$^{-1}$', fontsize=14)
plt.ylabel(r'$\epsilon$', fontsize=14)
plt.legend()

plt.figure("efficiency vs TDCR")
plt.clf()
plt.errorbar(tdcr,effD,xerr=u_tdcr,yerr=u_effD,fmt="-k")
#plt.xscale('log')
plt.xlabel(r'$R_T/R_D$', fontsize=14)
plt.ylabel(r'$\epsilon_{D}$', fontsize=14)
# Out:
# Text(0, 0.5, '$\\epsilon_{D}$')
