# %% [markdown]
# # Efficiency curves using TDCRPy

# %%
pip install TDCRPy==2.20.7
# Out:
# Requirement already satisfied: TDCRPy==2.20.7 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (2.20.7)
# Requirement already satisfied: numpy in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.7) (2.4.6)
# Requirement already satisfied: scipy in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.7) (1.18.0)
# Requirement already satisfied: matplotlib in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.7) (3.11.0)
# Requirement already satisfied: tqdm in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.7) (4.68.3)
# Requirement already satisfied: numba in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.7) (0.65.1)
# Requirement already satisfied: setuptools in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.7) (82.0.1)
# Requirement already satisfied: contourpy>=1.0.1 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.7) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.7) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.7) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.7) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.7) (26.2)
# Requirement already satisfied: pillow>=9 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.7) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.7) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.7) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from python-dateutil>=2.7->matplotlib->TDCRPy==2.20.7) (1.17.0)
# Requirement already satisfied: llvmlite<0.48,>=0.47.0dev0 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from numba->TDCRPy==2.20.7) (0.47.0)
# Requirement already satisfied: colorama in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from tqdm->TDCRPy==2.20.7) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import tdcrpy as td
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt

# %%
mode = "eff"                # ask for efficiency calculation
Rad="Co-60"                 # radionuclides
pmf_1="1"                   # relatives fractions of the radionulides
N = 1000                     # number of Monte Carlo trials
kB =1.0e-5                  # Birks constant in cm keV-1
V = 10                      # volume of scintillator in mL
L=np.logspace(-3,2,num=100) # free parameter in keV-1

# Record decay histories in temporary files
td.TDCRPy.TDCRPy(L[0], Rad, pmf_1, N, kB, V, mode, barp=True, record=True)

effS, u_effS, effD, u_effD, effT, u_effT, effD2, u_effD2 = [], [],[], [],[], [], [], []
for l in tqdm(L, desc="free parameters ", unit=" iterations"):
  out = td.TDCRPy.TDCRPy(l, Rad, pmf_1, N, kB, V, mode, readRecHist=True)
  effS.append(out[2])
  u_effS.append(out[3])
  effD.append(out[2])
  u_effD.append(out[3])
  effT.append(out[4])
  u_effT.append(out[5])
  effD2.append(out[12])
  u_effD2.append(out[13])
# Out:
#  ______  ______  ______ _______  ________
# |__  __||  ___ \|  ___||  ___ | |  ____ |
#   | |   | |  | || |    | |  | | | |___| |___     ___
#   | |   | |  | || |    | |__| | |  _____|\  \   |  |
#   | |   | |__| || |____|  __  \ | |       \  \  |  |
#   |_|   |_____/ |_____||_|  \__\|_|        \  \_|  |
#   +++++++++++++++++++++++++++++++++++++++++/      /
#   ________________________________________/      /
#  |______________________________________________/
#
#
# version 2.20.7
# BIPM 2023 - license MIT
# distribution: https://pypi.org/project/TDCRPy
# developement: https://github.com/RomainCoulon/TDCRPy
#
# start calculation...
# Processing:   0%|          | 0/1000 [00:00<?, ? decays/s]
# Processing:   1%|          | 8/1000 [00:00<00:12, 78.22 decays/s]
# Processing:   2%|▏         | 16/1000 [00:00<00:12, 77.75 decays/s]
# Processing:   2%|▏         | 24/1000 [00:00<00:12, 78.41 decays/s]
# Processing:   3%|▎         | 32/1000 [00:00<00:12, 78.32 decays/s]
# Processing:   4%|▍         | 40/1000 [00:00<00:12, 77.48 decays/s]
# Processing:   5%|▍         | 48/1000 [00:00<00:12, 77.84 decays/s]
# Processing:   6%|▌         | 56/1000 [00:00<00:12, 77.41 decays/s]
# Processing:   6%|▋         | 64/1000 [00:00<00:12, 77.92 decays/s]
# Processing:   7%|▋         | 72/1000 [00:00<00:11, 78.23 decays/s]
# Processing:   8%|▊         | 80/1000 [00:01<00:11, 78.01 decays/s]
# Processing:   9%|▉         | 88/1000 [00:01<00:11, 77.79 decays/s]
# Processing:  10%|▉         | 96/1000 [00:01<00:11, 76.99 decays/s]
# Processing:  10%|█         | 104/1000 [00:01<00:11, 77.11 decays/s]
# Processing:  11%|█         | 112/1000 [00:01<00:11, 77.44 decays/s]
# Processing:  12%|█▏        | 120/1000 [00:01<00:11, 77.76 decays/s]
# Processing:  13%|█▎        | 128/1000 [00:01<00:11, 76.09 decays/s]
# Processing:  14%|█▎        | 136/1000 [00:01<00:11, 77.09 decays/s]
# Processing:  14%|█▍        | 144/1000 [00:01<00:11, 77.78 decays/s]
# Processing:  15%|█▌        | 152/1000 [00:01<00:10, 77.58 decays/s]
# Processing:  16%|█▌        | 160/1000 [00:02<00:10, 77.41 decays/s]
# Processing:  17%|█▋        | 168/1000 [00:02<00:10, 77.78 decays/s]
# Processing:  18%|█▊        | 176/1000 [00:02<00:10, 78.11 decays/s]
# Processing:  18%|█▊        | 184/1000 [00:02<00:10, 78.13 decays/s]
# Processing:  19%|█▉        | 192/1000 [00:02<00:10, 78.30 decays/s]
# Processing:  20%|██        | 200/1000 [00:02<00:10, 76.54 decays/s]
# Processing:  21%|██        | 208/1000 [00:02<00:10, 77.33 decays/s]
# Processing:  22%|██▏       | 216/1000 [00:02<00:10, 77.72 decays/s]
# Processing:  22%|██▏       | 224/1000 [00:02<00:09, 78.02 decays/s]
# Processing:  23%|██▎       | 232/1000 [00:02<00:09, 78.49 decays/s]
# Processing:  24%|██▍       | 240/1000 [00:03<00:09, 78.63 decays/s]
# Processing:  25%|██▍       | 248/1000 [00:03<00:09, 78.76 decays/s]
# Processing:  26%|██▌       | 256/1000 [00:03<00:09, 78.84 decays/s]
# Processing:  26%|██▋       | 264/1000 [00:03<00:09, 77.99 decays/s]
# Processing:  27%|██▋       | 272/1000 [00:03<00:09, 77.99 decays/s]
# Processing:  28%|██▊       | 280/1000 [00:03<00:09, 78.11 decays/s]
# Processing:  29%|██▉       | 288/1000 [00:03<00:09, 78.40 decays/s]
# Processing:  30%|██▉       | 296/1000 [00:03<00:09, 75.80 decays/s]
# Processing:  30%|███       | 304/1000 [00:03<00:09, 76.39 decays/s]
# Processing:  31%|███       | 312/1000 [00:04<00:08, 77.22 decays/s]
# Processing:  32%|███▏      | 320/1000 [00:04<00:08, 77.84 decays/s]
# Processing:  33%|███▎      | 328/1000 [00:04<00:08, 77.74 decays/s]
# Processing:  34%|███▎      | 336/1000 [00:04<00:08, 77.71 decays/s]
# Processing:  34%|███▍      | 344/1000 [00:04<00:08, 77.93 decays/s]
# Processing:  35%|███▌      | 352/1000 [00:04<00:08, 77.21 decays/s]
# Processing:  36%|███▌      | 360/1000 [00:04<00:08, 77.55 decays/s]
# Processing:  37%|███▋      | 368/1000 [00:04<00:08, 78.19 decays/s]
# Processing:  38%|███▊      | 376/1000 [00:04<00:07, 78.30 decays/s]
# Processing:  38%|███▊      | 384/1000 [00:04<00:07, 78.58 decays/s]
# Processing:  39%|███▉      | 392/1000 [00:05<00:07, 78.65 decays/s]
# Processing:  40%|████      | 400/1000 [00:05<00:07, 78.47 decays/s]
# Processing:  41%|████      | 408/1000 [00:05<00:07, 75.23 decays/s]
# Processing:  42%|████▏     | 416/1000 [00:05<00:07, 76.27 decays/s]
# Processing:  42%|████▏     | 424/1000 [00:05<00:07, 76.69 decays/s]
# Processing:  43%|████▎     | 432/1000 [00:05<00:07, 76.82 decays/s]
# Processing:  44%|████▍     | 440/1000 [00:05<00:07, 77.16 decays/s]
# Processing:  45%|████▍     | 448/1000 [00:05<00:07, 77.75 decays/s]
# Processing:  46%|████▌     | 456/1000 [00:05<00:06, 78.20 decays/s]
# Processing:  46%|████▋     | 464/1000 [00:05<00:06, 78.20 decays/s]
# Processing:  47%|████▋     | 472/1000 [00:06<00:06, 78.63 decays/s]
# Processing:  48%|████▊     | 480/1000 [00:06<00:06, 78.90 decays/s]
# Processing:  49%|████▉     | 488/1000 [00:06<00:06, 78.84 decays/s]
# Processing:  50%|████▉     | 496/1000 [00:06<00:06, 78.26 decays/s]
# Processing:  50%|█████     | 504/1000 [00:06<00:06, 78.68 decays/s]
# Processing:  51%|█████     | 512/1000 [00:06<00:06, 78.84 decays/s]
# Processing:  52%|█████▏    | 520/1000 [00:06<00:06, 75.94 decays/s]
# Processing:  53%|█████▎    | 528/1000 [00:06<00:06, 76.86 decays/s]
# Processing:  54%|█████▎    | 536/1000 [00:06<00:06, 76.88 decays/s]
# Processing:  54%|█████▍    | 544/1000 [00:07<00:05, 77.55 decays/s]
# Processing:  55%|█████▌    | 552/1000 [00:07<00:05, 78.00 decays/s]
# Processing:  56%|█████▌    | 560/1000 [00:07<00:05, 76.45 decays/s]
# Processing:  57%|█████▋    | 568/1000 [00:07<00:05, 76.10 decays/s]
# Processing:  58%|█████▊    | 576/1000 [00:07<00:05, 77.03 decays/s]
# Processing:  58%|█████▊    | 584/1000 [00:07<00:05, 77.30 decays/s]
# Processing:  59%|█████▉    | 592/1000 [00:07<00:05, 77.61 decays/s]
# Processing:  60%|██████    | 600/1000 [00:07<00:05, 78.11 decays/s]
# Processing:  61%|██████    | 608/1000 [00:07<00:05, 78.32 decays/s]
# Processing:  62%|██████▏   | 616/1000 [00:07<00:04, 78.41 decays/s]
# Processing:  62%|██████▏   | 624/1000 [00:08<00:04, 76.12 decays/s]
# Processing:  63%|██████▎   | 632/1000 [00:08<00:04, 77.07 decays/s]
# Processing:  64%|██████▍   | 640/1000 [00:08<00:04, 77.60 decays/s]
# Processing:  65%|██████▍   | 648/1000 [00:08<00:04, 77.89 decays/s]
# Processing:  66%|██████▌   | 656/1000 [00:08<00:04, 78.44 decays/s]
# Processing:  66%|██████▋   | 664/1000 [00:08<00:04, 78.64 decays/s]
# Processing:  67%|██████▋   | 672/1000 [00:08<00:04, 77.50 decays/s]
# Processing:  68%|██████▊   | 680/1000 [00:08<00:04, 77.87 decays/s]
# Processing:  69%|██████▉   | 688/1000 [00:08<00:04, 77.82 decays/s]
# Processing:  70%|██████▉   | 696/1000 [00:08<00:03, 78.17 decays/s]
# Processing:  70%|███████   | 704/1000 [00:09<00:03, 78.52 decays/s]
# Processing:  71%|███████   | 712/1000 [00:09<00:03, 78.27 decays/s]
# Processing:  72%|███████▏  | 720/1000 [00:09<00:03, 77.32 decays/s]
# Processing:  73%|███████▎  | 728/1000 [00:09<00:03, 74.21 decays/s]
# Processing:  74%|███████▎  | 736/1000 [00:09<00:03, 75.57 decays/s]
# Processing:  74%|███████▍  | 744/1000 [00:09<00:03, 76.44 decays/s]
# Processing:  75%|███████▌  | 752/1000 [00:09<00:03, 77.25 decays/s]
# Processing:  76%|███████▌  | 760/1000 [00:09<00:03, 76.61 decays/s]
# Processing:  77%|███████▋  | 768/1000 [00:09<00:02, 77.48 decays/s]
# Processing:  78%|███████▊  | 776/1000 [00:09<00:02, 77.81 decays/s]
# Processing:  78%|███████▊  | 784/1000 [00:10<00:02, 78.04 decays/s]
# Processing:  79%|███████▉  | 792/1000 [00:10<00:02, 78.48 decays/s]
# Processing:  80%|████████  | 800/1000 [00:10<00:02, 78.75 decays/s]
# Processing:  81%|████████  | 808/1000 [00:10<00:02, 78.92 decays/s]
# Processing:  82%|████████▏ | 816/1000 [00:10<00:02, 78.83 decays/s]
# Processing:  82%|████████▏ | 824/1000 [00:10<00:02, 78.79 decays/s]
# Processing:  83%|████████▎ | 832/1000 [00:10<00:02, 75.17 decays/s]
# Processing:  84%|████████▍ | 840/1000 [00:10<00:02, 76.14 decays/s]
# Processing:  85%|████████▍ | 848/1000 [00:10<00:01, 76.54 decays/s]
# Processing:  86%|████████▌ | 856/1000 [00:11<00:01, 76.99 decays/s]
# Processing:  86%|████████▋ | 864/1000 [00:11<00:01, 77.64 decays/s]
# Processing:  87%|████████▋ | 872/1000 [00:11<00:01, 77.93 decays/s]
# Processing:  88%|████████▊ | 880/1000 [00:11<00:01, 78.38 decays/s]
# Processing:  89%|████████▉ | 888/1000 [00:11<00:01, 78.74 decays/s]
# Processing:  90%|████████▉ | 897/1000 [00:11<00:01, 80.29 decays/s]
# Processing:  91%|█████████ | 906/1000 [00:11<00:01, 80.06 decays/s]
# Processing:  92%|█████████▏| 915/1000 [00:11<00:01, 79.63 decays/s]
# Processing:  92%|█████████▏| 923/1000 [00:11<00:00, 79.45 decays/s]
# Processing:  93%|█████████▎| 931/1000 [00:11<00:00, 79.35 decays/s]
# Processing:  94%|█████████▍| 939/1000 [00:12<00:00, 77.19 decays/s]
# Processing:  95%|█████████▍| 947/1000 [00:12<00:00, 77.64 decays/s]
# Processing:  96%|█████████▌| 955/1000 [00:12<00:00, 76.69 decays/s]
# Processing:  96%|█████████▋| 963/1000 [00:12<00:00, 77.13 decays/s]
# Processing:  97%|█████████▋| 971/1000 [00:12<00:00, 77.81 decays/s]
# Processing:  98%|█████████▊| 979/1000 [00:12<00:00, 78.03 decays/s]
# Processing:  99%|█████████▊| 987/1000 [00:12<00:00, 76.87 decays/s]
# Processing: 100%|█████████▉| 995/1000 [00:12<00:00, 77.27 decays/s]
# Processing: 100%|██████████| 1000/1000 [00:12<00:00, 77.69 decays/s]
# free parameters :   0%|          | 0/100 [00:00<?, ? iterations/s]
# free parameters :   9%|▉         | 9/100 [00:00<00:01, 85.20 iterations/s]
# free parameters :  18%|█▊        | 18/100 [00:00<00:00, 86.62 iterations/s]
# free parameters :  27%|██▋       | 27/100 [00:00<00:00, 86.27 iterations/s]
# free parameters :  36%|███▌      | 36/100 [00:00<00:00, 87.11 iterations/s]
# free parameters :  45%|████▌     | 45/100 [00:00<00:00, 86.18 iterations/s]
# free parameters :  54%|█████▍    | 54/100 [00:00<00:00, 87.20 iterations/s]
# free parameters :  63%|██████▎   | 63/100 [00:00<00:00, 87.52 iterations/s]
# free parameters :  72%|███████▏  | 72/100 [00:00<00:00, 87.54 iterations/s]
# free parameters :  81%|████████  | 81/100 [00:00<00:00, 88.03 iterations/s]
# free parameters :  90%|█████████ | 90/100 [00:01<00:00, 88.05 iterations/s]
# free parameters :  99%|█████████▉| 99/100 [00:01<00:00, 88.04 iterations/s]
# free parameters : 100%|██████████| 100/100 [00:01<00:00, 87.39 iterations/s]

# %%
effS=np.asarray(effS)
effT=np.asarray(effT)
effD=np.asarray(effD)
effD2=np.asarray(effD2)
u_effS=np.asarray(u_effS)
u_effT=np.asarray(u_effT)
u_effD=np.asarray(u_effD)
u_effD2=np.asarray(u_effD2)

tdcr=effT/effD
u_tdcr=np.sqrt(u_effD**2*effT**2/effD**4+u_effT**2/effD**2)

plt.figure("efficiency vs free parameter")
plt.clf()
plt.errorbar(L,effD,yerr=u_effD,fmt="-k",label="double coincidences")
plt.errorbar(L,effT,yerr=u_effT,fmt="-r",label="triple coincidences")
plt.errorbar(L,effD2,yerr=u_effD2,fmt="-g",label="double coincidences (CIEMAT/NIST)")
plt.xscale('log')
plt.xlabel(r'$L$ /keV$^{-1}$', fontsize=14)
plt.ylabel(r'$\epsilon$', fontsize=14)
plt.legend()

plt.figure("efficiency vs TDCR")
plt.clf()
plt.errorbar(tdcr,effD,xerr=u_tdcr,yerr=u_effD,fmt="-k")
#plt.xscale('log')
plt.xlabel(r'$R_T/R_D$', fontsize=14)
plt.ylabel(r'$\epsilon_{D}$', fontsize=14)
# Out:
# Text(0, 0.5, '$\\epsilon_{D}$')
