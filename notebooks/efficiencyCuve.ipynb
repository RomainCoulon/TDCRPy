# %% [markdown]
# # Efficiency curves using TDCRPy

# %%
pip install TDCRPy==2.20.5
# Out:
# Requirement already satisfied: TDCRPy==2.20.5 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (2.20.5)
# Requirement already satisfied: numpy in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.5) (2.4.6)
# Requirement already satisfied: scipy in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.5) (1.18.0)
# Requirement already satisfied: matplotlib in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.5) (3.11.0)
# Requirement already satisfied: tqdm in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.5) (4.68.3)
# Requirement already satisfied: numba in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.5) (0.65.1)
# Requirement already satisfied: setuptools in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.5) (82.0.1)
# Requirement already satisfied: contourpy>=1.0.1 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.5) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.5) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.5) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.5) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.5) (26.2)
# Requirement already satisfied: pillow>=9 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.5) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.5) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.5) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from python-dateutil>=2.7->matplotlib->TDCRPy==2.20.5) (1.17.0)
# Requirement already satisfied: llvmlite<0.48,>=0.47.0dev0 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from numba->TDCRPy==2.20.5) (0.47.0)
# Requirement already satisfied: colorama in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from tqdm->TDCRPy==2.20.5) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import tdcrpy as td
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt

# %%
mode = "eff"                # ask for efficiency calculation
Rad="Co-60"                 # radionuclides
pmf_1="1"                   # relatives fractions of the radionulides
N = 1000                     # number of Monte Carlo trials
kB =1.0e-5                  # Birks constant in cm keV-1
V = 10                      # volume of scintillator in mL
L=np.logspace(-3,2,num=100) # free parameter in keV-1

# Record decay histories in temporary files
td.TDCRPy.TDCRPy(L[0], Rad, pmf_1, N, kB, V, mode, barp=True, record=True)

effS, u_effS, effD, u_effD, effT, u_effT, effD2, u_effD2 = [], [],[], [],[], [], [], []
for l in tqdm(L, desc="free parameters ", unit=" iterations"):
  out = td.TDCRPy.TDCRPy(l, Rad, pmf_1, N, kB, V, mode, readRecHist=True)
  effS.append(out[2])
  u_effS.append(out[3])
  effD.append(out[2])
  u_effD.append(out[3])
  effT.append(out[4])
  u_effT.append(out[5])
  effD2.append(out[12])
  u_effD2.append(out[13])
# Out:
#  ______  ______  ______ _______  ________
# |__  __||  ___ \|  ___||  ___ | |  ____ |
#   | |   | |  | || |    | |  | | | |___| |___     ___
#   | |   | |  | || |    | |__| | |  _____|\  \   |  |
#   | |   | |__| || |____|  __  \ | |       \  \  |  |
#   |_|   |_____/ |_____||_|  \__\|_|        \  \_|  |
#   +++++++++++++++++++++++++++++++++++++++++/      /
#   ________________________________________/      /
#  |______________________________________________/
#
#
# version 2.20.5
# BIPM 2023 - license MIT
# distribution: https://pypi.org/project/TDCRPy
# developement: https://github.com/RomainCoulon/TDCRPy
#
# start calculation...
# Processing:   0%|          | 0/1000 [00:00<?, ? decays/s]
# Processing:   1%|          | 8/1000 [00:00<00:12, 77.80 decays/s]
# Processing:   2%|▏         | 17/1000 [00:00<00:12, 79.72 decays/s]
# Processing:   3%|▎         | 26/1000 [00:00<00:12, 80.05 decays/s]
# Processing:   4%|▎         | 35/1000 [00:00<00:12, 76.51 decays/s]
# Processing:   4%|▍         | 44/1000 [00:00<00:12, 77.99 decays/s]
# Processing:   5%|▌         | 52/1000 [00:00<00:12, 78.39 decays/s]
# Processing:   6%|▌         | 61/1000 [00:00<00:11, 79.11 decays/s]
# Processing:   7%|▋         | 70/1000 [00:00<00:11, 79.62 decays/s]
# Processing:   8%|▊         | 78/1000 [00:00<00:11, 79.55 decays/s]
# Processing:   9%|▊         | 87/1000 [00:01<00:11, 79.91 decays/s]
# Processing:  10%|▉         | 95/1000 [00:01<00:11, 78.73 decays/s]
# Processing:  10%|█         | 103/1000 [00:01<00:11, 77.34 decays/s]
# Processing:  11%|█         | 111/1000 [00:01<00:11, 77.83 decays/s]
# Processing:  12%|█▏        | 119/1000 [00:01<00:11, 77.92 decays/s]
# Processing:  13%|█▎        | 127/1000 [00:01<00:11, 78.50 decays/s]
# Processing:  14%|█▎        | 135/1000 [00:01<00:11, 78.37 decays/s]
# Processing:  14%|█▍        | 143/1000 [00:01<00:11, 75.03 decays/s]
# Processing:  15%|█▌        | 151/1000 [00:01<00:11, 76.25 decays/s]
# Processing:  16%|█▌        | 159/1000 [00:02<00:10, 77.28 decays/s]
# Processing:  17%|█▋        | 168/1000 [00:02<00:10, 78.36 decays/s]
# Processing:  18%|█▊        | 177/1000 [00:02<00:10, 78.91 decays/s]
# Processing:  19%|█▊        | 186/1000 [00:02<00:10, 79.34 decays/s]
# Processing:  19%|█▉        | 194/1000 [00:02<00:10, 76.39 decays/s]
# Processing:  20%|██        | 203/1000 [00:02<00:10, 77.55 decays/s]
# Processing:  21%|██        | 212/1000 [00:02<00:10, 78.42 decays/s]
# Processing:  22%|██▏       | 220/1000 [00:02<00:09, 78.72 decays/s]
# Processing:  23%|██▎       | 228/1000 [00:02<00:09, 78.84 decays/s]
# Processing:  24%|██▎       | 236/1000 [00:03<00:09, 79.06 decays/s]
# Processing:  24%|██▍       | 244/1000 [00:03<00:09, 79.16 decays/s]
# Processing:  25%|██▌       | 252/1000 [00:03<00:09, 77.73 decays/s]
# Processing:  26%|██▌       | 261/1000 [00:03<00:09, 78.48 decays/s]
# Processing:  27%|██▋       | 269/1000 [00:03<00:09, 78.69 decays/s]
# Processing:  28%|██▊       | 277/1000 [00:03<00:09, 78.30 decays/s]
# Processing:  28%|██▊       | 285/1000 [00:03<00:09, 78.49 decays/s]
# Processing:  29%|██▉       | 293/1000 [00:03<00:08, 78.74 decays/s]
# Processing:  30%|███       | 301/1000 [00:03<00:08, 77.89 decays/s]
# Processing:  31%|███       | 309/1000 [00:03<00:08, 78.44 decays/s]
# Processing:  32%|███▏      | 318/1000 [00:04<00:08, 78.72 decays/s]
# Processing:  33%|███▎      | 326/1000 [00:04<00:08, 78.95 decays/s]
# Processing:  34%|███▎      | 335/1000 [00:04<00:08, 79.39 decays/s]
# Processing:  34%|███▍      | 343/1000 [00:04<00:08, 79.55 decays/s]
# Processing:  35%|███▌      | 351/1000 [00:04<00:08, 79.61 decays/s]
# Processing:  36%|███▌      | 359/1000 [00:04<00:08, 76.95 decays/s]
# Processing:  37%|███▋      | 367/1000 [00:04<00:08, 77.70 decays/s]
# Processing:  38%|███▊      | 376/1000 [00:04<00:07, 78.55 decays/s]
# Processing:  38%|███▊      | 384/1000 [00:04<00:08, 76.21 decays/s]
# Processing:  39%|███▉      | 393/1000 [00:05<00:07, 77.50 decays/s]
# Processing:  40%|████      | 401/1000 [00:05<00:07, 78.07 decays/s]
# Processing:  41%|████      | 409/1000 [00:05<00:07, 77.29 decays/s]
# Processing:  42%|████▏     | 417/1000 [00:05<00:07, 76.98 decays/s]
# Processing:  43%|████▎     | 426/1000 [00:05<00:07, 78.09 decays/s]
# Processing:  43%|████▎     | 434/1000 [00:05<00:07, 75.42 decays/s]
# Processing:  44%|████▍     | 443/1000 [00:05<00:07, 76.92 decays/s]
# Processing:  45%|████▌     | 451/1000 [00:05<00:07, 77.72 decays/s]
# Processing:  46%|████▌     | 460/1000 [00:05<00:07, 75.74 decays/s]
# Processing:  47%|████▋     | 468/1000 [00:05<00:06, 76.66 decays/s]
# Processing:  48%|████▊     | 477/1000 [00:06<00:06, 77.68 decays/s]
# Processing:  48%|████▊     | 485/1000 [00:06<00:06, 77.05 decays/s]
# Processing:  49%|████▉     | 493/1000 [00:06<00:06, 77.78 decays/s]
# Processing:  50%|█████     | 502/1000 [00:06<00:06, 78.89 decays/s]
# Processing:  51%|█████     | 510/1000 [00:06<00:06, 79.18 decays/s]
# Processing:  52%|█████▏    | 518/1000 [00:06<00:06, 79.23 decays/s]
# Processing:  53%|█████▎    | 526/1000 [00:06<00:05, 79.28 decays/s]
# Processing:  54%|█████▎    | 535/1000 [00:06<00:05, 79.54 decays/s]
# Processing:  54%|█████▍    | 544/1000 [00:06<00:05, 79.80 decays/s]
# Processing:  55%|█████▌    | 552/1000 [00:07<00:05, 79.66 decays/s]
# Processing:  56%|█████▌    | 561/1000 [00:07<00:05, 79.85 decays/s]
# Processing:  57%|█████▋    | 569/1000 [00:07<00:05, 78.97 decays/s]
# Processing:  58%|█████▊    | 578/1000 [00:07<00:05, 79.35 decays/s]
# Processing:  59%|█████▊    | 587/1000 [00:07<00:05, 79.60 decays/s]
# Processing:  60%|█████▉    | 595/1000 [00:07<00:05, 79.69 decays/s]
# Processing:  60%|██████    | 603/1000 [00:07<00:04, 79.53 decays/s]
# Processing:  61%|██████    | 611/1000 [00:07<00:04, 79.49 decays/s]
# Processing:  62%|██████▏   | 619/1000 [00:07<00:04, 77.32 decays/s]
# Processing:  63%|██████▎   | 627/1000 [00:08<00:04, 76.39 decays/s]
# Processing:  64%|██████▎   | 635/1000 [00:08<00:04, 77.31 decays/s]
# Processing:  64%|██████▍   | 644/1000 [00:08<00:04, 78.21 decays/s]
# Processing:  65%|██████▌   | 652/1000 [00:08<00:04, 78.64 decays/s]
# Processing:  66%|██████▌   | 660/1000 [00:08<00:04, 78.75 decays/s]
# Processing:  67%|██████▋   | 668/1000 [00:08<00:04, 78.49 decays/s]
# Processing:  68%|██████▊   | 676/1000 [00:08<00:04, 73.89 decays/s]
# Processing:  68%|██████▊   | 684/1000 [00:08<00:04, 75.08 decays/s]
# Processing:  69%|██████▉   | 692/1000 [00:08<00:04, 76.29 decays/s]
# Processing:  70%|███████   | 700/1000 [00:08<00:03, 75.06 decays/s]
# Processing:  71%|███████   | 708/1000 [00:09<00:03, 74.85 decays/s]
# Processing:  72%|███████▏  | 716/1000 [00:09<00:03, 74.34 decays/s]
# Processing:  72%|███████▏  | 724/1000 [00:09<00:03, 74.33 decays/s]
# Processing:  73%|███████▎  | 732/1000 [00:09<00:03, 73.13 decays/s]
# Processing:  74%|███████▍  | 740/1000 [00:09<00:03, 74.49 decays/s]
# Processing:  75%|███████▍  | 748/1000 [00:09<00:03, 74.85 decays/s]
# Processing:  76%|███████▌  | 756/1000 [00:09<00:03, 73.75 decays/s]
# Processing:  76%|███████▋  | 764/1000 [00:09<00:03, 72.83 decays/s]
# Processing:  77%|███████▋  | 772/1000 [00:09<00:03, 73.86 decays/s]
# Processing:  78%|███████▊  | 780/1000 [00:10<00:02, 73.41 decays/s]
# Processing:  79%|███████▉  | 788/1000 [00:10<00:02, 74.63 decays/s]
# Processing:  80%|███████▉  | 796/1000 [00:10<00:02, 75.60 decays/s]
# Processing:  80%|████████  | 804/1000 [00:10<00:02, 76.64 decays/s]
# Processing:  81%|████████  | 812/1000 [00:10<00:02, 76.57 decays/s]
# Processing:  82%|████████▏ | 820/1000 [00:10<00:02, 76.81 decays/s]
# Processing:  83%|████████▎ | 828/1000 [00:10<00:02, 77.02 decays/s]
# Processing:  84%|████████▎ | 836/1000 [00:10<00:02, 76.73 decays/s]
# Processing:  84%|████████▍ | 844/1000 [00:10<00:02, 77.41 decays/s]
# Processing:  85%|████████▌ | 852/1000 [00:10<00:01, 77.19 decays/s]
# Processing:  86%|████████▌ | 860/1000 [00:11<00:01, 76.52 decays/s]
# Processing:  87%|████████▋ | 868/1000 [00:11<00:01, 76.38 decays/s]
# Processing:  88%|████████▊ | 876/1000 [00:11<00:01, 77.06 decays/s]
# Processing:  88%|████████▊ | 884/1000 [00:11<00:01, 74.41 decays/s]
# Processing:  89%|████████▉ | 892/1000 [00:11<00:01, 75.52 decays/s]
# Processing:  90%|█████████ | 900/1000 [00:11<00:01, 76.00 decays/s]
# Processing:  91%|█████████ | 908/1000 [00:11<00:01, 76.79 decays/s]
# Processing:  92%|█████████▏| 916/1000 [00:11<00:01, 75.95 decays/s]
# Processing:  92%|█████████▏| 924/1000 [00:11<00:00, 76.68 decays/s]
# Processing:  93%|█████████▎| 932/1000 [00:12<00:00, 77.04 decays/s]
# Processing:  94%|█████████▍| 940/1000 [00:12<00:00, 77.77 decays/s]
# Processing:  95%|█████████▍| 948/1000 [00:12<00:00, 77.84 decays/s]
# Processing:  96%|█████████▌| 956/1000 [00:12<00:00, 77.98 decays/s]
# Processing:  96%|█████████▋| 964/1000 [00:12<00:00, 78.29 decays/s]
# Processing:  97%|█████████▋| 972/1000 [00:12<00:00, 78.65 decays/s]
# Processing:  98%|█████████▊| 980/1000 [00:12<00:00, 78.55 decays/s]
# Processing:  99%|█████████▉| 988/1000 [00:12<00:00, 76.39 decays/s]
# Processing: 100%|█████████▉| 996/1000 [00:12<00:00, 77.11 decays/s]
# Processing: 100%|██████████| 1000/1000 [00:12<00:00, 77.46 decays/s]
# free parameters :   0%|          | 0/100 [00:00<?, ? iterations/s]
# free parameters :   9%|▉         | 9/100 [00:00<00:01, 86.56 iterations/s]
# free parameters :  19%|█▉        | 19/100 [00:00<00:00, 89.08 iterations/s]
# free parameters :  29%|██▉       | 29/100 [00:00<00:00, 90.62 iterations/s]
# free parameters :  39%|███▉      | 39/100 [00:00<00:00, 89.96 iterations/s]
# free parameters :  49%|████▉     | 49/100 [00:00<00:00, 90.05 iterations/s]
# free parameters :  59%|█████▉    | 59/100 [00:00<00:00, 90.35 iterations/s]
# free parameters :  69%|██████▉   | 69/100 [00:00<00:00, 90.11 iterations/s]
# free parameters :  79%|███████▉  | 79/100 [00:00<00:00, 89.80 iterations/s]
# free parameters :  88%|████████▊ | 88/100 [00:00<00:00, 89.53 iterations/s]
# free parameters :  97%|█████████▋| 97/100 [00:01<00:00, 88.80 iterations/s]
# free parameters : 100%|██████████| 100/100 [00:01<00:00, 89.40 iterations/s]

# %%
effS=np.asarray(effS)
effT=np.asarray(effT)
effD=np.asarray(effD)
effD2=np.asarray(effD2)
u_effS=np.asarray(u_effS)
u_effT=np.asarray(u_effT)
u_effD=np.asarray(u_effD)
u_effD2=np.asarray(u_effD2)

tdcr=effT/effD
u_tdcr=np.sqrt(u_effD**2*effT**2/effD**4+u_effT**2/effD**2)

plt.figure("efficiency vs free parameter")
plt.clf()
plt.errorbar(L,effD,yerr=u_effD,fmt="-k",label="double coincidences")
plt.errorbar(L,effT,yerr=u_effT,fmt="-r",label="triple coincidences")
plt.errorbar(L,effD2,yerr=u_effD2,fmt="-g",label="double coincidences (CIEMAT/NIST)")
plt.xscale('log')
plt.xlabel(r'$L$ /keV$^{-1}$', fontsize=14)
plt.ylabel(r'$\epsilon$', fontsize=14)
plt.legend()

plt.figure("efficiency vs TDCR")
plt.clf()
plt.errorbar(tdcr,effD,xerr=u_tdcr,yerr=u_effD,fmt="-k")
#plt.xscale('log')
plt.xlabel(r'$R_T/R_D$', fontsize=14)
plt.ylabel(r'$\epsilon_{D}$', fontsize=14)
# Out:
# Text(0, 0.5, '$\\epsilon_{D}$')
