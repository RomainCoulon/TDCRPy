# %% [markdown]
# # Efficiency curves using TDCRPy

# %%
pip install TDCRPy==2.20.9
# Out:
# Requirement already satisfied: TDCRPy==2.20.8 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (2.20.8)
# Requirement already satisfied: numpy in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.8) (2.4.6)
# Requirement already satisfied: scipy in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.8) (1.18.0)
# Requirement already satisfied: matplotlib in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.8) (3.11.0)
# Requirement already satisfied: tqdm in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.8) (4.68.3)
# Requirement already satisfied: numba in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.8) (0.65.1)
# Requirement already satisfied: setuptools in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.8) (82.0.1)
# Requirement already satisfied: contourpy>=1.0.1 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.8) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.8) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.8) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.8) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.8) (26.2)
# Requirement already satisfied: pillow>=9 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.8) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.8) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.8) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from python-dateutil>=2.7->matplotlib->TDCRPy==2.20.8) (1.17.0)
# Requirement already satisfied: llvmlite<0.48,>=0.47.0dev0 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from numba->TDCRPy==2.20.8) (0.47.0)
# Requirement already satisfied: colorama in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from tqdm->TDCRPy==2.20.8) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import tdcrpy as td
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt

# %%
mode = "eff"                # ask for efficiency calculation
Rad="Co-60"                 # radionuclides
pmf_1="1"                   # relatives fractions of the radionulides
N = 1000                     # number of Monte Carlo trials
kB =1.0e-5                  # Birks constant in cm keV-1
V = 10                      # volume of scintillator in mL
L=np.logspace(-3,2,num=100) # free parameter in keV-1

# Record decay histories in temporary files
td.TDCRPy.TDCRPy(L[0], Rad, pmf_1, N, kB, V, mode, barp=True, record=True)

effS, u_effS, effD, u_effD, effT, u_effT, effD2, u_effD2 = [], [],[], [],[], [], [], []
for l in tqdm(L, desc="free parameters ", unit=" iterations"):
  out = td.TDCRPy.TDCRPy(l, Rad, pmf_1, N, kB, V, mode, readRecHist=True)
  effS.append(out[2])
  u_effS.append(out[3])
  effD.append(out[2])
  u_effD.append(out[3])
  effT.append(out[4])
  u_effT.append(out[5])
  effD2.append(out[12])
  u_effD2.append(out[13])
# Out:
#  ______  ______  ______ _______  ________
# |__  __||  ___ \|  ___||  ___ | |  ____ |
#   | |   | |  | || |    | |  | | | |___| |___     ___
#   | |   | |  | || |    | |__| | |  _____|\  \   |  |
#   | |   | |__| || |____|  __  \ | |       \  \  |  |
#   |_|   |_____/ |_____||_|  \__\|_|        \  \_|  |
#   +++++++++++++++++++++++++++++++++++++++++/      /
#   ________________________________________/      /
#  |______________________________________________/
#
#
# version 2.20.8
# BIPM 2023 - license MIT
# distribution: https://pypi.org/project/TDCRPy
# developement: https://github.com/RomainCoulon/TDCRPy
#
# start calculation...
# Processing:   0%|          | 0/1000 [00:00<?, ? decays/s]
# Processing:   1%|          | 8/1000 [00:00<00:13, 74.60 decays/s]
# Processing:   2%|▏         | 16/1000 [00:00<00:13, 75.53 decays/s]
# Processing:   2%|▏         | 24/1000 [00:00<00:12, 75.59 decays/s]
# Processing:   3%|▎         | 32/1000 [00:00<00:12, 76.36 decays/s]
# Processing:   4%|▍         | 40/1000 [00:00<00:12, 75.99 decays/s]
# Processing:   5%|▍         | 48/1000 [00:00<00:12, 75.91 decays/s]
# Processing:   6%|▌         | 56/1000 [00:00<00:12, 76.27 decays/s]
# Processing:   6%|▋         | 64/1000 [00:00<00:12, 74.02 decays/s]
# Processing:   7%|▋         | 72/1000 [00:00<00:12, 75.26 decays/s]
# Processing:   8%|▊         | 80/1000 [00:01<00:12, 76.59 decays/s]
# Processing:   9%|▉         | 88/1000 [00:01<00:11, 76.86 decays/s]
# Processing:  10%|▉         | 96/1000 [00:01<00:11, 75.95 decays/s]
# Processing:  10%|█         | 104/1000 [00:01<00:11, 76.07 decays/s]
# Processing:  11%|█         | 112/1000 [00:01<00:11, 76.39 decays/s]
# Processing:  12%|█▏        | 120/1000 [00:01<00:11, 74.45 decays/s]
# Processing:  13%|█▎        | 128/1000 [00:01<00:11, 75.27 decays/s]
# Processing:  14%|█▎        | 136/1000 [00:01<00:11, 75.41 decays/s]
# Processing:  14%|█▍        | 144/1000 [00:01<00:11, 74.89 decays/s]
# Processing:  15%|█▌        | 152/1000 [00:02<00:11, 75.04 decays/s]
# Processing:  16%|█▌        | 160/1000 [00:02<00:11, 72.50 decays/s]
# Processing:  17%|█▋        | 168/1000 [00:02<00:11, 72.64 decays/s]
# Processing:  18%|█▊        | 176/1000 [00:02<00:11, 73.47 decays/s]
# Processing:  18%|█▊        | 184/1000 [00:02<00:11, 73.98 decays/s]
# Processing:  19%|█▉        | 192/1000 [00:02<00:11, 73.23 decays/s]
# Processing:  20%|██        | 200/1000 [00:02<00:10, 73.74 decays/s]
# Processing:  21%|██        | 208/1000 [00:02<00:11, 70.43 decays/s]
# Processing:  22%|██▏       | 216/1000 [00:02<00:10, 72.04 decays/s]
# Processing:  22%|██▏       | 224/1000 [00:03<00:10, 73.18 decays/s]
# Processing:  23%|██▎       | 232/1000 [00:03<00:10, 73.30 decays/s]
# Processing:  24%|██▍       | 240/1000 [00:03<00:10, 71.45 decays/s]
# Processing:  25%|██▍       | 248/1000 [00:03<00:10, 72.37 decays/s]
# Processing:  26%|██▌       | 256/1000 [00:03<00:10, 72.94 decays/s]
# Processing:  26%|██▋       | 264/1000 [00:03<00:10, 70.51 decays/s]
# Processing:  27%|██▋       | 272/1000 [00:03<00:10, 70.88 decays/s]
# Processing:  28%|██▊       | 280/1000 [00:03<00:09, 72.82 decays/s]
# Processing:  29%|██▉       | 288/1000 [00:03<00:09, 74.14 decays/s]
# Processing:  30%|██▉       | 296/1000 [00:03<00:09, 74.54 decays/s]
# Processing:  30%|███       | 304/1000 [00:04<00:09, 74.52 decays/s]
# Processing:  31%|███       | 312/1000 [00:04<00:09, 74.86 decays/s]
# Processing:  32%|███▏      | 320/1000 [00:04<00:09, 75.12 decays/s]
# Processing:  33%|███▎      | 328/1000 [00:04<00:08, 75.06 decays/s]
# Processing:  34%|███▎      | 336/1000 [00:04<00:08, 74.02 decays/s]
# Processing:  34%|███▍      | 344/1000 [00:04<00:08, 74.18 decays/s]
# Processing:  35%|███▌      | 352/1000 [00:04<00:08, 73.33 decays/s]
# Processing:  36%|███▌      | 360/1000 [00:04<00:08, 73.73 decays/s]
# Processing:  37%|███▋      | 368/1000 [00:04<00:08, 72.37 decays/s]
# Processing:  38%|███▊      | 376/1000 [00:05<00:08, 72.83 decays/s]
# Processing:  38%|███▊      | 384/1000 [00:05<00:08, 72.55 decays/s]
# Processing:  39%|███▉      | 392/1000 [00:05<00:08, 73.30 decays/s]
# Processing:  40%|████      | 400/1000 [00:05<00:08, 72.66 decays/s]
# Processing:  41%|████      | 408/1000 [00:05<00:08, 73.54 decays/s]
# Processing:  42%|████▏     | 416/1000 [00:05<00:07, 74.02 decays/s]
# Processing:  42%|████▏     | 424/1000 [00:05<00:07, 74.14 decays/s]
# Processing:  43%|████▎     | 432/1000 [00:05<00:07, 74.63 decays/s]
# Processing:  44%|████▍     | 440/1000 [00:05<00:07, 75.00 decays/s]
# Processing:  45%|████▍     | 448/1000 [00:06<00:07, 76.18 decays/s]
# Processing:  46%|████▌     | 456/1000 [00:06<00:07, 76.40 decays/s]
# Processing:  46%|████▋     | 464/1000 [00:06<00:07, 74.55 decays/s]
# Processing:  47%|████▋     | 472/1000 [00:06<00:07, 75.00 decays/s]
# Processing:  48%|████▊     | 480/1000 [00:06<00:06, 75.28 decays/s]
# Processing:  49%|████▉     | 488/1000 [00:06<00:06, 74.38 decays/s]
# Processing:  50%|████▉     | 496/1000 [00:06<00:06, 74.67 decays/s]
# Processing:  50%|█████     | 504/1000 [00:06<00:06, 74.79 decays/s]
# Processing:  51%|█████     | 512/1000 [00:06<00:06, 75.43 decays/s]
# Processing:  52%|█████▏    | 520/1000 [00:07<00:06, 75.52 decays/s]
# Processing:  53%|█████▎    | 528/1000 [00:07<00:06, 75.34 decays/s]
# Processing:  54%|█████▎    | 536/1000 [00:07<00:06, 76.28 decays/s]
# Processing:  54%|█████▍    | 544/1000 [00:07<00:05, 76.94 decays/s]
# Processing:  55%|█████▌    | 552/1000 [00:07<00:05, 76.97 decays/s]
# Processing:  56%|█████▌    | 560/1000 [00:07<00:05, 76.87 decays/s]
# Processing:  57%|█████▋    | 568/1000 [00:07<00:05, 74.13 decays/s]
# Processing:  58%|█████▊    | 576/1000 [00:07<00:05, 74.94 decays/s]
# Processing:  58%|█████▊    | 584/1000 [00:07<00:05, 75.18 decays/s]
# Processing:  59%|█████▉    | 592/1000 [00:07<00:05, 74.13 decays/s]
# Processing:  60%|██████    | 600/1000 [00:08<00:05, 72.63 decays/s]
# Processing:  61%|██████    | 608/1000 [00:08<00:05, 72.50 decays/s]
# Processing:  62%|██████▏   | 616/1000 [00:08<00:05, 72.77 decays/s]
# Processing:  62%|██████▏   | 624/1000 [00:08<00:05, 69.83 decays/s]
# Processing:  63%|██████▎   | 632/1000 [00:08<00:05, 71.15 decays/s]
# Processing:  64%|██████▍   | 640/1000 [00:08<00:05, 71.47 decays/s]
# Processing:  65%|██████▍   | 648/1000 [00:08<00:04, 71.85 decays/s]
# Processing:  66%|██████▌   | 656/1000 [00:08<00:04, 72.28 decays/s]
# Processing:  66%|██████▋   | 664/1000 [00:08<00:04, 71.44 decays/s]
# Processing:  67%|██████▋   | 672/1000 [00:09<00:04, 72.75 decays/s]
# Processing:  68%|██████▊   | 680/1000 [00:09<00:04, 72.67 decays/s]
# Processing:  69%|██████▉   | 688/1000 [00:09<00:04, 73.70 decays/s]
# Processing:  70%|██████▉   | 696/1000 [00:09<00:04, 74.67 decays/s]
# Processing:  70%|███████   | 704/1000 [00:09<00:03, 75.12 decays/s]
# Processing:  71%|███████   | 712/1000 [00:09<00:03, 75.51 decays/s]
# Processing:  72%|███████▏  | 720/1000 [00:09<00:03, 75.65 decays/s]
# Processing:  73%|███████▎  | 728/1000 [00:09<00:03, 75.89 decays/s]
# Processing:  74%|███████▎  | 736/1000 [00:09<00:03, 76.12 decays/s]
# Processing:  74%|███████▍  | 744/1000 [00:10<00:03, 76.06 decays/s]
# Processing:  75%|███████▌  | 752/1000 [00:10<00:03, 77.05 decays/s]
# Processing:  76%|███████▌  | 760/1000 [00:10<00:03, 77.58 decays/s]
# Processing:  77%|███████▋  | 768/1000 [00:10<00:03, 76.63 decays/s]
# Processing:  78%|███████▊  | 776/1000 [00:10<00:02, 76.26 decays/s]
# Processing:  78%|███████▊  | 784/1000 [00:10<00:02, 76.44 decays/s]
# Processing:  79%|███████▉  | 792/1000 [00:10<00:02, 76.22 decays/s]
# Processing:  80%|████████  | 800/1000 [00:10<00:02, 76.16 decays/s]
# Processing:  81%|████████  | 808/1000 [00:10<00:02, 74.41 decays/s]
# Processing:  82%|████████▏ | 816/1000 [00:10<00:02, 75.27 decays/s]
# Processing:  82%|████████▏ | 824/1000 [00:11<00:02, 75.72 decays/s]
# Processing:  83%|████████▎ | 832/1000 [00:11<00:02, 75.24 decays/s]
# Processing:  84%|████████▍ | 840/1000 [00:11<00:02, 75.52 decays/s]
# Processing:  85%|████████▍ | 848/1000 [00:11<00:02, 75.70 decays/s]
# Processing:  86%|████████▌ | 856/1000 [00:11<00:01, 75.55 decays/s]
# Processing:  86%|████████▋ | 864/1000 [00:11<00:01, 72.57 decays/s]
# Processing:  87%|████████▋ | 872/1000 [00:11<00:01, 72.31 decays/s]
# Processing:  88%|████████▊ | 880/1000 [00:11<00:01, 72.42 decays/s]
# Processing:  89%|████████▉ | 888/1000 [00:11<00:01, 73.54 decays/s]
# Processing:  90%|████████▉ | 896/1000 [00:12<00:01, 74.08 decays/s]
# Processing:  90%|█████████ | 904/1000 [00:12<00:01, 71.34 decays/s]
# Processing:  91%|█████████ | 912/1000 [00:12<00:01, 72.55 decays/s]
# Processing:  92%|█████████▏| 920/1000 [00:12<00:01, 73.51 decays/s]
# Processing:  93%|█████████▎| 928/1000 [00:12<00:00, 74.35 decays/s]
# Processing:  94%|█████████▎| 936/1000 [00:12<00:00, 72.50 decays/s]
# Processing:  94%|█████████▍| 944/1000 [00:12<00:00, 70.50 decays/s]
# Processing:  95%|█████████▌| 952/1000 [00:12<00:00, 68.42 decays/s]
# Processing:  96%|█████████▌| 960/1000 [00:12<00:00, 70.03 decays/s]
# Processing:  97%|█████████▋| 968/1000 [00:13<00:00, 71.00 decays/s]
# Processing:  98%|█████████▊| 976/1000 [00:13<00:00, 71.76 decays/s]
# Processing:  98%|█████████▊| 984/1000 [00:13<00:00, 72.52 decays/s]
# Processing:  99%|█████████▉| 992/1000 [00:13<00:00, 73.51 decays/s]
# Processing: 100%|██████████| 1000/1000 [00:13<00:00, 71.66 decays/s]
# Processing: 100%|██████████| 1000/1000 [00:13<00:00, 73.99 decays/s]
# free parameters :   0%|          | 0/100 [00:00<?, ? iterations/s]
# free parameters :   3%|▎         | 3/100 [00:00<00:03, 29.66 iterations/s]
# free parameters :  12%|█▏        | 12/100 [00:00<00:01, 62.39 iterations/s]
# free parameters :  21%|██        | 21/100 [00:00<00:01, 73.63 iterations/s]
# free parameters :  29%|██▉       | 29/100 [00:00<00:00, 71.92 iterations/s]
# free parameters :  38%|███▊      | 38/100 [00:00<00:00, 75.73 iterations/s]
# free parameters :  46%|████▌     | 46/100 [00:00<00:01, 44.11 iterations/s]
# free parameters :  55%|█████▌    | 55/100 [00:00<00:00, 53.09 iterations/s]
# free parameters :  62%|██████▏   | 62/100 [00:01<00:01, 37.79 iterations/s]
# free parameters :  70%|███████   | 70/100 [00:01<00:00, 44.68 iterations/s]
# free parameters :  76%|███████▌  | 76/100 [00:01<00:00, 33.63 iterations/s]
# free parameters :  84%|████████▍ | 84/100 [00:01<00:00, 41.35 iterations/s]
# free parameters :  91%|█████████ | 91/100 [00:01<00:00, 46.02 iterations/s]
# free parameters :  98%|█████████▊| 98/100 [00:02<00:00, 34.38 iterations/s]
# free parameters : 100%|██████████| 100/100 [00:02<00:00, 43.93 iterations/s]

# %%
effS=np.asarray(effS)
effT=np.asarray(effT)
effD=np.asarray(effD)
effD2=np.asarray(effD2)
u_effS=np.asarray(u_effS)
u_effT=np.asarray(u_effT)
u_effD=np.asarray(u_effD)
u_effD2=np.asarray(u_effD2)

tdcr=effT/effD
u_tdcr=np.sqrt(u_effD**2*effT**2/effD**4+u_effT**2/effD**2)

plt.figure("efficiency vs free parameter")
plt.clf()
plt.errorbar(L,effD,yerr=u_effD,fmt="-k",label="double coincidences")
plt.errorbar(L,effT,yerr=u_effT,fmt="-r",label="triple coincidences")
plt.errorbar(L,effD2,yerr=u_effD2,fmt="-g",label="double coincidences (CIEMAT/NIST)")
plt.xscale('log')
plt.xlabel(r'$L$ /keV$^{-1}$', fontsize=14)
plt.ylabel(r'$\epsilon$', fontsize=14)
plt.legend()

plt.figure("efficiency vs TDCR")
plt.clf()
plt.errorbar(tdcr,effD,xerr=u_tdcr,yerr=u_effD,fmt="-k")
#plt.xscale('log')
plt.xlabel(r'$R_T/R_D$', fontsize=14)
plt.ylabel(r'$\epsilon_{D}$', fontsize=14)
# Out:
# Text(0, 0.5, '$\\epsilon_{D}$')
