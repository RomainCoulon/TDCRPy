# %%
pip install TDCRPy==2.19.0
# Out:
# Requirement already satisfied: TDCRPy==2.19.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (2.19.0)
# Requirement already satisfied: numpy in /home/codespace/.local/lib/python3.12/site-packages (from TDCRPy==2.19.0) (2.4.6)
# Requirement already satisfied: tqdm in /home/codespace/.local/lib/python3.12/site-packages (from TDCRPy==2.19.0) (4.68.1)
# Requirement already satisfied: setuptools in /home/codespace/.local/lib/python3.12/site-packages (from TDCRPy==2.19.0) (82.0.1)
# Requirement already satisfied: scipy in /home/codespace/.local/lib/python3.12/site-packages (from TDCRPy==2.19.0) (1.17.1)
# Requirement already satisfied: configparser in /home/codespace/.local/lib/python3.12/site-packages (from TDCRPy==2.19.0) (7.2.0)
# Requirement already satisfied: importlib.resources in /home/codespace/.local/lib/python3.12/site-packages (from TDCRPy==2.19.0) (7.1.0)
# Requirement already satisfied: matplotlib in /home/codespace/.local/lib/python3.12/site-packages (from TDCRPy==2.19.0) (3.10.9)
# Requirement already satisfied: contourpy>=1.0.1 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib->TDCRPy==2.19.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib->TDCRPy==2.19.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib->TDCRPy==2.19.0) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib->TDCRPy==2.19.0) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib->TDCRPy==2.19.0) (26.2)
# Requirement already satisfied: pillow>=8 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib->TDCRPy==2.19.0) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib->TDCRPy==2.19.0) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib->TDCRPy==2.19.0) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->TDCRPy==2.19.0) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import tdcrpy as td
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt

# %%
Rad="Zr-93"                   # radionuclides
pmf_1="1"                   # relatives fractions of the radionulides
kB =1.0e-5                  # Birks constant in cm keV-1
V = 10                      # volume of scintillator in mL
ne = 1000                   # number of discretization steps for the numerical computation of the quenching function

# %% [markdown]
# ## Analytical model (precise but less accurated for complex decay schemes)

# %%
TD = 0.977667386529166     # TDCR parameter
TAB = 0.992232838598821    # TDCR parameter T/AB
TBC = 0.992343419459002    # TDCR parameter T/BC
TAC = 0.99275350064608     # TDCR parameter T/AC
minL = 0.1                 # minimum light yield (keV-1)
maxL = 50                  # maximum light yield (keV-1)

result1 = td.TDCRPy.effA(TD, Rad, pmf_1, kB, V, Lbounds=[minL, maxL])
print(f"\nResults using a global parameter")
print(f"Global free parameter: {result1[0]}")
print(f"Efficiency of single events: {result1[2]}")
print(f"Efficiency of double coincidence events: {result1[3]}")
print(f"Efficiency of triple coincidence events: {result1[4]}\n")

result3 = td.TDCRPy.effA([TD, TAB, TBC, TAC], Rad, pmf_1, kB, V, Lbounds=[minL, maxL])
print(f"\nResults using 3 free parameters")
print(f"Global free parameter: {result3[0]}")
print(f"Free parameter PMT A: {result3[1][0]}")
print(f"Free parameter PMT B: {result3[1][1]}")
print(f"Free parameter PMT C: {result3[1][2]}")
print(f"Efficiency of single events: {result3[2]}")
print(f"Efficiency of double coincidence events: {result3[3]}")
print(f"Efficiency of triple coincidence events: {result3[4]}")
# Out:
# global free parameter = 27.34187271211288 keV-1
#
# Results using a global parameter
# Global free parameter: 27.34187271211288
# Efficiency of single events: 0.9592564778355045
# Efficiency of double coincidence events: 0.9778791955213901
# Efficiency of triple coincidence events: 0.9592564778355045
#
# global free parameter = 27.34187271211288 keV-1
# free parameters = [27.13555702 28.2856845  26.78466883] keV-1
#
# Results using 3 free parameters
# Global free parameter: 27.34187271211288
# Free parameter PMT A: 27.13555701557891
# Free parameter PMT B: 28.285684504202347
# Free parameter PMT C: 26.78466883341791
# Efficiency of single events: 0.9592911154125953
# Efficiency of double coincidence events: 0.9779211549007345
# Efficiency of triple coincidence events: 0.9592911154125953

# %% [markdown]
# ## Stochastic model (less precise but aimed to be more accurate for complex decay schemes)

# %%
N = 10000 # number of Monte-Carlo trials
result2 = td.TDCRPy.eff(TD, Rad, pmf_1, kB, V, N, Lbounds=(minL, maxL))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 N = 10000 # number of Monte-Carlo trials
# ----> 2 result2 = td.TDCRPy.eff(TD, Rad, pmf_1, kB, V, N, Lbounds=(minL, maxL))
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/tdcrpy/TDCRPy.py:1111, in eff(TD, Rad, pmf_1, kB, V, N, L, maxiter, xatol, disp, Lbounds)
#    1108 else:
#    1109     symm = True
# -> 1111 TDCRPy(L, Rad, pmf_1, N, kB, V, record = True)
#    1113 if symm: r=opt.minimize_scalar(objectFct, args=(TD, Rad, pmf_1, N, kB, V), method='bounded', bounds = (Lbounds[0], Lbounds[1]), options={'disp': disp, 'maxiter':maxiter})
#    1114 else: r=opt.minimize_scalar(objectFct, args=(TD[0], Rad, pmf_1, N, kB, V), method='bounded', bounds = (Lbounds[0], Lbounds[1]), options={'disp': disp, 'maxiter':maxiter})
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/tdcrpy/TDCRPy.py:949, in TDCRPy(L, Rad, pmf_1, N, kB, V, mode, Display, barp, Smodel, record, readRecHist, uncData, fullMC)
#     947 if writeOn:
#     948     if idec<10:
# --> 949         file.write(f"{col1} {e_quenching2[irec]*1e3:.6E}  {idec} 1 {t1:.6E}\n")
#     950     else:
#     951         file.write(f"{col1} {e_quenching2[irec]*1e3:.6E} {idec} 1 {t1:.6E}\n")
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
print(f"global free parameter = {round(result2[0],4)} keV-1")
print(f"global free parameter (PMT A) = {round(result2[1][0],4)} keV-1")
print(f"global free parameter (PMT B) = {round(result2[1][1],4)} keV-1")
print(f"global free parameter (PMT C) = {round(result2[1][2],4)} keV-1")
print(f"efficiency S = {round(result2[2],4)} +/- {round(result2[3],4)}")
print(f"efficiency D = {round(result2[4],4)} +/- {round(result2[5],4)}")
print(f"efficiency T = {round(result2[6],4)} +/- {round(result2[7],4)}")
print(f"efficiency AB = {round(result2[6],4)} +/- {round(result2[7],4)}")
print(f"efficiency BC = {round(result2[8],4)} +/- {round(result2[9],4)}")
print(f"efficiency AC = {round(result2[10],4)} +/- {round(result2[11],4)}")
# Out:
# global free parameter = 49.994 keV-1
# global free parameter (PMT A) = 49.994 keV-1
# global free parameter (PMT B) = 49.994 keV-1
# global free parameter (PMT C) = 49.994 keV-1
# efficiency S = 0.9901 +/- 0.0007
# efficiency D = 0.9769 +/- 0.0012
# efficiency T = 0.952 +/- 0.0018
# efficiency AB = 0.952 +/- 0.0018
# efficiency BC = 0.9603 +/- 0.0015
# efficiency AC = 0.9603 +/- 0.0015

# %% [markdown]
# ## Comparison

# %%
print(f"Efficiency of double coincidence events (deviation): {result1[3]-result2[4]}")
print(f"Efficiency of triple coincidence events (deviation): {result1[4]-result2[6]}")
# Out:
# Efficiency of double coincidence events (deviation): -0.006746311761145596
# Efficiency of triple coincidence events (deviation): -0.0035086928384544525
