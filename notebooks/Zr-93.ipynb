# %%
pip install TDCRPy==2.20.5
# Out:
# Requirement already satisfied: TDCRPy==2.20.5 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (2.20.5)
# Requirement already satisfied: numpy in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.5) (2.4.6)
# Requirement already satisfied: scipy in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.5) (1.18.0)
# Requirement already satisfied: matplotlib in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.5) (3.11.0)
# Requirement already satisfied: tqdm in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.5) (4.68.3)
# Requirement already satisfied: numba in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.5) (0.65.1)
# Requirement already satisfied: setuptools in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.5) (82.0.1)
# Requirement already satisfied: contourpy>=1.0.1 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.5) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.5) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.5) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.5) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.5) (26.2)
# Requirement already satisfied: pillow>=9 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.5) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.5) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.5) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from python-dateutil>=2.7->matplotlib->TDCRPy==2.20.5) (1.17.0)
# Requirement already satisfied: llvmlite<0.48,>=0.47.0dev0 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from numba->TDCRPy==2.20.5) (0.47.0)
# Requirement already satisfied: colorama in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from tqdm->TDCRPy==2.20.5) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import tdcrpy as td
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt

# %%
Rad="Zr-93"                   # radionuclides
pmf_1="1"                   # relatives fractions of the radionulides
kB =1.0e-5                  # Birks constant in cm keV-1
V = 10                      # volume of scintillator in mL
ne = 1000                   # number of discretization steps for the numerical computation of the quenching function

# %% [markdown]
# ## Analytical model (precise but less accurated for complex decay schemes)

# %%
TD = 0.977667386529166     # TDCR parameter
TAB = 0.992232838598821    # TDCR parameter T/AB
TBC = 0.992343419459002    # TDCR parameter T/BC
TAC = 0.99275350064608     # TDCR parameter T/AC
minL = 0.1                 # minimum light yield (keV-1)
maxL = 50                  # maximum light yield (keV-1)

result1 = td.TDCRPy.effA(TD, Rad, pmf_1, kB, V, Lbounds=[minL, maxL])
print(f"\nResults using a global parameter")
print(f"Global free parameter: {result1[0]}")
print(f"Efficiency of single events: {result1[2]}")
print(f"Efficiency of double coincidence events: {result1[3]}")
print(f"Efficiency of triple coincidence events: {result1[4]}\n")

result3 = td.TDCRPy.effA([TD, TAB, TBC, TAC], Rad, pmf_1, kB, V, Lbounds=[minL, maxL])
print(f"\nResults using 3 free parameters")
print(f"Global free parameter: {result3[0]}")
print(f"Free parameter PMT A: {result3[1][0]}")
print(f"Free parameter PMT B: {result3[1][1]}")
print(f"Free parameter PMT C: {result3[1][2]}")
print(f"Efficiency of single events: {result3[2]}")
print(f"Efficiency of double coincidence events: {result3[3]}")
print(f"Efficiency of triple coincidence events: {result3[4]}")
# Out:
# Results using a global parameter
# Global free parameter: 10.059356195847887
# Efficiency of single events: 0.9687132887841775
# Efficiency of double coincidence events: 0.9701434913610613
# Efficiency of triple coincidence events: 0.9484776517491379
# Results using 3 free parameters
# Global free parameter: 10.059356195847887
# Free parameter PMT A: 10.04934704610589
# Free parameter PMT B: 10.356919862219184
# Free parameter PMT C: 9.971744937148983
# Efficiency of single events: 0.9486589024763915
# Efficiency of double coincidence events: 0.9702943140108109
# Efficiency of triple coincidence events: 0.9486589024763915

# %% [markdown]
# ## Stochastic model (less precise but aimed to be more accurate for complex decay schemes)

# %%
N = 10000 # number of Monte-Carlo trials
result2 = td.TDCRPy.eff(TD, Rad, pmf_1, kB, V, N, Lbounds=(minL, maxL))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[5], line 2
#       1 N = 10000 # number of Monte-Carlo trials
# ----> 2 result2 = td.TDCRPy.eff(TD, Rad, pmf_1, kB, V, N, Lbounds=(minL, maxL))
#
# File g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages\tdcrpy\TDCRPy.py:1430, in eff(TD, Rad, pmf_1, kB, V, N, L, maxiter, xatol, disp, Lbounds)
#    1427 symm = not isinstance(TD, (tuple, list))
#    1429 # Step 1 — cache decay histories.
# -> 1430 TDCRPy(L, Rad, pmf_1, N, kB, V, record=True)
#    1432 # Step 2 — scalar optimisation for L (symmetric).
#    1433 td0 = TD if symm else TD[0]
#
# File g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages\tdcrpy\TDCRPy.py:713, in TDCRPy(L, Rad, pmf_1, N, kB, V, mode, display, barp, Smodel, record, readRecHist, uncData, fullMC, Display)
#     711 e_quenching2 = 0
#     712 if evenement != 1:
# --> 713     e_quenching2 = _quench(
#     714         particle_vec2, energy_vec2, energy_vec_initial2,
#     715         kB, ne_electron, ne_alpha, mic_corr, display,
#     716     )
#     718 # -------------------------------------------------------------- #
#     719 # 8.5a  Optional: record quenched energies                        #
#     720 # -------------------------------------------------------------- #
#     721 if record:
#
# File g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages\tdcrpy\TDCRPy.py:1132, in _quench(particle_vec, energy_vec, energy_vec_initial, kB, ne_electron, ne_alpha, mic_corr, display)
#    1128     e_quenching.append(energy_vec[ipart])
#    1130 elif p in ("electron", "positron"):
#    1131     eq = tl.Em_e(
# -> 1132         energy_vec_initial[ipart] * 1e3,
#    1133         energy_vec[ipart] * 1e3,
#    1134         kB * 1e3,
#    1135         ne_electron,
#    1136     ) * 1e-3
#    1137     if mic_corr:
#    1138         eq = tl.pure_mc_efficient_energy_numba(eq)
#
# IndexError: list index out of range

# %%
print(f"global free parameter = {round(result2[0],4)} keV-1")
print(f"global free parameter (PMT A) = {round(result2[1][0],4)} keV-1")
print(f"global free parameter (PMT B) = {round(result2[1][1],4)} keV-1")
print(f"global free parameter (PMT C) = {round(result2[1][2],4)} keV-1")
print(f"efficiency S = {round(result2[2],4)} +/- {round(result2[3],4)}")
print(f"efficiency D = {round(result2[4],4)} +/- {round(result2[5],4)}")
print(f"efficiency T = {round(result2[6],4)} +/- {round(result2[7],4)}")
print(f"efficiency AB = {round(result2[6],4)} +/- {round(result2[7],4)}")
print(f"efficiency BC = {round(result2[8],4)} +/- {round(result2[9],4)}")
print(f"efficiency AC = {round(result2[10],4)} +/- {round(result2[11],4)}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 print(f"global free parameter = {round(result2[0],4)} keV-1")
#       2 print(f"global free parameter (PMT A) = {round(result2[1][0],4)} keV-1")
#       3 print(f"global free parameter (PMT B) = {round(result2[1][1],4)} keV-1")
#       4 print(f"global free parameter (PMT C) = {round(result2[1][2],4)} keV-1")
#
# NameError: name 'result2' is not defined

# %% [markdown]
# ## Comparison

# %%
print(f"Efficiency of double coincidence events (deviation): {result1[3]-result2[4]}")
print(f"Efficiency of triple coincidence events (deviation): {result1[4]-result2[6]}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 print(f"Efficiency of double coincidence events (deviation): {result1[3]-result2[4]}")
#       2 print(f"Efficiency of triple coincidence events (deviation): {result1[4]-result2[6]}")
#
# NameError: name 'result2' is not defined
