# %%
pip install TDCRPy==2.20.11
# Out:
# Requirement already satisfied: TDCRPy==2.20.10 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (2.20.10)
# Requirement already satisfied: numpy in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.10) (2.4.6)
# Requirement already satisfied: scipy in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.10) (1.18.0)
# Requirement already satisfied: matplotlib in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.10) (3.11.0)
# Requirement already satisfied: tqdm in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.10) (4.68.3)
# Requirement already satisfied: numba in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.10) (0.65.1)
# Requirement already satisfied: setuptools in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.10) (82.0.1)
# Requirement already satisfied: contourpy>=1.0.1 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.10) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.10) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.10) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.10) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.10) (26.2)
# Requirement already satisfied: pillow>=9 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.10) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.10) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.10) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from python-dateutil>=2.7->matplotlib->TDCRPy==2.20.10) (1.17.0)
# Requirement already satisfied: llvmlite<0.48,>=0.47.0dev0 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from numba->TDCRPy==2.20.10) (0.47.0)
# Requirement already satisfied: colorama in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from tqdm->TDCRPy==2.20.10) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import tdcrpy as td
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt

# %%
Rad="Sr-90, Y-90"           # radionuclides
pmf_1="0.5, 0.5"                # relatives fractions of the radionulides
kB =1.0e-5                  # Birks constant in cm keV-1
V = 10                      # volume of scintillator in mL

# %%
TD = 0.9838                # TDCR parameter
minL = 0.1                 # minimum light yield (keV-1)
maxL = 50                  # maximum light yield (keV-1)
N = 10000                  # number of Monte-Carlo trials
result2 = td.TDCRPy.eff(TD, Rad, pmf_1, kB, V, N, Lbounds=(minL, maxL))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 5
#       1 TD = 0.9838                # TDCR parameter
#       2 minL = 0.1                 # minimum light yield (keV-1)
#       3 maxL = 50                  # maximum light yield (keV-1)
#       4 N = 10000                  # number of Monte-Carlo trials
# ----> 5 result2 = td.TDCRPy.eff(TD, Rad, pmf_1, kB, V, N, Lbounds=(minL, maxL))
#
# File g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages\tdcrpy\TDCRPy.py:1353, in eff(TD, Rad, pmf_1, kB, V, N, L, maxiter, xatol, disp, Lbounds)
#    1350 symm = not isinstance(TD, (tuple, list))
#    1352 # Step 1 — cache decay histories.
# -> 1353 TDCRPy(L, Rad, pmf_1, N, kB, V, record=True)
#    1355 # Step 2 — scalar optimisation for L (symmetric).
#    1356 td0 = TD if symm else TD[0]
#
# File g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages\tdcrpy\TDCRPy.py:517, in TDCRPy(L, Rad, pmf_1, N, kB, V, mode, display, barp, Smodel, record, readRecHist, uncData, fullMC, Display)
#     507     print(f"\n\n Trial {idec + 1} — Sampled radionuclide: {rad_i}")
#     509 # -------------------------------------------------------------- #
#     510 # 8.1  Nuclear decay                                               #
#     511 # -------------------------------------------------------------- #
#     512 (
#     513     particle_vec, energy_vec,
#     514     particle_vec2, energy_vec2,
#     515     evenement, t1,
#     516     level_before_trans, iDaughter,
# --> 517 ) = _sample_nuclear_decay(
#     518     index_rad, Rad, DaughterVec, Pdaughter, particle, p_branch,
#     519     e_branch, LevelDaughter, levelNumber, prob_trans, prob_branch,
#     520     levelEnergy, transitionType, e_trans, next_level,
#     521     Transition_prob_sum, trans_halfLife, u_prob_trans,
#     522     tau, uncData, display,
#     523 )
#     525 # -------------------------------------------------------------- #
#     526 # 8.2  Atomic relaxation                                           #
#     527 # -------------------------------------------------------------- #
#     528 daughter_relax = DaughterVec[index_rad][iDaughter]
#
# File g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages\tdcrpy\TDCRPy.py:816, in _sample_nuclear_decay(index_rad, Rad, DaughterVec, Pdaughter, particle, p_branch, e_branch, LevelDaughter, levelNumber, prob_trans, prob_branch, levelEnergy, transitionType, e_trans, next_level, Transition_prob_sum, trans_halfLife, u_prob_trans, tau, unc_data, display)
#     813     prob_t = tl.normalise(prob_trans[index_rad][iDaughter][i_level])
#     815 index_t = tl.sampling(prob_t)
# --> 816 t_type = transitionType[index_rad][iDaughter][i_level][index_t]
#     817 e_t = e_trans[index_rad][iDaughter][i_level][index_t]
#     819 if display:
#
# IndexError: list index out of range

# %%
print(f"global free parameter = {round(result2[0],4)} keV-1")
print(f"global free parameter (PMT A) = {round(result2[1][0],4)} keV-1")
print(f"global free parameter (PMT B) = {round(result2[1][1],4)} keV-1")
print(f"global free parameter (PMT C) = {round(result2[1][2],4)} keV-1")
print(f"efficiency S = {2*round(result2[2],4)} +/- {2*round(result2[3],4)}")
print(f"efficiency D = {2*round(result2[4],4)} +/- {2*round(result2[5],4)}")
print(f"efficiency T = {2*round(result2[6],4)} +/- {2*round(result2[7],4)}")
print(f"efficiency AB = {2*round(result2[6],4)} +/- {2*round(result2[7],4)}")
print(f"efficiency BC = {2*round(result2[8],4)} +/- {2*round(result2[9],4)}")
print(f"efficiency AC = {2*round(result2[10],4)} +/- {2*round(result2[11],4)}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 print(f"global free parameter = {round(result2[0],4)} keV-1")
#       2 print(f"global free parameter (PMT A) = {round(result2[1][0],4)} keV-1")
#       3 print(f"global free parameter (PMT B) = {round(result2[1][1],4)} keV-1")
#       4 print(f"global free parameter (PMT C) = {round(result2[1][2],4)} keV-1")
#
# NameError: name 'result2' is not defined
