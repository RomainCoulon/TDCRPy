# %% [markdown]
# <a href="https://colab.research.google.com/github/RomainCoulon/TDCRPy/blob/main/Tuturial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Quick start with the TDCRPy code

# %% [markdown]
# ## install a stable version of TDCRPy

# %%
pip install TDCRPy==2.19.2
# Out:
# Collecting TDCRPy==2.19.2
#   Downloading tdcrpy-2.19.2-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: numpy in /home/codespace/.local/lib/python3.12/site-packages (from TDCRPy==2.19.2) (2.4.6)
# Requirement already satisfied: tqdm in /home/codespace/.local/lib/python3.12/site-packages (from TDCRPy==2.19.2) (4.68.1)
# Requirement already satisfied: setuptools in /home/codespace/.local/lib/python3.12/site-packages (from TDCRPy==2.19.2) (82.0.1)
# Requirement already satisfied: scipy in /home/codespace/.local/lib/python3.12/site-packages (from TDCRPy==2.19.2) (1.17.1)
# Requirement already satisfied: configparser in /home/codespace/.local/lib/python3.12/site-packages (from TDCRPy==2.19.2) (7.2.0)
# Requirement already satisfied: importlib.resources in /home/codespace/.local/lib/python3.12/site-packages (from TDCRPy==2.19.2) (7.1.0)
# Requirement already satisfied: matplotlib in /home/codespace/.local/lib/python3.12/site-packages (from TDCRPy==2.19.2) (3.10.9)
# Requirement already satisfied: numba in /usr/local/python/3.12.1/lib/python3.12/site-packages (from TDCRPy==2.19.2) (0.65.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib->TDCRPy==2.19.2) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib->TDCRPy==2.19.2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib->TDCRPy==2.19.2) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib->TDCRPy==2.19.2) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib->TDCRPy==2.19.2) (26.2)
# Requirement already satisfied: pillow>=8 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib->TDCRPy==2.19.2) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib->TDCRPy==2.19.2) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib->TDCRPy==2.19.2) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->TDCRPy==2.19.2) (1.17.0)
# Requirement already satisfied: llvmlite<0.48,>=0.47.0dev0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from numba->TDCRPy==2.19.2) (0.47.0)
# Downloading tdcrpy-2.19.2-py3-none-any.whl (23.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.4/23.4 MB 4.4 MB/s  0:00:0536m0:00:0100:01
# Installing collected packages: TDCRPy
#   Attempting uninstall: TDCRPy
#     Found existing installation: TDCRPy 2.19.1
#     Uninstalling TDCRPy-2.19.1:
#       Successfully uninstalled TDCRPy-2.19.1
# Successfully installed TDCRPy-2.19.2
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Import the module

# %%
import tdcrpy

# %% [markdown]
# ## Enter the input parameters

# %%
Rad="Co-60"                # radionuclide
pmf_1="1"                  # relative fraction of the radionulide
N = 1000                   # number of Monte Carlo trials
kB =1.0e-5                 # Birks constant in cm keV-1
V = 10                     # volume of scintillator in mL

lsCocktail = "Ultima Gold" # type of LS cocktail
micellCorr = True          # activate Micelle correction
frac_aq = 1/10             # aqueous fraction
solvant = "HCl"            # type of solvant
solvant_conc = 0.1         # concentration of solvant mol/L
t_W = 50                   # coincidence resolving time ns
t_EXT = 100                # extended dead time µs
quantum_effA = 0.25        # quantum efficiency of PMT A
quantum_effB = 0.25        # quantum efficiency of PMT B
quantum_effC = 0.25        # quantum efficiency of PMT C

# modification of advanced parameters
tdcrpy.TDCR_model_lib.modifyTau(int(t_W))
tdcrpy.TDCR_model_lib.modifyDeadTime(int(t_EXT))
tdcrpy.TDCR_model_lib.modifyEffQ(str(quantum_effA)+","+str(quantum_effB )+","+str(quantum_effC))
tdcrpy.TDCR_model_lib.modifySolvantType(solvant)
tdcrpy.TDCR_model_lib.modifySolvantConc(solvant_conc)
tdcrpy.TDCR_model_lib.modifyMicCorr(micellCorr)
tdcrpy.TDCR_model_lib.modifyLScocktail(lsCocktail, frac_aq, solvantType=solvant, solvantConc=solvant_conc)
# Out:
# QUENCHING NUMERICAL CALCULATION
# 	Number of bins to discretize
# 	the linear energy space
# 	for quenching calculation:
# 	for electrons = 1000 bins
# 	the stopping power model at low energy = tan_xia
# 	for alphas = 1000 bins
# 	Chou quenching parameter 0.0 cm2/MeV2
#
# PROPERTIES OF THE SCINTILLATOR
# 	Liquid scintillation cocktail = Ultima Gold
# 	acqueous fraction = 0.1 (Type: HCl, 0.1 mol/L)
# 	Density = 0.9817900800899254 g/cm3
# 	Z = 3.2603, A = 5.9524
# 	Atomic fraction: H=0.5795, C=0.3517, N=0.0008, O=0.0647
# 	                 P=0.0023, S=0.0004, Na=0.0004, Cl=0.0001
# 	Micelle correction activated
# 	Density = 2.0 nm
#
# OPTICAL PROPERTIES
# 	Quantum efficiency of PMT A = 0.250
# 	Quantum efficiency of PMT B = 0.250
# 	Quantum efficiency of PMT C = 0.250
#
# PROPERTIES OF THE COUNTER
# 	Coincidence resolving time = 50 ns
# 	Extended dead time = 100.0 µs
# 	Measurement time = 20.0 min

# %% [markdown]
# ## Detection efficiencies given the free parameter

# %%
mode = "eff"               # ask for efficiency calculation
L = 5.1                    # free parameter in keV-1 (scintillation light yield) 
result1 = tdcrpy.TDCRPy.TDCRPy(L, Rad, pmf_1, N, kB, V, mode)

# %%
print(f"efficiency S = {round(result1[0],4)} +/- {round(result1[1],4)}")
print(f"efficiency D = {round(result1[2],4)} +/- {round(result1[3],4)}")
print(f"efficiency T = {round(result1[4],4)} +/- {round(result1[5],4)}")
print(f"efficiency AB = {round(result1[6],4)} +/- {round(result1[7],4)}")
print(f"efficiency BC = {round(result1[8],4)} +/- {round(result1[9],4)}")
print(f"efficiency AC = {round(result1[10],4)} +/- {round(result1[11],4)}")
print(f"efficiency D (C/N system) = {round(result1[12],4)} +/- {round(result1[13],4)}")
# Out:
# efficiency S = 0.9797 +/- 0.004
# efficiency D = 0.9682 +/- 0.0049
# efficiency T = 0.9482 +/- 0.0061
# efficiency AB = 0.9549 +/- 0.0056
# efficiency BC = 0.9549 +/- 0.0056
# efficiency AC = 0.9549 +/- 0.0056
# efficiency D (C/N system) = 0.9647 +/- 0.0051

# %% [markdown]
# ## Detection efficiencies given the measured TDCR parameter

# %% [markdown]
# ### Case of global TDCR parameter

# %%
TD = 0.977667386529166     # TDCR parameter
minL = 0.01                # minimum light yield (keV-1)
maxL = 20                  # maximum light yield (keV-1)

# %%
result2 = tdcrpy.TDCRPy.eff(TD, Rad, pmf_1, kB, V, N, Lbounds=(minL, maxL))
# Out:
# [11.61129, 0.0, 0.0]
# [11.61129, 0.0, 0.0]
# [11.61129, 0.0, 0.0]
# [11.61129, 0.0, 0.0]
# [11.61129, 0.0, 0.0]
# [11.61129, 0.0, 0.0]
# [11.61129, 0.0, 0.0]
# [11.61129, 0.0, 0.0]
# [11.61129, 0.0, 0.0]
# [11.61129, 0.0, 0.0]
# [11.61129, 0.0, 0.0]
# [11.61129, 0.0, 0.0]
# [11.61129, 0.0, 0.0]
# [11.61129, 0.0, 0.0]
# [11.61129, 0.0, 0.0]
# global free parameter = 4.962979303157702 keV-1
# [11.61129, 0.0, 0.0]

# %%
print(f"global free parameter = {round(result2[0],4)} keV-1")
print(f"global free parameter (PMT A) = {round(result2[1][0],4)} keV-1")
print(f"global free parameter (PMT B) = {round(result2[1][1],4)} keV-1")
print(f"global free parameter (PMT C) = {round(result2[1][2],4)} keV-1")
print(f"efficiency S = {round(result2[2],4)} +/- {round(result2[3],4)}")
print(f"efficiency D = {round(result2[4],4)} +/- {round(result2[5],4)}")
print(f"efficiency T = {round(result2[6],4)} +/- {round(result2[7],4)}")
print(f"efficiency AB = {round(result2[6],4)} +/- {round(result2[7],4)}")
print(f"efficiency BC = {round(result2[8],4)} +/- {round(result2[9],4)}")
print(f"efficiency AC = {round(result2[10],4)} +/- {round(result2[11],4)}")
print(f"efficiency D (C/N system) = {round(result2[14],4)} +/- {round(result2[15],4)}")
# Out:
# global free parameter = 4.963 keV-1
# global free parameter (PMT A) = 4.963 keV-1
# global free parameter (PMT B) = 4.963 keV-1
# global free parameter (PMT C) = 4.963 keV-1
# efficiency S = 0.985 +/- 0.003
# efficiency D = 0.9708 +/- 0.0045
# efficiency T = 0.9491 +/- 0.006
# efficiency AB = 0.9491 +/- 0.006
# efficiency BC = 0.9563 +/- 0.0054
# efficiency AC = 0.9563 +/- 0.0054
# efficiency D (C/N system) = 0.967 +/- 0.0048

# %% [markdown]
# ### Case of specific TDCR parameters

# %%
TD = 0.977667386529166     # TDCR parameter
TAB = 0.992232838598821    # TDCR parameter T/AB
TBC = 0.992343419459002    # TDCR parameter T/BC
TAC = 0.99275350064608     # TDCR parameter T/AC
minL = 0.01                # minimum light yield (keV-1)
maxL = 20                  # maximum light yield (keV-1)

# %%
result3 = tdcrpy.TDCRPy.eff([TD, TAB, TBC, TAC], Rad, pmf_1, kB, V, N, Lbounds=(minL, maxL))
# Out:
# [107.6112, 0.0, 0.0]
# [107.6112, 0.0, 0.0]
# [107.6112, 0.0, 0.0]
# [107.6112, 0.0, 0.0]
# [107.6112, 0.0, 0.0]
# [107.6112, 0.0, 0.0]
# [107.6112, 0.0, 0.0]
# [107.6112, 0.0, 0.0]
# [107.6112, 0.0, 0.0]
# [107.6112, 0.0, 0.0]
# [107.6112, 0.0, 0.0]
# [107.6112, 0.0, 0.0]
# [107.6112, 0.0, 0.0]
# [107.6112, 0.0, 0.0]
# [107.6112, 0.0, 0.0]
# [107.6112, 0.0, 0.0]
# [107.6112, 0.0, 0.0]
# [107.6112, 0.0, 0.0]
# [107.6112, 0.0, 0.0]
# [107.6112, 0.0, 0.0]
# global free parameter = 19.99799582098737 keV-1
# [107.6112, 0.0, 0.0]
# [107.6112, 0.0, 0.0]
# [107.6112, 0.0, 0.0]
# [107.6112, 0.0, 0.0]
# [107.6112, 0.0, 0.0]
# [107.6112, 0.0, 0.0]
# [107.6112, 0.0, 0.0]
# [107.6112, 0.0, 0.0]
# [107.6112, 0.0, 0.0]
# [107.6112, 0.0, 0.0]
# [107.6112, 0.0, 0.0]
# [107.6112, 0.0, 0.0]
# [107.6112, 0.0, 0.0]
# [107.6112, 0.0, 0.0]
# [107.6112, 0.0, 0.0]
# [107.6112, 0.0, 0.0]
# [107.6112, 0.0, 0.0]
# [107.6112, 0.0, 0.0]
# [107.6112, 0.0, 0.0]
# [107.6112, 0.0, 0.0]
# [107.6112, 0.0, 0.0]
# [107.6112, 0.0, 0.0]
# [107.6112, 0.0, 0.0]
# [107.6112, 0.0, 0.0]
# [107.6112, 0.0, 0.0]
# [107.6112, 0.0, 0.0]
# [107.6112, 0.0, 0.0]
# [107.6112, 0.0, 0.0]
# [107.6112, 0.0, 0.0]
# [107.6112, 0.0, 0.0]
# [107.6112, 0.0, 0.0]
# [107.6112, 0.0, 0.0]
# [107.6112, 0.0, 0.0]
# [107.6112, 0.0, 0.0]
# [107.6112, 0.0, 0.0]
# [107.6112, 0.0, 0.0]
# [107.6112, 0.0, 0.0]
# [107.6112, 0.0, 0.0]
# [107.6112, 0.0, 0.0]
# free parameters = [28.35619094 23.5390155  22.60502038] keV-1
# [107.6112, 0.0, 0.0]

# %%
print(f"Global free parameter = {round(result3[0],4)} keV-1")
print(f"free parameter of PMT A = {round(result3[1][0],4)} keV-1")
print(f"free parameter of PMT B = {round(result3[1][1],4)} keV-1")
print(f"free parameter of PMT C = {round(result3[1][2],4)} keV-1")
print(f"efficiency S = {round(result3[2],4)} +/- {round(result3[3],4)}")
print(f"efficiency D = {round(result3[4],4)} +/- {round(result3[5],4)}")
print(f"efficiency T = {round(result3[6],4)} +/- {round(result3[7],4)}")
print(f"efficiency AB = {round(result3[8],4)} +/- {round(result3[9],4)}")
print(f"efficiency BC = {round(result3[10],4)} +/- {round(result3[11],4)}")
print(f"efficiency AC = {round(result3[12],4)} +/- {round(result3[13],4)}")
print(f"efficiency D (C/N system) = {round(result3[14],4)} +/- {round(result3[15],4)}")
# Out:
# Global free parameter = 3.6275 keV-1
# free parameter of PMT A = 3.6275 keV-1
# free parameter of PMT B = 3.6275 keV-1
# free parameter of PMT C = 3.6275 keV-1
# efficiency S = 0.9834 +/- 0.0032
# efficiency D = 0.9697 +/- 0.0047
# efficiency T = 0.948 +/- 0.006
# efficiency AB = 0.9552 +/- 0.0055
# efficiency BC = 0.9552 +/- 0.0055
# efficiency AC = 0.9552 +/- 0.0055
# efficiency D (C/N system) = 0.9661 +/- 0.0049

# %% [markdown]
# ### Case of radionuclide mixture

# %%
L = 1.2                    # free parameter in keV-1
Rad="Co-60, H-3"           # radionuclides
pmf_1="0.8, 0.2"                  # relatives fractions of the radionulides

# %%
result4 = tdcrpy.TDCRPy.TDCRPy(L, Rad, pmf_1, N, kB, V, mode)

# %%
print(f"efficiency S = {round(result4[0],4)} +/- {round(result4[1],4)}")
print(f"efficiency D = {round(result4[2],4)} +/- {round(result4[3],4)}")
print(f"efficiency T = {round(result4[4],4)} +/- {round(result4[5],4)}")
print(f"efficiency AB = {round(result4[6],4)} +/- {round(result4[7],4)}")
print(f"efficiency BC = {round(result4[8],4)} +/- {round(result4[9],4)}")
print(f"efficiency AC = {round(result4[10],4)} +/- {round(result4[11],4)}")
print(f"efficiency D (C/N system) = {round(result4[12],4)} +/- {round(result4[13],4)}")
# Out:
# efficiency S = 0.8736 +/- 0.0082
# efficiency D = 0.7811 +/- 0.0113
# efficiency T = 0.6917 +/- 0.0131
# efficiency AB = 0.7215 +/- 0.0123
# efficiency BC = 0.7215 +/- 0.0123
# efficiency AC = 0.7215 +/- 0.0123
# efficiency D (C/N system) = 0.7641 +/- 0.0116

# %%
TD = 0.977667386529166     # TDCR parameter

# %%
result5 = tdcrpy.TDCRPy.eff(TD, Rad, pmf_1, kB, V, N, Lbounds=(minL, maxL))
# Out:
# [2.44346, 0.0, 0.0]
# [2.44346, 0.0, 0.0]
# [2.44346, 0.0, 0.0]
# [2.44346, 0.0, 0.0]
# [2.44346, 0.0, 0.0]
# [2.44346, 0.0, 0.0]
# [2.44346, 0.0, 0.0]
# [2.44346, 0.0, 0.0]
# [2.44346, 0.0, 0.0]
# [2.44346, 0.0, 0.0]
# [2.44346, 0.0, 0.0]
# [2.44346, 0.0, 0.0]
# [2.44346, 0.0, 0.0]
# [2.44346, 0.0, 0.0]
# [2.44346, 0.0, 0.0]
# [2.44346, 0.0, 0.0]
# [2.44346, 0.0, 0.0]
# [2.44346, 0.0, 0.0]
# [2.44346, 0.0, 0.0]
# [2.44346, 0.0, 0.0]
# global free parameter = 19.99829804516288 keV-1
# [2.44346, 0.0, 0.0]

# %%
print(f"Global free parameter = {round(result5[0],4)} keV-1")
print(f"free parameter of PMT A = {round(result5[1][0],4)} keV-1")
print(f"free parameter of PMT B = {round(result5[1][1],4)} keV-1")
print(f"free parameter of PMT C = {round(result5[1][2],4)} keV-1")
print(f"efficiency S = {round(result5[2],4)} +/- {round(result5[3],4)}")
print(f"efficiency D = {round(result5[4],4)} +/- {round(result5[5],4)}")
print(f"efficiency T = {round(result5[6],4)} +/- {round(result5[7],4)}")
print(f"efficiency AB = {round(result5[8],4)} +/- {round(result5[9],4)}")
print(f"efficiency BC = {round(result5[10],4)} +/- {round(result5[11],4)}")
print(f"efficiency AC = {round(result5[12],4)} +/- {round(result5[13],4)}")
print(f"efficiency D (C/N system) = {round(result5[14],4)} +/- {round(result5[15],4)}")
# Out:
# Global free parameter = 19.9983 keV-1
# free parameter of PMT A = 19.9983 keV-1
# free parameter of PMT B = 19.9983 keV-1
# free parameter of PMT C = 19.9983 keV-1
# efficiency S = 0.9759 +/- 0.0043
# efficiency D = 0.9607 +/- 0.0052
# efficiency T = 0.931 +/- 0.0068
# efficiency AB = 0.9409 +/- 0.0062
# efficiency BC = 0.9409 +/- 0.0062
# efficiency AC = 0.9409 +/- 0.0062
# efficiency D (C/N system) = 0.9555 +/- 0.0055
