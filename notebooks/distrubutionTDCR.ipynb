# %% [markdown]
# # Distribution of TDCR measurements

# %%
pip install TDCRPy==2.20.7
# Out:
# Requirement already satisfied: TDCRPy==2.20.7 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (2.20.7)
# Requirement already satisfied: numpy in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.7) (2.4.6)
# Requirement already satisfied: scipy in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.7) (1.18.0)
# Requirement already satisfied: matplotlib in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.7) (3.11.0)
# Requirement already satisfied: tqdm in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.7) (4.68.3)
# Requirement already satisfied: numba in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.7) (0.65.1)
# Requirement already satisfied: setuptools in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.7) (82.0.1)
# Requirement already satisfied: contourpy>=1.0.1 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.7) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.7) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.7) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.7) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.7) (26.2)
# Requirement already satisfied: pillow>=9 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.7) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.7) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.7) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from python-dateutil>=2.7->matplotlib->TDCRPy==2.20.7) (1.17.0)
# Requirement already satisfied: llvmlite<0.48,>=0.47.0dev0 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from numba->TDCRPy==2.20.7) (0.47.0)
# Requirement already satisfied: colorama in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from tqdm->TDCRPy==2.20.7) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import tdcrpy as td
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt

# %% [markdown]
# ## Record the decay histories in temporary files

# %%
mode = "eff"                # ask for efficiency calculation
Rad="Cd-109"                # radionuclides
pmf_1="1"                   # relatives fractions of the radionulides
N = 1500                    # number of Monte Carlo trials
kB =1.0e-5                  # Birks constant in cm keV-1
V = 10                      # volume of scintillator in mL
L=1                         # free parameter in keV-1

out = td.TDCRPy.TDCRPy(1, Rad, pmf_1, N, kB, V, mode, record=True, barp=True)
# Out:
#  ______  ______  ______ _______  ________
# |__  __||  ___ \|  ___||  ___ | |  ____ |
#   | |   | |  | || |    | |  | | | |___| |___     ___
#   | |   | |  | || |    | |__| | |  _____|\  \   |  |
#   | |   | |__| || |____|  __  \ | |       \  \  |  |
#   |_|   |_____/ |_____||_|  \__\|_|        \  \_|  |
#   +++++++++++++++++++++++++++++++++++++++++/      /
#   ________________________________________/      /
#  |______________________________________________/
#
#
# version 2.20.7
# BIPM 2023 - license MIT
# distribution: https://pypi.org/project/TDCRPy
# developement: https://github.com/RomainCoulon/TDCRPy
#
# start calculation...
# Processing:   0%|          | 0/1500 [00:00<?, ? decays/s]
# Processing:   0%|          | 6/1500 [00:00<01:30, 16.45 decays/s]
# Processing:   1%|          | 12/1500 [00:00<00:53, 27.81 decays/s]
# Processing:   1%|▏         | 21/1500 [00:00<00:33, 43.68 decays/s]
# Processing:   2%|▏         | 34/1500 [00:00<00:22, 64.31 decays/s]
# Processing:   3%|▎         | 42/1500 [00:00<00:22, 64.22 decays/s]
# Processing:   3%|▎         | 50/1500 [00:00<00:24, 59.74 decays/s]
# Processing:   4%|▍         | 58/1500 [00:01<00:22, 64.19 decays/s]
# Processing:   5%|▍         | 68/1500 [00:01<00:19, 72.55 decays/s]
# Processing:   5%|▌         | 77/1500 [00:01<00:18, 76.50 decays/s]
# Processing:   6%|▌         | 86/1500 [00:01<00:18, 76.61 decays/s]
# Processing:   6%|▋         | 94/1500 [00:01<00:19, 70.33 decays/s]
# Processing:   7%|▋         | 102/1500 [00:01<00:19, 71.03 decays/s]
# Processing:   8%|▊         | 113/1500 [00:01<00:17, 78.81 decays/s]
# Processing:   8%|▊         | 124/1500 [00:01<00:15, 86.44 decays/s]
# Processing:   9%|▉         | 133/1500 [00:01<00:16, 84.24 decays/s]
# Processing:   9%|▉         | 142/1500 [00:02<00:16, 82.19 decays/s]
# Processing:  10%|█         | 151/1500 [00:02<00:19, 68.89 decays/s]
# Processing:  11%|█         | 161/1500 [00:02<00:18, 74.37 decays/s]
# Processing:  11%|█▏        | 169/1500 [00:02<00:18, 72.67 decays/s]
# Processing:  12%|█▏        | 177/1500 [00:02<00:18, 71.77 decays/s]
# Processing:  12%|█▏        | 185/1500 [00:02<00:20, 65.15 decays/s]
# Processing:  13%|█▎        | 192/1500 [00:02<00:20, 64.74 decays/s]
# Processing:  14%|█▎        | 204/1500 [00:03<00:16, 76.58 decays/s]
# Processing:  14%|█▍        | 215/1500 [00:03<00:15, 84.06 decays/s]
# Processing:  15%|█▌        | 226/1500 [00:03<00:14, 88.19 decays/s]
# Processing:  16%|█▌        | 235/1500 [00:03<00:15, 81.50 decays/s]
# Processing:  16%|█▋        | 244/1500 [00:03<00:15, 79.67 decays/s]
# Processing:  17%|█▋        | 253/1500 [00:03<00:15, 80.77 decays/s]
# Processing:  17%|█▋        | 262/1500 [00:03<00:15, 80.30 decays/s]
# Processing:  18%|█▊        | 271/1500 [00:03<00:16, 74.92 decays/s]
# Processing:  19%|█▊        | 280/1500 [00:03<00:15, 78.25 decays/s]
# Processing:  19%|█▉        | 288/1500 [00:04<00:16, 73.86 decays/s]
# Processing:  20%|█▉        | 296/1500 [00:04<00:17, 69.32 decays/s]
# Processing:  20%|██        | 306/1500 [00:04<00:15, 75.37 decays/s]
# Processing:  21%|██        | 314/1500 [00:04<00:15, 74.95 decays/s]
# Processing:  21%|██▏       | 322/1500 [00:04<00:15, 76.28 decays/s]
# Processing:  22%|██▏       | 331/1500 [00:04<00:15, 77.51 decays/s]
# Processing:  23%|██▎       | 343/1500 [00:04<00:13, 88.76 decays/s]
# Processing:  23%|██▎       | 352/1500 [00:04<00:12, 88.65 decays/s]
# Processing:  24%|██▍       | 363/1500 [00:04<00:13, 86.38 decays/s]
# Processing:  25%|██▌       | 378/1500 [00:05<00:11, 101.07 decays/s]
# Processing:  26%|██▌       | 389/1500 [00:05<00:12, 89.87 decays/s]
# Processing:  27%|██▋       | 399/1500 [00:05<00:12, 89.10 decays/s]
# Processing:  27%|██▋       | 409/1500 [00:05<00:12, 87.13 decays/s]
# Processing:  28%|██▊       | 420/1500 [00:05<00:11, 92.31 decays/s]
# Processing:  29%|██▊       | 430/1500 [00:05<00:12, 86.97 decays/s]
# Processing:  29%|██▉       | 439/1500 [00:05<00:12, 86.85 decays/s]
# Processing:  30%|██▉       | 448/1500 [00:05<00:13, 76.37 decays/s]
# Processing:  30%|███       | 456/1500 [00:06<00:15, 66.27 decays/s]
# Processing:  31%|███▏      | 469/1500 [00:06<00:12, 79.31 decays/s]
# Processing:  32%|███▏      | 478/1500 [00:06<00:13, 75.11 decays/s]
# Processing:  32%|███▏      | 487/1500 [00:06<00:13, 74.44 decays/s]
# Processing:  33%|███▎      | 495/1500 [00:06<00:14, 71.18 decays/s]
# Processing:  34%|███▎      | 506/1500 [00:06<00:12, 80.59 decays/s]
# Processing:  35%|███▍      | 518/1500 [00:06<00:10, 89.85 decays/s]
# Processing:  35%|███▌      | 528/1500 [00:06<00:11, 81.36 decays/s]
# Processing:  36%|███▌      | 537/1500 [00:07<00:11, 83.44 decays/s]
# Processing:  36%|███▋      | 546/1500 [00:07<00:12, 76.26 decays/s]
# Processing:  37%|███▋      | 554/1500 [00:07<00:12, 75.00 decays/s]
# Processing:  38%|███▊      | 563/1500 [00:07<00:12, 72.65 decays/s]
# Processing:  38%|███▊      | 571/1500 [00:07<00:13, 70.13 decays/s]
# Processing:  39%|███▊      | 579/1500 [00:07<00:13, 68.44 decays/s]
# Processing:  39%|███▉      | 587/1500 [00:07<00:13, 68.34 decays/s]
# Processing:  40%|███▉      | 595/1500 [00:07<00:13, 68.04 decays/s]
# Processing:  40%|████      | 604/1500 [00:08<00:12, 72.87 decays/s]
# Processing:  41%|████      | 612/1500 [00:08<00:13, 65.41 decays/s]
# Processing:  41%|████▏     | 622/1500 [00:08<00:12, 72.23 decays/s]
# Processing:  42%|████▏     | 631/1500 [00:08<00:11, 73.98 decays/s]
# Processing:  43%|████▎     | 641/1500 [00:08<00:10, 78.93 decays/s]
# Processing:  43%|████▎     | 650/1500 [00:08<00:10, 78.23 decays/s]
# Processing:  44%|████▍     | 659/1500 [00:08<00:10, 80.17 decays/s]
# Processing:  45%|████▍     | 668/1500 [00:08<00:11, 70.94 decays/s]
# Processing:  45%|████▌     | 680/1500 [00:09<00:09, 82.91 decays/s]
# Processing:  46%|████▌     | 689/1500 [00:09<00:10, 77.19 decays/s]
# Processing:  47%|████▋     | 698/1500 [00:09<00:10, 73.91 decays/s]
# Processing:  47%|████▋     | 709/1500 [00:09<00:09, 80.01 decays/s]
# Processing:  48%|████▊     | 718/1500 [00:09<00:10, 75.72 decays/s]
# Processing:  49%|████▊     | 729/1500 [00:09<00:09, 83.65 decays/s]
# Processing:  49%|████▉     | 738/1500 [00:09<00:09, 78.76 decays/s]
# Processing:  50%|█████     | 750/1500 [00:09<00:08, 87.71 decays/s]
# Processing:  51%|█████     | 762/1500 [00:10<00:07, 94.56 decays/s]
# Processing:  51%|█████▏    | 772/1500 [00:10<00:08, 86.79 decays/s]
# Processing:  52%|█████▏    | 781/1500 [00:10<00:08, 87.43 decays/s]
# Processing:  53%|█████▎    | 790/1500 [00:10<00:08, 80.79 decays/s]
# Processing:  53%|█████▎    | 799/1500 [00:10<00:09, 75.16 decays/s]
# Processing:  54%|█████▍    | 809/1500 [00:10<00:08, 81.26 decays/s]
# Processing:  55%|█████▍    | 818/1500 [00:10<00:08, 78.73 decays/s]
# Processing:  55%|█████▌    | 827/1500 [00:10<00:08, 79.42 decays/s]
# Processing:  56%|█████▌    | 837/1500 [00:10<00:07, 83.92 decays/s]
# Processing:  56%|█████▋    | 847/1500 [00:11<00:07, 87.59 decays/s]
# Processing:  57%|█████▋    | 856/1500 [00:11<00:08, 76.74 decays/s]
# Processing:  58%|█████▊    | 866/1500 [00:11<00:07, 80.24 decays/s]
# Processing:  58%|█████▊    | 875/1500 [00:11<00:07, 80.01 decays/s]
# Processing:  59%|█████▉    | 884/1500 [00:11<00:07, 80.29 decays/s]
# Processing:  60%|█████▉    | 894/1500 [00:11<00:07, 81.49 decays/s]
# Processing:  60%|██████    | 903/1500 [00:11<00:07, 82.73 decays/s]
# Processing:  61%|██████    | 912/1500 [00:11<00:07, 77.47 decays/s]
# Processing:  61%|██████▏   | 920/1500 [00:12<00:07, 74.87 decays/s]
# Processing:  62%|██████▏   | 931/1500 [00:12<00:06, 81.45 decays/s]
# Processing:  63%|██████▎   | 940/1500 [00:12<00:07, 77.73 decays/s]
# Processing:  63%|██████▎   | 948/1500 [00:12<00:07, 77.48 decays/s]
# Processing:  64%|██████▍   | 961/1500 [00:12<00:05, 90.68 decays/s]
# Processing:  65%|██████▍   | 971/1500 [00:12<00:06, 86.86 decays/s]
# Processing:  65%|██████▌   | 980/1500 [00:12<00:06, 86.51 decays/s]
# Processing:  66%|██████▌   | 993/1500 [00:12<00:05, 96.60 decays/s]
# Processing:  67%|██████▋   | 1003/1500 [00:12<00:05, 91.83 decays/s]
# Processing:  68%|██████▊   | 1014/1500 [00:13<00:05, 93.70 decays/s]
# Processing:  68%|██████▊   | 1025/1500 [00:13<00:05, 90.29 decays/s]
# Processing:  69%|██████▉   | 1035/1500 [00:13<00:05, 79.99 decays/s]
# Processing:  70%|██████▉   | 1044/1500 [00:13<00:06, 67.18 decays/s]
# Processing:  70%|███████   | 1052/1500 [00:13<00:07, 60.85 decays/s]
# Processing:  71%|███████   | 1060/1500 [00:13<00:06, 64.22 decays/s]
# Processing:  71%|███████   | 1067/1500 [00:13<00:06, 63.32 decays/s]
# Processing:  72%|███████▏  | 1074/1500 [00:14<00:06, 64.77 decays/s]
# Processing:  72%|███████▏  | 1083/1500 [00:14<00:05, 71.19 decays/s]
# Processing:  73%|███████▎  | 1091/1500 [00:14<00:05, 70.03 decays/s]
# Processing:  73%|███████▎  | 1099/1500 [00:14<00:05, 71.73 decays/s]
# Processing:  74%|███████▍  | 1108/1500 [00:14<00:05, 75.53 decays/s]
# Processing:  75%|███████▍  | 1119/1500 [00:14<00:04, 85.11 decays/s]
# Processing:  75%|███████▌  | 1128/1500 [00:14<00:04, 76.52 decays/s]
# Processing:  76%|███████▌  | 1139/1500 [00:14<00:04, 82.88 decays/s]
# Processing:  77%|███████▋  | 1148/1500 [00:14<00:04, 79.73 decays/s]
# Processing:  77%|███████▋  | 1157/1500 [00:15<00:04, 75.47 decays/s]
# Processing:  78%|███████▊  | 1166/1500 [00:15<00:04, 79.00 decays/s]
# Processing:  78%|███████▊  | 1176/1500 [00:15<00:03, 84.55 decays/s]
# Processing:  79%|███████▉  | 1185/1500 [00:15<00:04, 71.32 decays/s]
# Processing:  80%|███████▉  | 1193/1500 [00:15<00:04, 68.95 decays/s]
# Processing:  80%|████████  | 1201/1500 [00:15<00:04, 67.61 decays/s]
# Processing:  81%|████████  | 1211/1500 [00:15<00:03, 74.00 decays/s]
# Processing:  81%|████████▏ | 1222/1500 [00:15<00:03, 81.78 decays/s]
# Processing:  82%|████████▏ | 1231/1500 [00:16<00:03, 79.37 decays/s]
# Processing:  83%|████████▎ | 1241/1500 [00:16<00:03, 83.87 decays/s]
# Processing:  83%|████████▎ | 1251/1500 [00:16<00:02, 87.84 decays/s]
# Processing:  84%|████████▍ | 1260/1500 [00:16<00:02, 87.00 decays/s]
# Processing:  85%|████████▍ | 1269/1500 [00:16<00:02, 85.94 decays/s]
# Processing:  85%|████████▌ | 1278/1500 [00:16<00:03, 72.05 decays/s]
# Processing:  86%|████████▌ | 1286/1500 [00:16<00:02, 73.82 decays/s]
# Processing:  87%|████████▋ | 1301/1500 [00:16<00:02, 93.02 decays/s]
# Processing:  87%|████████▋ | 1311/1500 [00:16<00:02, 88.64 decays/s]
# Processing:  89%|████████▊ | 1330/1500 [00:17<00:01, 113.67 decays/s]
# Processing:  89%|████████▉ | 1342/1500 [00:17<00:01, 96.86 decays/s]
# Processing:  90%|█████████ | 1353/1500 [00:17<00:01, 95.73 decays/s]
# Processing:  91%|█████████ | 1364/1500 [00:17<00:01, 96.53 decays/s]
# Processing:  92%|█████████▏| 1374/1500 [00:17<00:01, 80.94 decays/s]
# Processing:  92%|█████████▏| 1383/1500 [00:17<00:01, 82.23 decays/s]
# Processing:  93%|█████████▎| 1392/1500 [00:17<00:01, 78.23 decays/s]
# Processing:  93%|█████████▎| 1401/1500 [00:17<00:01, 80.86 decays/s]
# Processing:  94%|█████████▍| 1412/1500 [00:18<00:00, 88.06 decays/s]
# Processing:  95%|█████████▌| 1425/1500 [00:18<00:00, 92.94 decays/s]
# Processing:  96%|█████████▌| 1435/1500 [00:18<00:00, 68.67 decays/s]
# Processing:  96%|█████████▋| 1444/1500 [00:18<00:00, 67.76 decays/s]
# Processing:  97%|█████████▋| 1456/1500 [00:18<00:00, 77.72 decays/s]
# Processing:  98%|█████████▊| 1465/1500 [00:18<00:00, 73.05 decays/s]
# Processing:  98%|█████████▊| 1473/1500 [00:19<00:00, 61.39 decays/s]
# Processing:  99%|█████████▊| 1481/1500 [00:19<00:00, 64.82 decays/s]
# Processing:  99%|█████████▉| 1489/1500 [00:19<00:00, 65.63 decays/s]
# Processing: 100%|██████████| 1500/1500 [00:19<00:00, 77.49 decays/s]

# %% [markdown]
# ## Read initial energy from the decay process

# %%
temp1, temp2, temp3, temp4 = td.TDCR_model_lib.read_temp_files()

ee_vec, eg_vec, ep_vec, ea_vec = td.TDCR_model_lib.energyVectors1(temp1)
nbins=50
plt.figure("1")
plt.hist(eg_vec, bins=nbins, edgecolor='none',density=True,label='photons')
plt.hist(ee_vec, bins=nbins, edgecolor='none',density=True,label='electrons')
plt.hist(ep_vec, bins=nbins, edgecolor='none',density=True,label='positrons')
plt.hist(ea_vec, bins=nbins, edgecolor='none',density=True,label='alphas')
plt.title('Distribution of Initial Energies')
plt.xlabel('Energy /keV')
plt.ylabel('Frequency')
plt.legend()
plt.show()
# Out:
# g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages\numpy\lib\_histograms_impl.py:897: RuntimeWarning: invalid value encountered in divide
#   return n / db / n.sum(), bin_edges

# %% [markdown]
# ## Read deposited energy in the scintillator

# %%
ee_vec, ep_vec, ea_vec = td.TDCR_model_lib.energyVectors2(temp2)
nbins=50
plt.figure("2")
plt.hist(ee_vec, bins=nbins, edgecolor='none',density=True,label='electrons')
plt.hist(ep_vec, bins=nbins, edgecolor='none',density=True,label='positrons')
plt.hist(ea_vec, bins=nbins, edgecolor='none',density=True,label='alphas')
plt.title('Distribution of Deposited Energies')
plt.xlabel('Energy /keV')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %% [markdown]
# ## Read quenched deposited energy in the scintillator

# %%
ee_vec = td.TDCR_model_lib.energyVectors3(temp3)
nbins=50
plt.figure("3")
plt.hist(ee_vec, bins=nbins, edgecolor='none',density=True,label='electrons')
plt.title('Distribution of Quenched Deposited Energies')
plt.xlabel('Energy /keV')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %% [markdown]
# ## Read detection probabilities per decay event

# %%
s_vec, d_vec, t_vec = td.TDCR_model_lib.effVector(temp4)
nbins=50
plt.figure("4")
plt.hist(s_vec, bins=nbins, edgecolor='none',density=True,label='single events')
plt.hist(d_vec, bins=nbins, edgecolor='none',density=True,label='double coincidences')
plt.hist(t_vec, bins=nbins, edgecolor='none',density=True,label='triple coincidences')
plt.title('Distribution of detection probabilities per decay event')
plt.xlabel('Detection probability')
plt.ylabel('Frequency')
plt.legend()
plt.show()
