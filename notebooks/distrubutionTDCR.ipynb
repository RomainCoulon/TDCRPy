# %% [markdown]
# # Distribution of TDCR measurements

# %%
pip install TDCRPy==2.20.10
# Out:
# Requirement already satisfied: TDCRPy==2.20.8 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (2.20.8)
# Requirement already satisfied: numpy in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.8) (2.4.6)
# Requirement already satisfied: scipy in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.8) (1.18.0)
# Requirement already satisfied: matplotlib in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.8) (3.11.0)
# Requirement already satisfied: tqdm in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.8) (4.68.3)
# Requirement already satisfied: numba in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.8) (0.65.1)
# Requirement already satisfied: setuptools in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.8) (82.0.1)
# Requirement already satisfied: contourpy>=1.0.1 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.8) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.8) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.8) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.8) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.8) (26.2)
# Requirement already satisfied: pillow>=9 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.8) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.8) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.8) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from python-dateutil>=2.7->matplotlib->TDCRPy==2.20.8) (1.17.0)
# Requirement already satisfied: llvmlite<0.48,>=0.47.0dev0 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from numba->TDCRPy==2.20.8) (0.47.0)
# Requirement already satisfied: colorama in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from tqdm->TDCRPy==2.20.8) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import tdcrpy as td
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt

# %% [markdown]
# ## Record the decay histories in temporary files

# %%
mode = "eff"                # ask for efficiency calculation
Rad="Cd-109"                # radionuclides
pmf_1="1"                   # relatives fractions of the radionulides
N = 1500                    # number of Monte Carlo trials
kB =1.0e-5                  # Birks constant in cm keV-1
V = 10                      # volume of scintillator in mL
L=1                         # free parameter in keV-1

out = td.TDCRPy.TDCRPy(1, Rad, pmf_1, N, kB, V, mode, record=True, barp=True)
# Out:
#  ______  ______  ______ _______  ________
# |__  __||  ___ \|  ___||  ___ | |  ____ |
#   | |   | |  | || |    | |  | | | |___| |___     ___
#   | |   | |  | || |    | |__| | |  _____|\  \   |  |
#   | |   | |__| || |____|  __  \ | |       \  \  |  |
#   |_|   |_____/ |_____||_|  \__\|_|        \  \_|  |
#   +++++++++++++++++++++++++++++++++++++++++/      /
#   ________________________________________/      /
#  |______________________________________________/
#
#
# version 2.20.8
# BIPM 2023 - license MIT
# distribution: https://pypi.org/project/TDCRPy
# developement: https://github.com/RomainCoulon/TDCRPy
#
# start calculation...
# Processing:   0%|          | 0/1500 [00:00<?, ? decays/s]
# Processing:   0%|          | 6/1500 [00:00<00:34, 43.00 decays/s]
# Processing:   1%|          | 13/1500 [00:00<00:26, 55.60 decays/s]
# Processing:   1%|▏         | 19/1500 [00:00<00:26, 56.64 decays/s]
# Processing:   2%|▏         | 26/1500 [00:00<00:24, 60.87 decays/s]
# Processing:   2%|▏         | 37/1500 [00:00<00:18, 77.23 decays/s]
# Processing:   3%|▎         | 48/1500 [00:00<00:16, 85.44 decays/s]
# Processing:   4%|▍         | 60/1500 [00:00<00:14, 96.13 decays/s]
# Processing:   5%|▍         | 70/1500 [00:00<00:16, 87.84 decays/s]
# Processing:   5%|▌         | 81/1500 [00:01<00:15, 88.96 decays/s]
# Processing:   6%|▌         | 91/1500 [00:01<00:18, 74.24 decays/s]
# Processing:   7%|▋         | 100/1500 [00:01<00:18, 76.72 decays/s]
# Processing:   7%|▋         | 109/1500 [00:01<00:18, 76.70 decays/s]
# Processing:   8%|▊         | 117/1500 [00:01<00:18, 73.03 decays/s]
# Processing:   8%|▊         | 127/1500 [00:01<00:17, 77.94 decays/s]
# Processing:   9%|▉         | 135/1500 [00:01<00:17, 77.73 decays/s]
# Processing:  10%|▉         | 144/1500 [00:01<00:18, 73.29 decays/s]
# Processing:  10%|█         | 154/1500 [00:02<00:16, 80.17 decays/s]
# Processing:  11%|█         | 163/1500 [00:02<00:16, 79.55 decays/s]
# Processing:  12%|█▏        | 174/1500 [00:02<00:15, 87.49 decays/s]
# Processing:  12%|█▏        | 183/1500 [00:02<00:16, 81.55 decays/s]
# Processing:  13%|█▎        | 192/1500 [00:02<00:16, 78.05 decays/s]
# Processing:  13%|█▎        | 202/1500 [00:02<00:16, 76.47 decays/s]
# Processing:  14%|█▍        | 211/1500 [00:02<00:16, 79.53 decays/s]
# Processing:  15%|█▌        | 226/1500 [00:02<00:12, 98.21 decays/s]
# Processing:  16%|█▌        | 237/1500 [00:02<00:14, 85.38 decays/s]
# Processing:  16%|█▋        | 247/1500 [00:03<00:15, 80.77 decays/s]
# Processing:  17%|█▋        | 257/1500 [00:03<00:14, 84.62 decays/s]
# Processing:  18%|█▊        | 266/1500 [00:03<00:18, 68.05 decays/s]
# Processing:  19%|█▊        | 278/1500 [00:03<00:15, 77.37 decays/s]
# Processing:  19%|█▉        | 287/1500 [00:03<00:16, 73.50 decays/s]
# Processing:  20%|█▉        | 295/1500 [00:03<00:16, 72.42 decays/s]
# Processing:  20%|██        | 307/1500 [00:03<00:14, 80.32 decays/s]
# Processing:  21%|██        | 316/1500 [00:04<00:14, 79.13 decays/s]
# Processing:  22%|██▏       | 325/1500 [00:04<00:14, 78.88 decays/s]
# Processing:  22%|██▏       | 335/1500 [00:04<00:13, 84.05 decays/s]
# Processing:  23%|██▎       | 344/1500 [00:04<00:14, 81.82 decays/s]
# Processing:  24%|██▎       | 355/1500 [00:04<00:13, 87.90 decays/s]
# Processing:  24%|██▍       | 364/1500 [00:04<00:13, 83.31 decays/s]
# Processing:  25%|██▍       | 374/1500 [00:04<00:12, 87.38 decays/s]
# Processing:  26%|██▌       | 383/1500 [00:04<00:13, 81.00 decays/s]
# Processing:  26%|██▋       | 394/1500 [00:04<00:12, 88.50 decays/s]
# Processing:  27%|██▋       | 404/1500 [00:05<00:12, 88.54 decays/s]
# Processing:  28%|██▊       | 413/1500 [00:05<00:12, 87.03 decays/s]
# Processing:  28%|██▊       | 424/1500 [00:05<00:12, 84.60 decays/s]
# Processing:  29%|██▉       | 433/1500 [00:05<00:14, 74.74 decays/s]
# Processing:  29%|██▉       | 441/1500 [00:05<00:14, 73.82 decays/s]
# Processing:  30%|███       | 451/1500 [00:05<00:13, 80.24 decays/s]
# Processing:  31%|███       | 460/1500 [00:05<00:12, 82.20 decays/s]
# Processing:  31%|███▏      | 469/1500 [00:05<00:13, 77.34 decays/s]
# Processing:  32%|███▏      | 478/1500 [00:06<00:12, 80.07 decays/s]
# Processing:  33%|███▎      | 488/1500 [00:06<00:12, 83.88 decays/s]
# Processing:  33%|███▎      | 500/1500 [00:06<00:11, 85.53 decays/s]
# Processing:  34%|███▍      | 509/1500 [00:06<00:11, 84.54 decays/s]
# Processing:  35%|███▍      | 521/1500 [00:06<00:10, 92.62 decays/s]
# Processing:  35%|███▌      | 532/1500 [00:06<00:10, 93.35 decays/s]
# Processing:  36%|███▋      | 547/1500 [00:06<00:08, 106.95 decays/s]
# Processing:  37%|███▋      | 558/1500 [00:06<00:10, 94.11 decays/s]
# Processing:  38%|███▊      | 568/1500 [00:06<00:10, 91.68 decays/s]
# Processing:  39%|███▊      | 578/1500 [00:07<00:12, 75.79 decays/s]
# Processing:  39%|███▉      | 588/1500 [00:07<00:11, 79.34 decays/s]
# Processing:  40%|███▉      | 599/1500 [00:07<00:10, 86.77 decays/s]
# Processing:  41%|████      | 609/1500 [00:07<00:10, 81.64 decays/s]
# Processing:  42%|████▏     | 623/1500 [00:07<00:09, 92.19 decays/s]
# Processing:  42%|████▏     | 633/1500 [00:07<00:09, 90.04 decays/s]
# Processing:  43%|████▎     | 647/1500 [00:07<00:08, 100.35 decays/s]
# Processing:  44%|████▍     | 658/1500 [00:07<00:09, 91.37 decays/s]
# Processing:  45%|████▍     | 668/1500 [00:08<00:10, 76.44 decays/s]
# Processing:  45%|████▌     | 680/1500 [00:08<00:09, 86.03 decays/s]
# Processing:  46%|████▌     | 691/1500 [00:08<00:09, 88.52 decays/s]
# Processing:  47%|████▋     | 701/1500 [00:08<00:09, 79.92 decays/s]
# Processing:  47%|████▋     | 710/1500 [00:08<00:10, 74.75 decays/s]
# Processing:  48%|████▊     | 720/1500 [00:08<00:09, 80.39 decays/s]
# Processing:  49%|████▊     | 729/1500 [00:08<00:09, 81.14 decays/s]
# Processing:  49%|████▉     | 739/1500 [00:09<00:09, 81.30 decays/s]
# Processing:  50%|████▉     | 749/1500 [00:09<00:08, 83.82 decays/s]
# Processing:  51%|█████     | 758/1500 [00:09<00:08, 84.26 decays/s]
# Processing:  51%|█████     | 767/1500 [00:09<00:08, 85.72 decays/s]
# Processing:  52%|█████▏    | 777/1500 [00:09<00:08, 87.28 decays/s]
# Processing:  52%|█████▏    | 787/1500 [00:09<00:08, 87.34 decays/s]
# Processing:  53%|█████▎    | 801/1500 [00:09<00:06, 101.60 decays/s]
# Processing:  54%|█████▍    | 812/1500 [00:09<00:06, 99.08 decays/s]
# Processing:  55%|█████▌    | 826/1500 [00:09<00:06, 109.26 decays/s]
# Processing:  56%|█████▌    | 838/1500 [00:10<00:06, 97.93 decays/s]
# Processing:  57%|█████▋    | 849/1500 [00:10<00:08, 81.07 decays/s]
# Processing:  57%|█████▋    | 858/1500 [00:10<00:08, 79.41 decays/s]
# Processing:  58%|█████▊    | 867/1500 [00:10<00:08, 77.60 decays/s]
# Processing:  58%|█████▊    | 876/1500 [00:10<00:07, 79.85 decays/s]
# Processing:  59%|█████▉    | 887/1500 [00:10<00:07, 83.57 decays/s]
# Processing:  60%|█████▉    | 896/1500 [00:10<00:07, 79.54 decays/s]
# Processing:  60%|██████    | 907/1500 [00:10<00:06, 86.52 decays/s]
# Processing:  61%|██████    | 916/1500 [00:11<00:07, 82.61 decays/s]
# Processing:  62%|██████▏   | 925/1500 [00:11<00:07, 81.39 decays/s]
# Processing:  62%|██████▏   | 934/1500 [00:11<00:06, 81.38 decays/s]
# Processing:  63%|██████▎   | 943/1500 [00:11<00:07, 78.81 decays/s]
# Processing:  63%|██████▎   | 951/1500 [00:11<00:07, 74.13 decays/s]
# Processing:  64%|██████▍   | 959/1500 [00:11<00:07, 73.03 decays/s]
# Processing:  64%|██████▍   | 967/1500 [00:11<00:07, 70.92 decays/s]
# Processing:  65%|██████▌   | 975/1500 [00:11<00:07, 71.32 decays/s]
# Processing:  66%|██████▌   | 983/1500 [00:11<00:07, 73.21 decays/s]
# Processing:  66%|██████▌   | 991/1500 [00:12<00:06, 74.76 decays/s]
# Processing:  67%|██████▋   | 1001/1500 [00:12<00:06, 81.74 decays/s]
# Processing:  67%|██████▋   | 1010/1500 [00:12<00:06, 71.04 decays/s]
# Processing:  68%|██████▊   | 1018/1500 [00:12<00:06, 70.68 decays/s]
# Processing:  68%|██████▊   | 1026/1500 [00:12<00:06, 69.81 decays/s]
# Processing:  69%|██████▉   | 1036/1500 [00:12<00:06, 76.25 decays/s]
# Processing:  70%|██████▉   | 1044/1500 [00:12<00:05, 76.69 decays/s]
# Processing:  70%|███████   | 1055/1500 [00:12<00:05, 83.06 decays/s]
# Processing:  71%|███████   | 1065/1500 [00:13<00:05, 78.60 decays/s]
# Processing:  72%|███████▏  | 1075/1500 [00:13<00:05, 80.53 decays/s]
# Processing:  72%|███████▏  | 1084/1500 [00:13<00:05, 80.62 decays/s]
# Processing:  73%|███████▎  | 1094/1500 [00:13<00:04, 82.03 decays/s]
# Processing:  74%|███████▎  | 1104/1500 [00:13<00:04, 82.62 decays/s]
# Processing:  74%|███████▍  | 1113/1500 [00:13<00:04, 83.61 decays/s]
# Processing:  75%|███████▍  | 1122/1500 [00:13<00:04, 75.74 decays/s]
# Processing:  76%|███████▌  | 1137/1500 [00:13<00:04, 90.33 decays/s]
# Processing:  76%|███████▋  | 1147/1500 [00:14<00:04, 79.75 decays/s]
# Processing:  77%|███████▋  | 1156/1500 [00:14<00:04, 80.55 decays/s]
# Processing:  78%|███████▊  | 1165/1500 [00:14<00:04, 77.97 decays/s]
# Processing:  78%|███████▊  | 1173/1500 [00:14<00:04, 77.78 decays/s]
# Processing:  79%|███████▊  | 1181/1500 [00:14<00:04, 73.39 decays/s]
# Processing:  79%|███████▉  | 1192/1500 [00:14<00:03, 79.34 decays/s]
# Processing:  80%|████████  | 1201/1500 [00:14<00:03, 78.86 decays/s]
# Processing:  81%|████████  | 1209/1500 [00:14<00:04, 70.88 decays/s]
# Processing:  81%|████████  | 1218/1500 [00:14<00:03, 73.92 decays/s]
# Processing:  82%|████████▏ | 1228/1500 [00:15<00:03, 80.71 decays/s]
# Processing:  82%|████████▏ | 1237/1500 [00:15<00:03, 82.26 decays/s]
# Processing:  83%|████████▎ | 1246/1500 [00:15<00:03, 83.83 decays/s]
# Processing:  84%|████████▍ | 1258/1500 [00:15<00:02, 90.12 decays/s]
# Processing:  85%|████████▍ | 1268/1500 [00:15<00:02, 86.34 decays/s]
# Processing:  85%|████████▌ | 1280/1500 [00:15<00:02, 93.00 decays/s]
# Processing:  86%|████████▌ | 1290/1500 [00:15<00:02, 91.40 decays/s]
# Processing:  87%|████████▋ | 1300/1500 [00:15<00:02, 84.62 decays/s]
# Processing:  87%|████████▋ | 1310/1500 [00:16<00:02, 87.71 decays/s]
# Processing:  88%|████████▊ | 1321/1500 [00:16<00:01, 90.59 decays/s]
# Processing:  89%|████████▉ | 1332/1500 [00:16<00:01, 91.19 decays/s]
# Processing:  89%|████████▉ | 1342/1500 [00:16<00:01, 90.85 decays/s]
# Processing:  90%|█████████ | 1352/1500 [00:16<00:01, 84.88 decays/s]
# Processing:  91%|█████████ | 1361/1500 [00:16<00:01, 82.10 decays/s]
# Processing:  92%|█████████▏| 1375/1500 [00:16<00:01, 89.34 decays/s]
# Processing:  92%|█████████▏| 1384/1500 [00:16<00:01, 88.11 decays/s]
# Processing:  93%|█████████▎| 1393/1500 [00:16<00:01, 87.75 decays/s]
# Processing:  93%|█████████▎| 1402/1500 [00:17<00:01, 87.02 decays/s]
# Processing:  94%|█████████▍| 1411/1500 [00:17<00:01, 86.60 decays/s]
# Processing:  95%|█████████▍| 1421/1500 [00:17<00:00, 88.70 decays/s]
# Processing:  95%|█████████▌| 1431/1500 [00:17<00:00, 87.74 decays/s]
# Processing:  96%|█████████▌| 1441/1500 [00:17<00:00, 88.55 decays/s]
# Processing:  97%|█████████▋| 1450/1500 [00:17<00:00, 87.73 decays/s]
# Processing:  97%|█████████▋| 1461/1500 [00:17<00:00, 89.87 decays/s]
# Processing:  98%|█████████▊| 1470/1500 [00:17<00:00, 88.50 decays/s]
# Processing:  99%|█████████▊| 1479/1500 [00:17<00:00, 88.08 decays/s]
# Processing:  99%|█████████▉| 1488/1500 [00:18<00:00, 76.28 decays/s]
# Processing: 100%|█████████▉| 1497/1500 [00:18<00:00, 78.58 decays/s]
# Processing: 100%|██████████| 1500/1500 [00:18<00:00, 82.28 decays/s]

# %% [markdown]
# ## Read initial energy from the decay process

# %%
temp1, temp2, temp3, temp4 = td.TDCR_model_lib.read_temp_files()

ee_vec, eg_vec, ep_vec, ea_vec = td.TDCR_model_lib.energyVectors1(temp1)
nbins=50
plt.figure("1")
plt.hist(eg_vec, bins=nbins, edgecolor='none',density=True,label='photons')
plt.hist(ee_vec, bins=nbins, edgecolor='none',density=True,label='electrons')
plt.hist(ep_vec, bins=nbins, edgecolor='none',density=True,label='positrons')
plt.hist(ea_vec, bins=nbins, edgecolor='none',density=True,label='alphas')
plt.title('Distribution of Initial Energies')
plt.xlabel('Energy /keV')
plt.ylabel('Frequency')
plt.legend()
plt.show()
# Out:
# g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages\numpy\lib\_histograms_impl.py:897: RuntimeWarning: invalid value encountered in divide
#   return n / db / n.sum(), bin_edges

# %% [markdown]
# ## Read deposited energy in the scintillator

# %%
ee_vec, ep_vec, ea_vec = td.TDCR_model_lib.energyVectors2(temp2)
nbins=50
plt.figure("2")
plt.hist(ee_vec, bins=nbins, edgecolor='none',density=True,label='electrons')
plt.hist(ep_vec, bins=nbins, edgecolor='none',density=True,label='positrons')
plt.hist(ea_vec, bins=nbins, edgecolor='none',density=True,label='alphas')
plt.title('Distribution of Deposited Energies')
plt.xlabel('Energy /keV')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %% [markdown]
# ## Read quenched deposited energy in the scintillator

# %%
ee_vec = td.TDCR_model_lib.energyVectors3(temp3)
nbins=50
plt.figure("3")
plt.hist(ee_vec, bins=nbins, edgecolor='none',density=True,label='electrons')
plt.title('Distribution of Quenched Deposited Energies')
plt.xlabel('Energy /keV')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %% [markdown]
# ## Read detection probabilities per decay event

# %%
s_vec, d_vec, t_vec = td.TDCR_model_lib.effVector(temp4)
nbins=50
plt.figure("4")
plt.hist(s_vec, bins=nbins, edgecolor='none',density=True,label='single events')
plt.hist(d_vec, bins=nbins, edgecolor='none',density=True,label='double coincidences')
plt.hist(t_vec, bins=nbins, edgecolor='none',density=True,label='triple coincidences')
plt.title('Distribution of detection probabilities per decay event')
plt.xlabel('Detection probability')
plt.ylabel('Frequency')
plt.legend()
plt.show()
