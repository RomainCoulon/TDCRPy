# %% [markdown]
# # Distribution of TDCR measurements

# %%
pip install TDCRPy==2.20.11
# Out:
# Requirement already satisfied: TDCRPy==2.20.10 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (2.20.10)
# Requirement already satisfied: numpy in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.10) (2.4.6)
# Requirement already satisfied: scipy in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.10) (1.18.0)
# Requirement already satisfied: matplotlib in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.10) (3.11.0)
# Requirement already satisfied: tqdm in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.10) (4.68.3)
# Requirement already satisfied: numba in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.10) (0.65.1)
# Requirement already satisfied: setuptools in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from TDCRPy==2.20.10) (82.0.1)
# Requirement already satisfied: contourpy>=1.0.1 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.10) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.10) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.10) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.10) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.10) (26.2)
# Requirement already satisfied: pillow>=9 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.10) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.10) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from matplotlib->TDCRPy==2.20.10) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from python-dateutil>=2.7->matplotlib->TDCRPy==2.20.10) (1.17.0)
# Requirement already satisfied: llvmlite<0.48,>=0.47.0dev0 in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from numba->TDCRPy==2.20.10) (0.47.0)
# Requirement already satisfied: colorama in g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages (from tqdm->TDCRPy==2.20.10) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import tdcrpy as td
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt

# %% [markdown]
# ## Record the decay histories in temporary files

# %%
mode = "eff"                # ask for efficiency calculation
Rad="Cd-109"                # radionuclides
pmf_1="1"                   # relatives fractions of the radionulides
N = 1500                    # number of Monte Carlo trials
kB =1.0e-5                  # Birks constant in cm keV-1
V = 10                      # volume of scintillator in mL
L=1                         # free parameter in keV-1

out = td.TDCRPy.TDCRPy(1, Rad, pmf_1, N, kB, V, mode, record=True, barp=True)
# Out:
#  ______  ______  ______ _______  ________
# |__  __||  ___ \|  ___||  ___ | |  ____ |
#   | |   | |  | || |    | |  | | | |___| |___     ___
#   | |   | |  | || |    | |__| | |  _____|\  \   |  |
#   | |   | |__| || |____|  __  \ | |       \  \  |  |
#   |_|   |_____/ |_____||_|  \__\|_|        \  \_|  |
#   +++++++++++++++++++++++++++++++++++++++++/      /
#   ________________________________________/      /
#  |______________________________________________/
#
#
# version 2.20.10
# BIPM 2023 - license MIT
# distribution: https://pypi.org/project/TDCRPy
# developement: https://github.com/RomainCoulon/TDCRPy
#
# start calculation...
# Processing:   0%|          | 0/1500 [00:00<?, ? decays/s]
# Processing:   0%|          | 5/1500 [00:00<00:40, 36.98 decays/s]
# Processing:   1%|          | 12/1500 [00:00<00:28, 53.06 decays/s]
# Processing:   2%|▏         | 23/1500 [00:00<00:19, 74.14 decays/s]
# Processing:   2%|▏         | 31/1500 [00:00<00:23, 62.42 decays/s]
# Processing:   3%|▎         | 40/1500 [00:00<00:20, 70.22 decays/s]
# Processing:   3%|▎         | 51/1500 [00:00<00:18, 78.01 decays/s]
# Processing:   4%|▍         | 60/1500 [00:00<00:17, 80.40 decays/s]
# Processing:   5%|▍         | 69/1500 [00:00<00:17, 81.09 decays/s]
# Processing:   5%|▌         | 80/1500 [00:01<00:16, 84.61 decays/s]
# Processing:   6%|▌         | 89/1500 [00:01<00:18, 76.49 decays/s]
# Processing:   6%|▋         | 97/1500 [00:01<00:20, 69.99 decays/s]
# Processing:   7%|▋         | 105/1500 [00:01<00:19, 71.64 decays/s]
# Processing:   8%|▊         | 113/1500 [00:01<00:19, 72.14 decays/s]
# Processing:   8%|▊         | 121/1500 [00:01<00:19, 72.52 decays/s]
# Processing:   9%|▊         | 129/1500 [00:01<00:21, 64.38 decays/s]
# Processing:   9%|▉         | 136/1500 [00:01<00:20, 65.75 decays/s]
# Processing:  10%|▉         | 143/1500 [00:02<00:20, 65.69 decays/s]
# Processing:  10%|█         | 153/1500 [00:02<00:18, 74.56 decays/s]
# Processing:  11%|█         | 162/1500 [00:02<00:17, 77.35 decays/s]
# Processing:  11%|█▏        | 170/1500 [00:02<00:20, 65.67 decays/s]
# Processing:  12%|█▏        | 181/1500 [00:02<00:18, 72.96 decays/s]
# Processing:  13%|█▎        | 189/1500 [00:02<00:17, 73.97 decays/s]
# Processing:  14%|█▎        | 203/1500 [00:02<00:14, 90.09 decays/s]
# Processing:  14%|█▍        | 213/1500 [00:02<00:15, 85.13 decays/s]
# Processing:  15%|█▍        | 222/1500 [00:03<00:15, 80.68 decays/s]
# Processing:  15%|█▌        | 232/1500 [00:03<00:14, 85.11 decays/s]
# Processing:  16%|█▌        | 241/1500 [00:03<00:14, 84.78 decays/s]
# Processing:  17%|█▋        | 252/1500 [00:03<00:13, 89.37 decays/s]
# Processing:  17%|█▋        | 262/1500 [00:03<00:15, 81.99 decays/s]
# Processing:  18%|█▊        | 271/1500 [00:03<00:15, 79.12 decays/s]
# Processing:  19%|█▊        | 281/1500 [00:03<00:14, 83.37 decays/s]
# Processing:  19%|█▉        | 292/1500 [00:03<00:13, 89.32 decays/s]
# Processing:  20%|██        | 302/1500 [00:03<00:13, 87.72 decays/s]
# Processing:  21%|██        | 313/1500 [00:04<00:12, 93.76 decays/s]
# Processing:  22%|██▏       | 323/1500 [00:04<00:13, 85.73 decays/s]
# Processing:  22%|██▏       | 333/1500 [00:04<00:13, 87.73 decays/s]
# Processing:  23%|██▎       | 342/1500 [00:04<00:13, 84.45 decays/s]
# Processing:  23%|██▎       | 351/1500 [00:04<00:14, 76.89 decays/s]
# Processing:  24%|██▍       | 359/1500 [00:04<00:15, 75.41 decays/s]
# Processing:  24%|██▍       | 367/1500 [00:04<00:15, 73.02 decays/s]
# Processing:  25%|██▌       | 378/1500 [00:04<00:14, 78.25 decays/s]
# Processing:  26%|██▌       | 388/1500 [00:04<00:13, 81.79 decays/s]
# Processing:  26%|██▋       | 397/1500 [00:05<00:14, 78.51 decays/s]
# Processing:  27%|██▋       | 405/1500 [00:05<00:14, 75.99 decays/s]
# Processing:  28%|██▊       | 414/1500 [00:05<00:13, 79.57 decays/s]
# Processing:  28%|██▊       | 423/1500 [00:05<00:13, 81.95 decays/s]
# Processing:  29%|██▉       | 432/1500 [00:05<00:14, 72.48 decays/s]
# Processing:  30%|██▉       | 446/1500 [00:05<00:11, 89.73 decays/s]
# Processing:  30%|███       | 456/1500 [00:05<00:12, 82.17 decays/s]
# Processing:  31%|███       | 465/1500 [00:05<00:14, 73.49 decays/s]
# Processing:  32%|███▏      | 473/1500 [00:06<00:14, 70.37 decays/s]
# Processing:  32%|███▏      | 481/1500 [00:06<00:15, 64.49 decays/s]
# Processing:  33%|███▎      | 490/1500 [00:06<00:14, 70.14 decays/s]
# Processing:  33%|███▎      | 498/1500 [00:06<00:16, 59.38 decays/s]
# Processing:  34%|███▍      | 507/1500 [00:06<00:15, 65.45 decays/s]
# Processing:  34%|███▍      | 516/1500 [00:06<00:14, 70.24 decays/s]
# Processing:  35%|███▍      | 524/1500 [00:06<00:14, 68.43 decays/s]
# Processing:  36%|███▌      | 533/1500 [00:07<00:13, 71.81 decays/s]
# Processing:  36%|███▌      | 541/1500 [00:07<00:13, 72.60 decays/s]
# Processing:  37%|███▋      | 550/1500 [00:07<00:12, 75.33 decays/s]
# Processing:  37%|███▋      | 558/1500 [00:07<00:13, 71.73 decays/s]
# Processing:  38%|███▊      | 570/1500 [00:07<00:11, 84.40 decays/s]
# Processing:  39%|███▊      | 579/1500 [00:07<00:11, 78.09 decays/s]
# Processing:  39%|███▉      | 588/1500 [00:07<00:11, 81.14 decays/s]
# Processing:  40%|███▉      | 597/1500 [00:07<00:11, 79.78 decays/s]
# Processing:  41%|████      | 608/1500 [00:07<00:10, 86.29 decays/s]
# Processing:  41%|████      | 617/1500 [00:08<00:10, 85.46 decays/s]
# Processing:  42%|████▏     | 628/1500 [00:08<00:09, 91.97 decays/s]
# Processing:  43%|████▎     | 638/1500 [00:08<00:09, 91.67 decays/s]
# Processing:  43%|████▎     | 648/1500 [00:08<00:10, 83.98 decays/s]
# Processing:  44%|████▍     | 657/1500 [00:08<00:10, 81.93 decays/s]
# Processing:  44%|████▍     | 666/1500 [00:08<00:10, 75.85 decays/s]
# Processing:  45%|████▍     | 674/1500 [00:08<00:10, 75.47 decays/s]
# Processing:  46%|████▌     | 683/1500 [00:08<00:10, 77.94 decays/s]
# Processing:  46%|████▌     | 692/1500 [00:08<00:10, 79.71 decays/s]
# Processing:  47%|████▋     | 701/1500 [00:09<00:10, 79.74 decays/s]
# Processing:  47%|████▋     | 711/1500 [00:09<00:09, 84.83 decays/s]
# Processing:  48%|████▊     | 720/1500 [00:09<00:09, 86.06 decays/s]
# Processing:  49%|████▊     | 729/1500 [00:09<00:09, 81.99 decays/s]
# Processing:  49%|████▉     | 738/1500 [00:09<00:10, 69.79 decays/s]
# Processing:  50%|████▉     | 748/1500 [00:09<00:10, 74.81 decays/s]
# Processing:  50%|█████     | 756/1500 [00:09<00:09, 76.09 decays/s]
# Processing:  51%|█████     | 765/1500 [00:09<00:09, 76.13 decays/s]
# Processing:  52%|█████▏    | 774/1500 [00:10<00:09, 77.25 decays/s]
# Processing:  52%|█████▏    | 782/1500 [00:10<00:09, 76.22 decays/s]
# Processing:  53%|█████▎    | 790/1500 [00:10<00:10, 69.87 decays/s]
# Processing:  53%|█████▎    | 798/1500 [00:10<00:10, 69.07 decays/s]
# Processing:  54%|█████▎    | 806/1500 [00:10<00:10, 68.10 decays/s]
# Processing:  54%|█████▍    | 814/1500 [00:10<00:10, 67.27 decays/s]
# Processing:  55%|█████▍    | 822/1500 [00:10<00:09, 69.72 decays/s]
# Processing:  55%|█████▌    | 830/1500 [00:10<00:11, 59.09 decays/s]
# Processing:  56%|█████▌    | 840/1500 [00:11<00:10, 64.76 decays/s]
# Processing:  57%|█████▋    | 850/1500 [00:11<00:09, 68.77 decays/s]
# Processing:  57%|█████▋    | 858/1500 [00:11<00:09, 68.30 decays/s]
# Processing:  58%|█████▊    | 870/1500 [00:11<00:08, 78.66 decays/s]
# Processing:  59%|█████▊    | 879/1500 [00:11<00:08, 77.13 decays/s]
# Processing:  59%|█████▉    | 890/1500 [00:11<00:07, 84.17 decays/s]
# Processing:  60%|██████    | 901/1500 [00:11<00:06, 88.44 decays/s]
# Processing:  61%|██████    | 910/1500 [00:11<00:06, 86.61 decays/s]
# Processing:  62%|██████▏   | 923/1500 [00:11<00:05, 97.16 decays/s]
# Processing:  62%|██████▏   | 933/1500 [00:12<00:06, 93.55 decays/s]
# Processing:  63%|██████▎   | 943/1500 [00:12<00:06, 84.85 decays/s]
# Processing:  63%|██████▎   | 952/1500 [00:12<00:06, 85.69 decays/s]
# Processing:  64%|██████▍   | 961/1500 [00:12<00:06, 85.50 decays/s]
# Processing:  65%|██████▍   | 974/1500 [00:12<00:05, 94.72 decays/s]
# Processing:  66%|██████▌   | 984/1500 [00:12<00:05, 87.17 decays/s]
# Processing:  66%|██████▋   | 994/1500 [00:12<00:05, 86.42 decays/s]
# Processing:  67%|██████▋   | 1004/1500 [00:12<00:05, 89.98 decays/s]
# Processing:  68%|██████▊   | 1014/1500 [00:13<00:05, 88.86 decays/s]
# Processing:  68%|██████▊   | 1025/1500 [00:13<00:05, 94.08 decays/s]
# Processing:  69%|██████▉   | 1035/1500 [00:13<00:05, 90.37 decays/s]
# Processing:  70%|██████▉   | 1045/1500 [00:13<00:05, 80.54 decays/s]
# Processing:  70%|███████   | 1054/1500 [00:13<00:05, 76.78 decays/s]
# Processing:  71%|███████   | 1062/1500 [00:13<00:05, 74.79 decays/s]
# Processing:  71%|███████▏  | 1070/1500 [00:13<00:05, 71.73 decays/s]
# Processing:  72%|███████▏  | 1080/1500 [00:13<00:05, 78.78 decays/s]
# Processing:  73%|███████▎  | 1089/1500 [00:13<00:05, 76.79 decays/s]
# Processing:  73%|███████▎  | 1098/1500 [00:14<00:05, 77.82 decays/s]
# Processing:  74%|███████▍  | 1108/1500 [00:14<00:04, 81.49 decays/s]
# Processing:  74%|███████▍  | 1117/1500 [00:14<00:05, 71.54 decays/s]
# Processing:  75%|███████▌  | 1125/1500 [00:14<00:05, 72.40 decays/s]
# Processing:  76%|███████▌  | 1133/1500 [00:14<00:04, 73.45 decays/s]
# Processing:  76%|███████▌  | 1142/1500 [00:14<00:04, 73.84 decays/s]
# Processing:  77%|███████▋  | 1150/1500 [00:14<00:05, 68.79 decays/s]
# Processing:  77%|███████▋  | 1158/1500 [00:14<00:04, 71.48 decays/s]
# Processing:  78%|███████▊  | 1168/1500 [00:15<00:04, 75.76 decays/s]
# Processing:  78%|███████▊  | 1176/1500 [00:15<00:04, 65.22 decays/s]
# Processing:  79%|███████▉  | 1183/1500 [00:15<00:05, 62.72 decays/s]
# Processing:  79%|███████▉  | 1190/1500 [00:15<00:04, 62.86 decays/s]
# Processing:  80%|███████▉  | 1197/1500 [00:15<00:04, 62.80 decays/s]
# Processing:  80%|████████  | 1207/1500 [00:15<00:04, 70.34 decays/s]
# Processing:  81%|████████  | 1215/1500 [00:15<00:04, 65.39 decays/s]
# Processing:  82%|████████▏ | 1228/1500 [00:15<00:03, 79.65 decays/s]
# Processing:  82%|████████▏ | 1237/1500 [00:16<00:03, 72.77 decays/s]
# Processing:  83%|████████▎ | 1245/1500 [00:16<00:03, 68.83 decays/s]
# Processing:  84%|████████▎ | 1253/1500 [00:16<00:03, 70.31 decays/s]
# Processing:  84%|████████▍ | 1261/1500 [00:16<00:03, 71.75 decays/s]
# Processing:  85%|████████▍ | 1269/1500 [00:16<00:03, 71.07 decays/s]
# Processing:  85%|████████▌ | 1277/1500 [00:16<00:03, 65.25 decays/s]
# Processing:  86%|████████▌ | 1284/1500 [00:16<00:03, 64.23 decays/s]
# Processing:  86%|████████▌ | 1291/1500 [00:16<00:03, 65.31 decays/s]
# Processing:  87%|████████▋ | 1298/1500 [00:17<00:03, 54.82 decays/s]
# Processing:  87%|████████▋ | 1306/1500 [00:17<00:03, 59.94 decays/s]
# Processing:  88%|████████▊ | 1313/1500 [00:17<00:03, 62.06 decays/s]
# Processing:  88%|████████▊ | 1320/1500 [00:17<00:02, 63.15 decays/s]
# Processing:  89%|████████▊ | 1330/1500 [00:17<00:02, 71.15 decays/s]
# Processing:  89%|████████▉ | 1338/1500 [00:17<00:02, 62.41 decays/s]
# Processing:  90%|████████▉ | 1345/1500 [00:17<00:02, 63.73 decays/s]
# Processing:  90%|█████████ | 1352/1500 [00:17<00:02, 61.19 decays/s]
# Processing:  91%|█████████ | 1361/1500 [00:18<00:02, 67.25 decays/s]
# Processing:  91%|█████████▏| 1372/1500 [00:18<00:01, 78.07 decays/s]
# Processing:  92%|█████████▏| 1381/1500 [00:18<00:01, 73.13 decays/s]
# Processing:  93%|█████████▎| 1389/1500 [00:18<00:01, 74.72 decays/s]
# Processing:  93%|█████████▎| 1398/1500 [00:18<00:01, 73.30 decays/s]
# Processing:  94%|█████████▎| 1406/1500 [00:18<00:01, 72.15 decays/s]
# Processing:  94%|█████████▍| 1414/1500 [00:18<00:01, 59.46 decays/s]
# Processing:  95%|█████████▍| 1422/1500 [00:18<00:01, 61.33 decays/s]
# Processing:  95%|█████████▌| 1429/1500 [00:19<00:01, 61.80 decays/s]
# Processing:  96%|█████████▌| 1438/1500 [00:19<00:00, 65.73 decays/s]
# Processing:  97%|█████████▋| 1448/1500 [00:19<00:00, 70.77 decays/s]
# Processing:  97%|█████████▋| 1457/1500 [00:19<00:00, 71.87 decays/s]
# Processing:  98%|█████████▊| 1466/1500 [00:19<00:00, 75.59 decays/s]
# Processing:  98%|█████████▊| 1474/1500 [00:19<00:00, 70.09 decays/s]
# Processing:  99%|█████████▉| 1482/1500 [00:19<00:00, 65.71 decays/s]
# Processing:  99%|█████████▉| 1490/1500 [00:19<00:00, 67.47 decays/s]
# Processing: 100%|██████████| 1500/1500 [00:19<00:00, 75.07 decays/s]

# %% [markdown]
# ## Read initial energy from the decay process

# %%
temp1, temp2, temp3, temp4 = td.TDCR_model_lib.read_temp_files()

ee_vec, eg_vec, ep_vec, ea_vec = td.TDCR_model_lib.energyVectors1(temp1)
nbins=50
plt.figure("1")
plt.hist(eg_vec, bins=nbins, edgecolor='none',density=True,label='photons')
plt.hist(ee_vec, bins=nbins, edgecolor='none',density=True,label='electrons')
plt.hist(ep_vec, bins=nbins, edgecolor='none',density=True,label='positrons')
plt.hist(ea_vec, bins=nbins, edgecolor='none',density=True,label='alphas')
plt.title('Distribution of Initial Energies')
plt.xlabel('Energy /keV')
plt.ylabel('Frequency')
plt.legend()
plt.show()
# Out:
# g:\Python_modules\TDCRPy\TDCRPy\.venv\Lib\site-packages\numpy\lib\_histograms_impl.py:897: RuntimeWarning: invalid value encountered in divide
#   return n / db / n.sum(), bin_edges

# %% [markdown]
# ## Read deposited energy in the scintillator

# %%
ee_vec, ep_vec, ea_vec = td.TDCR_model_lib.energyVectors2(temp2)
nbins=50
plt.figure("2")
plt.hist(ee_vec, bins=nbins, edgecolor='none',density=True,label='electrons')
plt.hist(ep_vec, bins=nbins, edgecolor='none',density=True,label='positrons')
plt.hist(ea_vec, bins=nbins, edgecolor='none',density=True,label='alphas')
plt.title('Distribution of Deposited Energies')
plt.xlabel('Energy /keV')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %% [markdown]
# ## Read quenched deposited energy in the scintillator

# %%
ee_vec = td.TDCR_model_lib.energyVectors3(temp3)
nbins=50
plt.figure("3")
plt.hist(ee_vec, bins=nbins, edgecolor='none',density=True,label='electrons')
plt.title('Distribution of Quenched Deposited Energies')
plt.xlabel('Energy /keV')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %% [markdown]
# ## Read detection probabilities per decay event

# %%
s_vec, d_vec, t_vec = td.TDCR_model_lib.effVector(temp4)
nbins=50
plt.figure("4")
plt.hist(s_vec, bins=nbins, edgecolor='none',density=True,label='single events')
plt.hist(d_vec, bins=nbins, edgecolor='none',density=True,label='double coincidences')
plt.hist(t_vec, bins=nbins, edgecolor='none',density=True,label='triple coincidences')
plt.title('Distribution of detection probabilities per decay event')
plt.xlabel('Detection probability')
plt.ylabel('Frequency')
plt.legend()
plt.show()
